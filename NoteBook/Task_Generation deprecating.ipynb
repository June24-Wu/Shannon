# %%
Alpha_Name = "Original_Input_Moving_7_Shift_5"
sequence = 6
LR = [0.001,0.0001]
epoch_num = [30,20]
feature_num = 108

# %%
import pandas as pd
import numpy as np
task_info = np.load("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",allow_pickle=True).item()
# pd.read_parquet("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.par")
original = task_info["Task"]
original
# Out:
#                                              Alpha_Name sequence  \
# task_id
# 0                      Original_Input_Moving_10_Shift_5        5
# 1                      Original_Input_Moving_10_Shift_5        5
# 2                      Original_Input_Moving_10_Shift_5        5
# 3                      Original_Input_Moving_10_Shift_5        5
# 4                      Original_Input_Moving_10_Shift_5        5
# 5                       Original_Input_Moving_7_Shift_5        6
# 6                       Original_Input_Moving_7_Shift_5        6
# 7                       Original_Input_Moving_7_Shift_5        6
# 8                       Original_Input_Moving_7_Shift_5        6
# 9                       Original_Input_Moving_7_Shift_5        6
# 10                   Original_Input_Shift_1_Sequence_10       10
# 11                   Original_Input_Shift_1_Sequence_10       10
# 12                   Original_Input_Shift_1_Sequence_10       10
# 13                   Original_Input_Shift_1_Sequence_10       10
# 14                   Original_Input_Shift_1_Sequence_10       10
# 15                   Original_Input_Shift_3_Sequence_10       10
# 16                   Original_Input_Shift_3_Sequence_10       10
# 17                   Original_Input_Shift_3_Sequence_10       10
# 18                   Original_Input_Shift_3_Sequence_10       10
# 19                   Original_Input_Shift_3_Sequence_10       10
# 20                    Original_Input_Shift_1_Sequence_5        5
# 21                    Original_Input_Shift_1_Sequence_5        5
# 22                    Original_Input_Shift_1_Sequence_5        5
# 23                    Original_Input_Shift_1_Sequence_5        5
# 24                    Original_Input_Shift_1_Sequence_5        5
# 25        Original_Input_Ts_Standard_Shift_1_Sequence_5        5
# 26        Original_Input_Ts_Standard_Shift_1_Sequence_5        5
# 27        Original_Input_Ts_Standard_Shift_1_Sequence_5        5
# 28        Original_Input_Ts_Standard_Shift_1_Sequence_5        5
# 29        Original_Input_Ts_Standard_Shift_1_Sequence_5        5
# 30       Original_Input_Ts_Standard_Shift_3_Sequence_10       10
# 31       Original_Input_Ts_Standard_Shift_3_Sequence_10       10
# 32       Original_Input_Ts_Standard_Shift_3_Sequence_10       10
# 33       Original_Input_Ts_Standard_Shift_3_Sequence_10       10
# 34       Original_Input_Ts_Standard_Shift_3_Sequence_10       10
# 35       Original_Input_Ts_Standard_Shift_1_Sequence_10       10
# 36       Original_Input_Ts_Standard_Shift_1_Sequence_10       10
# 37       Original_Input_Ts_Standard_Shift_1_Sequence_10       10
# 38       Original_Input_Ts_Standard_Shift_1_Sequence_10       10
# 39       Original_Input_Ts_Standard_Shift_1_Sequence_10       10
#
#                              LR     epoch_num feature_num  start_date  \
# task_id
# 0               [0.001, 0.0001]      [30, 20]         108  2019-01-01
# 1               [0.001, 0.0001]      [30, 20]         108  2019-06-01
# 2               [0.001, 0.0001]      [30, 20]         108  2020-01-01
# 3               [0.001, 0.0001]      [30, 20]         108  2020-06-01
# 4               [0.001, 0.0001]      [30, 20]         108  2021-01-01
# 5               [0.001, 0.0001]      [30, 20]         108  2019-01-01
# 6               [0.001, 0.0001]      [30, 20]         108  2019-06-01
# 7               [0.001, 0.0001]      [30, 20]         108  2020-01-01
# 8               [0.001, 0.0001]      [30, 20]         108  2020-06-01
# 9               [0.001, 0.0001]      [30, 20]         108  2021-01-01
# 10       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-01-01
# 11       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-06-01
# 12       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-01-01
# 13       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-06-01
# 14       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2021-01-01
# 15       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-01-01
# 16       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-06-01
# 17       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-01-01
# 18       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-06-01
# 19       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2021-01-01
# 20       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-01-01
# 21       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-06-01
# 22       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-01-01
# 23       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-06-01
# 24       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2021-01-01
# 25       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-01-01
# 26       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2019-06-01
# 27       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-01-01
# 28       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2020-06-01
# 29       [0.001, 0.0001, 1e-05]  [40, 20, 20]           9  2021-01-01
# 30       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2019-01-01
# 31       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2019-06-01
# 32       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2020-01-01
# 33       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2020-06-01
# 34       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2021-01-01
# 35       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2019-01-01
# 36       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2019-06-01
# 37       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2020-01-01
# 38       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2020-06-01
# 39       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2021-01-01
#
#            end_date    status  \
# task_id
# 0        2019-06-01  finished
# 1        2020-01-01  finished
# 2        2020-06-01  finished
# 3        2021-01-01  finished
# 4        2021-06-01  finished
# 5        2019-06-01  finished
# 6        2020-01-01  finished
# 7        2020-06-01   running
# 8        2021-01-01   running
# 9        2021-06-01   waiting
# 10       2019-06-01   waiting
# 11       2020-01-01   waiting
# 12       2020-06-01   waiting
# 13       2021-01-01   waiting
# 14       2021-06-01   waiting
# 15       2019-06-01   waiting
# 16       2020-01-01   waiting
# 17       2020-06-01   waiting
# 18       2021-01-01   waiting
# 19       2021-06-01   waiting
# 20       2019-06-01   waiting
# 21       2020-01-01   waiting
# 22       2020-06-01   waiting
# 23       2021-01-01   waiting
# 24       2021-06-01   waiting
# 25       2019-06-01   waiting
# 26       2020-01-01   waiting
# 27       2020-06-01   waiting
# 28       2021-01-01   waiting
# 29       2021-06-01   waiting
# 30       2019-06-01   waiting
# 31       2020-01-01   waiting
# 32       2020-06-01   waiting
# 33       2021-01-01   waiting
# 34       2021-06-01   waiting
# 35       2019-06-01   waiting
# 36       2020-01-01   waiting
# 37       2020-06-01   waiting
# 38       2021-01-01   waiting
# 39       2021-06-01   waiting
#
#                                                description
# task_id
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# 5                                                     None
# 6                                                     None
# 7                                                     None
# 8                                                     None
# 9                                                     None
# 10       {'target': '10d_ret_standscalar', 'alpha_name'...
# 11       {'target': '10d_ret_standscalar', 'alpha_name'...
# 12       {'target': '10d_ret_standscalar', 'alpha_name'...
# 13       {'target': '10d_ret_standscalar', 'alpha_name'...
# 14       {'target': '10d_ret_standscalar', 'alpha_name'...
# 15       {'target': '10d_ret_standscalar', 'alpha_name'...
# 16       {'target': '10d_ret_standscalar', 'alpha_name'...
# 17       {'target': '10d_ret_standscalar', 'alpha_name'...
# 18       {'target': '10d_ret_standscalar', 'alpha_name'...
# 19       {'target': '10d_ret_standscalar', 'alpha_name'...
# 20       {'target': '10d_ret_standscalar', 'alpha_name'...
# 21       {'target': '10d_ret_standscalar', 'alpha_name'...
# 22       {'target': '10d_ret_standscalar', 'alpha_name'...
# 23       {'target': '10d_ret_standscalar', 'alpha_name'...
# 24       {'target': '10d_ret_standscalar', 'alpha_name'...
# 25       {'target': '10d_ret_standscalar', 'alpha_name'...
# 26       {'target': '10d_ret_standscalar', 'alpha_name'...
# 27       {'target': '10d_ret_standscalar', 'alpha_name'...
# 28       {'target': '10d_ret_standscalar', 'alpha_name'...
# 29       {'target': '10d_ret_standscalar', 'alpha_name'...
# 30       {'target': '10d_ret_standscalar', 'alpha_name'...
# 31       {'target': '10d_ret_standscalar', 'alpha_name'...
# 32       {'target': '10d_ret_standscalar', 'alpha_name'...
# 33       {'target': '10d_ret_standscalar', 'alpha_name'...
# 34       {'target': '10d_ret_standscalar', 'alpha_name'...
# 35       {'target': '10d_ret_standscalar', 'alpha_name'...
# 36       {'target': '10d_ret_standscalar', 'alpha_name'...
# 37       {'target': '10d_ret_standscalar', 'alpha_name'...
# 38       {'target': '10d_ret_standscalar', 'alpha_name'...
# 39       {'target': '10d_ret_standscalar', 'alpha_name'...

# %%
time_list = ["2019-01-01","2019-06-01","2020-01-01","2020-06-01","2021-01-01","2021-06-01"]
time_list2 = []
for i in range(len(time_list)-1):
    time_list2.append([time_list[i],time_list[i+1]])
time_list2 = pd.DataFrame(time_list2,columns=["start_date","end_date"])
time_list2
# Out:
#    start_date    end_date
# 0  2019-01-01  2019-06-01
# 1  2019-06-01  2020-01-01
# 2  2020-01-01  2020-06-01
# 3  2020-06-01  2021-01-01
# 4  2021-01-01  2021-06-01

# %%
task = pd.DataFrame([Alpha_Name,sequence,LR,epoch_num,feature_num],index=["Alpha_Name","sequence","LR","epoch_num","feature_num"]).T
task['value']=1
time_list2['value']=1
task = pd.merge(task,time_list2,how='left',on='value')
del task['value']
task["status"] = "waiting"
task
# Out:
#                         Alpha_Name sequence               LR epoch_num  \
# 0  Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 1  Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 2  Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 3  Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 4  Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
#
#   feature_num  start_date    end_date   status
# 0         108  2019-01-01  2019-06-01  waiting
# 1         108  2019-06-01  2020-01-01  waiting
# 2         108  2020-01-01  2020-06-01  waiting
# 3         108  2020-06-01  2021-01-01  waiting
# 4         108  2021-01-01  2021-06-01  waiting

# %%
task = pd.concat([original,task],axis=0)
task.reset_index(drop=True,inplace=True)
task.index.names = ["task_id"]
task_info["Task"] = task
# if task.duplicated().any() == True:
#     task = original
#     raise ValueError("concains duplicates value")
task
# Out:
#                                Alpha_Name sequence               LR epoch_num  \
# task_id
# 0        Original_Input_Moving_10_Shift_5        5  [0.001, 0.0001]  [30, 20]
# 1        Original_Input_Moving_10_Shift_5        5  [0.001, 0.0001]  [30, 20]
# 2        Original_Input_Moving_10_Shift_5        5  [0.001, 0.0001]  [30, 20]
# 3        Original_Input_Moving_10_Shift_5        5  [0.001, 0.0001]  [30, 20]
# 4        Original_Input_Moving_10_Shift_5        5  [0.001, 0.0001]  [30, 20]
# 5         Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 6         Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 7         Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 8         Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
# 9         Original_Input_Moving_7_Shift_5        6  [0.001, 0.0001]  [30, 20]
#
#         feature_num  start_date    end_date    status
# task_id
# 0               108  2019-01-01  2019-06-01  finished
# 1               108  2019-06-01  2020-01-01   waiting
# 2               108  2020-01-01  2020-06-01  finished
# 3               108  2020-06-01  2021-01-01  finished
# 4               108  2021-01-01  2021-06-01   waiting
# 5               108  2019-01-01  2019-06-01   waiting
# 6               108  2019-06-01  2020-01-01   waiting
# 7               108  2020-01-01  2020-06-01   waiting
# 8               108  2020-06-01  2021-01-01   waiting
# 9               108  2021-01-01  2021-06-01   waiting

# %%
task_info["Cuda"]
# Out:
# ['cuda:0', 'cuda:1', 'cuda:1', 'cuda:1']

# %%
# task_info.to_parquet("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.par")
np.save("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",task_info)
