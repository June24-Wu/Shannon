# %% [markdown]
# # 从DataBase里面读取数据

# %%
time_start = 20150101
time_end =  20210630
feat_list = ['open','high','low','close','vwap','volume','pct_chg','turnover','free_turnover']
return_value = '5d_ret'
Alpha_Name = "AlphaNet_Original_Input_12.14"
output_path = '/home/wuwenjun/Data/' + Alpha_Name +'/'

# %%
import time
import os
from Research.backtest.bt import BTDaily
from Research.feature.ft import FeatureAnalysis
import Research.utils.namespace as namespace
import Research.utils.normalization as norm
from Platform.database.mysql import MysqlAPI
from Platform.utils.persistence import convert_to_standard_daily_feature_csv, convert_to_standard_daily_feature_par
from Platform.config.mysql_info import FACTOR_LIB_MYSQL_TIO
import DataAPI
from os import walk
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from progressbar import ProgressBar
from tqdm import tqdm

# %% [markdown]
# # New

# %%
dataframe_list = pd.read_csv("/home/wuwenjun/Data/AlphaNet_Original_Input_12.14/data.csv")
time_list = list(dataframe_list['timestamp'].drop_duplicates())
dataframe_list["timestamp"] = pd.to_datetime(dataframe_list["timestamp"])
dataframe_list.set_index(["timestamp","ticker"],inplace=True)
dataframe_list
# Out:
#                                open     high      low    close         vwap  \
# timestamp           ticker
# 2015-01-06 09:30:00 1       1136.15  1156.75  1108.44  1138.28  1134.052643
#                     2       1774.23  1885.20  1753.27  1838.34  1823.031224
#                     4         63.31    64.62    62.18    63.76    63.277989
#                     5         38.00    38.00    38.00    38.00    37.997172
#                     6        225.64   234.85   223.10   225.00   228.438278
# ...                             ...      ...      ...      ...          ...
# 2021-07-01 09:30:00 688700    47.80    54.50    47.03    53.38    50.715300
#                     688777    90.21    95.08    89.32    94.42    93.250464
#                     688788   138.07   149.35   137.11   146.22   145.197985
#                     688819    44.04    45.64    43.95    45.15    45.026221
#                     688981    59.69    62.50    59.40    61.82    61.542000
#
#                                 volume  pct_chg  turnover  free_turnover  \
# timestamp           ticker
# 2015-01-06 09:30:00 1       2860436.43   1.1364    2.9079         5.7657
#                     2       6560835.70   7.2662    6.7834         8.1741
#                     4         28095.12   0.7707    3.3496         4.5343
#                     5             0.00   0.0000    0.0000         0.0000
#                     6       1078647.12   0.4255    8.0562        13.2751
# ...                                ...      ...       ...            ...
# 2021-07-01 09:30:00 688700    64336.83  14.5494   19.2222        19.2222
#                     688777    19001.61   4.6111    4.6288         4.6288
#                     688788    13572.56   5.1954    7.7977         7.7977
#                     688819    47249.01   1.8544    4.6754         4.6754
#                     688981   777950.53   4.3376    7.1003         7.1003
#
#                               5d_ret
# timestamp           ticker
# 2015-01-06 09:30:00 1      -0.075710
#                     2      -0.106164
#                     4       0.006390
#                     5       0.000000
#                     6      -0.078571
# ...                              ...
# 2021-07-01 09:30:00 688700  0.153171
#                     688777  0.053133
#                     688788 -0.102721
#                     688819  0.032164
#                     688981 -0.058075
#
# [5357761 rows x 10 columns]

# %%
import multiprocessing as mp
pool = mp.Pool(10)
t1 = time.time()
result = {}
def test(i):
    return DataAPI.get_stock_daily_return(date=i,ti =  0, tp = 0, price='close',period = "1d")
for i in tqdm(time_list):
    result[i]  = (pool.apply_async(test, args=(i,)))   #维持执行的进程总数为10，当一个进程执行完后启动一个新进程.
pool.close()
pool.join()
t2 = time.time()
print("并行执行时间：", int(t2 - t1))
# Out:
# 100%|██████████| 1580/1580 [00:00<00:00, 84974.62it/s]
# 并行执行时间： 4

# %%
target_df = []
for i in tqdm(result):
    target_df.append(result[i].get())
target_df = pd.concat(target_df,axis=0)
target_df
# Out:
# 100%|██████████| 1580/1580 [00:00<00:00, 87884.26it/s]
#                               1d_ret  trading_status
# timestamp           ticker
# 2015-01-06 09:30:00 000001 -0.018297               0
#                     000002 -0.023288               0
#                     000004  0.051118               0
#                     000005  0.000000               3
#                     000006 -0.028571               0
# ...                              ...             ...
# 2021-07-01 09:30:00 688700 -0.040395               0
#                     688777 -0.005927               0
#                     688788 -0.025238               0
#                     688819 -0.022042               0
#                     688981 -0.019086               0
#
# [5370219 rows x 2 columns]

# %%
target_df.reset_index(inplace=True)
target_df['ticker'] = target_df["ticker"].apply(lambda x: int(x))
target_df['timestamp'] = pd.to_datetime(target_df["timestamp"])
target_df.set_index(["timestamp","ticker"],inplace=True)
target_df = pd.DataFrame(target_df["1d_ret"])
target_df
# Out:
#                               1d_ret
# timestamp           ticker
# 2015-01-06 09:30:00 1      -0.018297
#                     2      -0.023288
#                     4       0.051118
#                     5       0.000000
#                     6      -0.028571
# ...                              ...
# 2021-07-01 09:30:00 688700 -0.040395
#                     688777 -0.005927
#                     688788 -0.025238
#                     688819 -0.022042
#                     688981 -0.019086
#
# [5370219 rows x 1 columns]

# %%
data = pd.merge(dataframe_list,target_df,left_index=True,right_index=True,how = "left")
data
# Out:
#                                open     high      low    close         vwap  \
# timestamp           ticker
# 2015-01-06 09:30:00 1       1136.15  1156.75  1108.44  1138.28  1134.052643
#                     2       1774.23  1885.20  1753.27  1838.34  1823.031224
#                     4         63.31    64.62    62.18    63.76    63.277989
#                     5         38.00    38.00    38.00    38.00    37.997172
#                     6        225.64   234.85   223.10   225.00   228.438278
# ...                             ...      ...      ...      ...          ...
# 2021-07-01 09:30:00 688700    47.80    54.50    47.03    53.38    50.715300
#                     688777    90.21    95.08    89.32    94.42    93.250464
#                     688788   138.07   149.35   137.11   146.22   145.197985
#                     688819    44.04    45.64    43.95    45.15    45.026221
#                     688981    59.69    62.50    59.40    61.82    61.542000
#
#                                 volume  pct_chg  turnover  free_turnover  \
# timestamp           ticker
# 2015-01-06 09:30:00 1       2860436.43   1.1364    2.9079         5.7657
#                     2       6560835.70   7.2662    6.7834         8.1741
#                     4         28095.12   0.7707    3.3496         4.5343
#                     5             0.00   0.0000    0.0000         0.0000
#                     6       1078647.12   0.4255    8.0562        13.2751
# ...                                ...      ...       ...            ...
# 2021-07-01 09:30:00 688700    64336.83  14.5494   19.2222        19.2222
#                     688777    19001.61   4.6111    4.6288         4.6288
#                     688788    13572.56   5.1954    7.7977         7.7977
#                     688819    47249.01   1.8544    4.6754         4.6754
#                     688981   777950.53   4.3376    7.1003         7.1003
#
#                               5d_ret    1d_ret
# timestamp           ticker
# 2015-01-06 09:30:00 1      -0.075710 -0.018297
#                     2      -0.106164 -0.023288
#                     4       0.006390  0.051118
#                     5       0.000000  0.000000
#                     6      -0.078571 -0.028571
# ...                              ...       ...
# 2021-07-01 09:30:00 688700  0.153171 -0.040395
#                     688777  0.053133 -0.005927
#                     688788 -0.102721 -0.025238
#                     688819  0.032164 -0.022042
#                     688981 -0.058075 -0.019086
#
# [5357761 rows x 11 columns]

# %%
data.drop("5d_ret",axis=1).to_csv(output_path + "data.csv")

# %% [markdown]
# # Original

# %%
dataframe_list = DataAPI.get_stock_prices(start_date=time_start, end_date=time_end,fq=True).reset_index().set_index(['timestamp','ticker'])
dataframe_list
# Out:
#                   pre_close     open    close     high      low         vwap  \
# timestamp ticker
# 20150105  000001    1125.49  1136.15  1138.28  1156.75  1108.44  1134.052643
#           000002    1713.82  1774.23  1838.34  1885.20  1753.27  1823.031224
#           000004      63.27    63.31    63.76    64.62    62.18    63.277989
#           000005      38.00    38.00    38.00    38.00    38.00    37.997172
#           000006     224.05   225.64   225.00   234.85   223.10   228.438278
# ...                     ...      ...      ...      ...      ...          ...
# 20210630  688700      46.60    47.80    53.38    54.50    47.03    50.715300
#           688777      90.26    90.21    94.42    95.08    89.32    93.250464
#           688788     138.99   138.07   146.22   149.35   137.11   145.197985
#           688819      44.32    44.04    45.15    45.64    43.95    45.026221
#           688981      59.25    59.69    61.82    62.50    59.40    61.542000
#
#                      chg  pct_chg      volume        amount  turnover  \
# timestamp ticker
# 20150105  000001   12.79   1.1364  2860436.43  4.565388e+06    2.9079
#           000002  124.52   7.2662  6560835.70  9.700712e+06    6.7834
#           000004    0.49   0.7707    28095.12  4.374656e+04    3.3496
#           000005    0.00   0.0000        0.00  0.000000e+00    0.0000
#           000006    0.95   0.4255  1078647.12  7.753464e+05    8.0562
# ...                  ...      ...         ...           ...       ...
# 20210630  688700    6.78  14.5494    64336.83  3.262860e+05   19.2222
#           688777    4.16   4.6111    19001.61  1.766767e+05    4.6288
#           688788    7.23   5.1954    13572.56  1.959448e+05    7.7977
#           688819    0.83   1.8544    47249.01  2.096566e+05    4.6754
#           688981    2.57   4.3376   777950.53  4.787665e+06    7.1003
#
#                   free_turnover   fq_factor   high_limit    low_limit  \
# timestamp ticker
# 20150105  000001         5.7657   71.053704  1237.755524  1013.225819
#           000002         8.1741  123.296083  1885.197109  1542.433998
#           000004         4.5343    4.063862    69.613956    56.934707
#           000005         0.0000    9.267603          NaN          NaN
#           000006        13.2751   31.780064   246.613297   201.803406
# ...                         ...         ...          ...          ...
# 20210630  688700        19.2222    1.000000    55.920000    37.280000
#           688777         4.6288    1.002911   108.314388    72.209592
#           688788         7.7977    1.005747   166.793082   111.195388
#           688819         4.6754    1.014728    53.192042    35.454596
#           688981         7.1003    1.000000    71.100000    47.400000
#
#                   trading_status
# timestamp ticker
# 20150105  000001            -1.0
#           000002            -1.0
#           000004            -1.0
#           000005             0.0
#           000006            -1.0
# ...                          ...
# 20210630  688700            -1.0
#           688777            -1.0
#           688788            -1.0
#           688819            -1.0
#           688981            -1.0
#
# [5357761 rows x 16 columns]

# %%
dataframe_list = dataframe_list[feat_list].reset_index()
time_df = pd.DataFrame(dataframe_list['timestamp'].drop_duplicates())
time_df['timestamp_shift'] = time_df['timestamp'].apply(lambda x : DataAPI.get_next_trading_day(x, output='datetime'))
dataframe_list = pd.merge(left = dataframe_list , right = time_df , how = 'left',on = 'timestamp')
dataframe_list.drop(['timestamp'],axis=1,inplace=True)
dataframe_list.rename(columns = {"timestamp_shift":"timestamp"},inplace=True)
dataframe_list['timestamp'] = pd.to_datetime(dataframe_list['timestamp']) + pd.Timedelta(hours=9,minutes = 30)
time_list = list(dataframe_list['timestamp'].drop_duplicates())
dataframe_list.set_index(['timestamp','ticker'],inplace = True)
dataframe_list
# Out:
#                                open     high      low    close         vwap  \
# timestamp           ticker
# 2015-01-06 09:30:00 000001  1136.15  1156.75  1108.44  1138.28  1134.052643
#                     000002  1774.23  1885.20  1753.27  1838.34  1823.031224
#                     000004    63.31    64.62    62.18    63.76    63.277989
#                     000005    38.00    38.00    38.00    38.00    37.997172
#                     000006   225.64   234.85   223.10   225.00   228.438278
# ...                             ...      ...      ...      ...          ...
# 2021-07-01 09:30:00 688700    47.80    54.50    47.03    53.38    50.715300
#                     688777    90.21    95.08    89.32    94.42    93.250464
#                     688788   138.07   149.35   137.11   146.22   145.197985
#                     688819    44.04    45.64    43.95    45.15    45.026221
#                     688981    59.69    62.50    59.40    61.82    61.542000
#
#                                 volume  pct_chg  turnover  free_turnover
# timestamp           ticker
# 2015-01-06 09:30:00 000001  2860436.43   1.1364    2.9079         5.7657
#                     000002  6560835.70   7.2662    6.7834         8.1741
#                     000004    28095.12   0.7707    3.3496         4.5343
#                     000005        0.00   0.0000    0.0000         0.0000
#                     000006  1078647.12   0.4255    8.0562        13.2751
# ...                                ...      ...       ...            ...
# 2021-07-01 09:30:00 688700    64336.83  14.5494   19.2222        19.2222
#                     688777    19001.61   4.6111    4.6288         4.6288
#                     688788    13572.56   5.1954    7.7977         7.7977
#                     688819    47249.01   1.8544    4.6754         4.6754
#                     688981   777950.53   4.3376    7.1003         7.1003
#
# [5357761 rows x 9 columns]

# %%
# time_df = pd.DataFrame(dataframe_list['timestamp'].drop_duplicates())
# time_df['timestamp_shift'] = time_df['timestamp'].apply(lambda x : DataAPI.get_next_trading_day(x, output='datetime'))
time_df
# Out:
#          timestamp timestamp_shift
# 0         20150105      2015-01-06
# 2588      20150106      2015-01-07
# 5176      20150107      2015-01-08
# 7764      20150108      2015-01-09
# 10352     20150109      2015-01-12
# ...            ...             ...
# 5335953   20210624      2021-06-25
# 5340309   20210625      2021-06-28
# 5344668   20210628      2021-06-29
# 5349030   20210629      2021-06-30
# 5353393   20210630      2021-07-01
#
# [1580 rows x 2 columns]

# %%
config_path = r'/home/ShareFolder/lgc/Modules/Research/config/feature_bt_template'
print('Loading the configuration from ' + config_path)
configs = namespace.load_namespace(config_path)
FT = FeatureAnalysis(configs, feature_path=r"/home/ShareFolder/factor_lib")
# Out:
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template
# Process ForkPoolWorker-131:
# Process ForkPoolWorker-102:
# Process ForkPoolWorker-124:
# Process ForkPoolWorker-135:
# Process ForkPoolWorker-128:
# Process ForkPoolWorker-142:
# Process ForkPoolWorker-136:
# Process ForkPoolWorker-140:
# Process ForkPoolWorker-134:
# Process ForkPoolWorker-93:
# Process ForkPoolWorker-126:
# Process ForkPoolWorker-123:
# Process ForkPoolWorker-139:
# Process ForkPoolWorker-104:
# Process ForkPoolWorker-137:
# Process ForkPoolWorker-101:
# Process ForkPoolWorker-94:
# Process ForkPoolWorker-122:
# Process ForkPoolWorker-133:
# Process ForkPoolWorker-141:
# Process ForkPoolWorker-92:
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-125:
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-86:
# Process ForkPoolWorker-83:
# Process ForkPoolWorker-107:
# Process ForkPoolWorker-129:
# Process ForkPoolWorker-95:
# Process ForkPoolWorker-88:
# Process ForkPoolWorker-105:
# Process ForkPoolWorker-138:
# Process ForkPoolWorker-108:
# Process ForkPoolWorker-99:
# Process ForkPoolWorker-87:
# Process ForkPoolWorker-144:
# Process ForkPoolWorker-143:
# Process ForkPoolWorker-127:
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-85:
# Process ForkPoolWorker-132:
# Process ForkPoolWorker-121:
# Process ForkPoolWorker-96:
# Process ForkPoolWorker-89:
# Traceback (most recent call last):
# Process ForkPoolWorker-74:
# Traceback (most recent call last):
# Process ForkPoolWorker-80:
# Process ForkPoolWorker-106:
# Process ForkPoolWorker-91:
# Process ForkPoolWorker-78:
# Process ForkPoolWorker-82:
# Process ForkPoolWorker-90:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-84:
# Process ForkPoolWorker-97:
# Traceback (most recent call last):
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-103:
# Process ForkPoolWorker-98:
# Process ForkPoolWorker-81:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-77:
# Process ForkPoolWorker-75:
# Process ForkPoolWorker-73:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-112:
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-79:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-119:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-116:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-117:
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-113:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-118:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-111:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-115:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-114:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
FT.load_feature_from_dataframe(dataframe_list,universe='Investable')
FT.load_return_data()
# Out:
# Loading Feature...: 100%|████████████████████████████████████████████████████████████████████████████████████████| 1580/1580 [00:04<00:00, 329.34it/s]
# Loading target...: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 1580/1580 [00:05<00:00, 313.15it/s]
# Merging feature and return...: 100%|█████████████████████████████████████████████████████████████████████████████| 1580/1580 [00:07<00:00, 215.63it/s]

# %%
data_info = FT.data_info

# %%
# Drop 掉不需要的return 列
df = pd.DataFrame()
return_list = feat_list.copy()
return_list.append(return_value)
for timestamp in tqdm(data_info.keys()):
    timestamp = pd.to_datetime(timestamp)
    one_data = data_info[timestamp][return_list].reset_index()
    one_data['timestamp'] = timestamp
    df = pd.concat([df,one_data],axis=0)
df.sort_values(by = ['timestamp','ticker'],inplace=True)
display(df)
# Out:
# 100%|██████████| 1580/1580 [05:06<00:00,  5.15it/s]
#       ticker  pre_close    open    high     low   close      vwap      volume  \
# 0     000001      15.84   15.99   16.28   15.60   16.02   15.9605  2860436.43
# 1     000002      13.90   14.39   15.29   14.22   14.91   14.7858  6560835.70
# 2     000004      15.57   15.58   15.90   15.30   15.69   15.5709    28095.12
# 3     000006       7.05    7.10    7.39    7.02    7.08    7.1881  1078647.12
# 4     000007      14.60   14.51   14.80   14.25   14.52   14.5105    28415.72
# ...      ...        ...     ...     ...     ...     ...       ...         ...
# 4024  688699     237.77  285.32  285.32  285.32  285.32  285.3200     1225.82
# 4025  688777      90.00   89.95   94.80   89.06   94.15   92.9798    19001.61
# 4026  688788     138.20  137.28  148.50  136.33  145.38  144.3683    13572.56
# 4027  688819      43.68   43.40   44.98   43.31   44.49   44.3727    47249.01
# 4028  688981      59.25   59.69   62.50   59.40   61.82   61.5420   777950.53
#
#       pct_chg  turnover  free_turnover    chg    5d_ret           timestamp
# 0      1.1364    2.9079         5.7657   0.18 -0.075710 2015-01-06 09:30:00
# 1      7.2662    6.7834         8.1741   1.01 -0.106164 2015-01-06 09:30:00
# 2      0.7707    3.3496         4.5343   0.12  0.006390 2015-01-06 09:30:00
# 3      0.4255    8.0562        13.2751   0.03 -0.078571 2015-01-06 09:30:00
# 4     -0.5479    1.3807         1.7538  -0.08 -0.004844 2015-01-06 09:30:00
# ...       ...       ...            ...    ...       ...                 ...
# 4024  19.9983    0.6940         0.6940  47.55 -0.024476 2021-07-01 09:30:00
# 4025   4.6111    4.6288         4.6288   4.15  0.053133 2021-07-01 09:30:00
# 4026   5.1954    7.7977         7.7977   7.18 -0.102721 2021-07-01 09:30:00
# 4027   1.8544    4.6754         4.6754   0.81  0.032164 2021-07-01 09:30:00
# 4028   4.3376    7.1003         7.1003   2.57 -0.058075 2021-07-01 09:30:00
#
# [4851238 rows x 14 columns]

# %%
df.set_index(['timestamp','ticker']).to_csv(output_path + 'data.csv')
print(output_path + 'data.csv')
