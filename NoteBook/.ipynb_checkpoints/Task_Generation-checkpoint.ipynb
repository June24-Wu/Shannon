# %%
Alpha_Name = "Original_Input_Moving_7_Shift_5"
sequence = 6
LR = [0.01,0.001,0.0001,0.00001]
epoch_num = [5,30,20,20]
feature_num = 108

# %%
import pandas as pd
original = pd.read_parquet("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.par")
original
# Out:
#                                Alpha_Name  sequence  \
# task_id
# 0        Original_Input_Moving_10_Shift_5         5
# 1        Original_Input_Moving_10_Shift_5         5
# 2        Original_Input_Moving_10_Shift_5         5
# 3        Original_Input_Moving_10_Shift_5         5
# 4        Original_Input_Moving_10_Shift_5         5
# 5         Original_Input_Moving_7_Shift_5         6
# 6         Original_Input_Moving_7_Shift_5         6
# 7         Original_Input_Moving_7_Shift_5         6
# 8         Original_Input_Moving_7_Shift_5         6
# 9         Original_Input_Moving_7_Shift_5         6
#
#                                    LR         epoch_num  feature_num  \
# task_id
# 0        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
# 1        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
# 2        [0.01, 0.001, 0.0001, 1e-05]  [10, 30, 30, 30]          108
# 3        [0.01, 0.001, 0.0001, 1e-05]  [10, 30, 30, 30]          108
# 4        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
# 5        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
# 6        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
# 7        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
# 8        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
# 9        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]          108
#
#          start_date    end_date    status
# task_id
# 0        2019-01-01  2019-06-01  finished
# 1        2019-06-01  2020-01-01   waiting
# 2        2020-01-01  2020-06-01  finished
# 3        2020-06-01  2021-01-01  finished
# 4        2021-01-01  2021-06-01   waiting
# 5        2019-01-01  2019-06-01   waiting
# 6        2019-06-01  2020-01-01   waiting
# 7        2020-01-01  2020-06-01   waiting
# 8        2020-06-01  2021-01-01   waiting
# 9        2021-01-01  2021-06-01   waiting

# %%
original.loc[:,"LR"] = []
# Out:
# task_id
# 0    [0.01, 0.001, 0.0001, 1e-05]
# 1    [0.01, 0.001, 0.0001, 1e-05]
# 2    [0.01, 0.001, 0.0001, 1e-05]
# 3    [0.01, 0.001, 0.0001, 1e-05]
# 4    [0.01, 0.001, 0.0001, 1e-05]
# 5    [0.01, 0.001, 0.0001, 1e-05]
# 6    [0.01, 0.001, 0.0001, 1e-05]
# 7    [0.01, 0.001, 0.0001, 1e-05]
# 8    [0.01, 0.001, 0.0001, 1e-05]
# 9    [0.01, 0.001, 0.0001, 1e-05]
# Name: LR, dtype: object

# %%
time_list = ["2019-01-01","2019-06-01","2020-01-01","2020-06-01","2021-01-01","2021-06-01"]
time_list2 = []
for i in range(len(time_list)-1):
    time_list2.append([time_list[i],time_list[i+1]])
time_list2 = pd.DataFrame(time_list2,columns=["start_date","end_date"])
time_list2
# Out:
#    start_date    end_date
# 0  2019-01-01  2019-06-01
# 1  2019-06-01  2020-01-01
# 2  2020-01-01  2020-06-01
# 3  2020-06-01  2021-01-01
# 4  2021-01-01  2021-06-01

# %%
task = pd.DataFrame([Alpha_Name,sequence,LR,epoch_num,feature_num],index=["Alpha_Name","sequence","LR","epoch_num","feature_num"]).T
task['value']=1
time_list2['value']=1
task = pd.merge(task,time_list2,how='left',on='value')
del task['value']
task["status"] = "waiting"
task
# Out:
#                         Alpha_Name sequence                            LR  \
# 0  Original_Input_Moving_7_Shift_5        6  [0.01, 0.001, 0.0001, 1e-05]
# 1  Original_Input_Moving_7_Shift_5        6  [0.01, 0.001, 0.0001, 1e-05]
# 2  Original_Input_Moving_7_Shift_5        6  [0.01, 0.001, 0.0001, 1e-05]
# 3  Original_Input_Moving_7_Shift_5        6  [0.01, 0.001, 0.0001, 1e-05]
# 4  Original_Input_Moving_7_Shift_5        6  [0.01, 0.001, 0.0001, 1e-05]
#
#          epoch_num feature_num  start_date    end_date   status
# 0  [5, 30, 20, 20]         108  2019-01-01  2019-06-01  waiting
# 1  [5, 30, 20, 20]         108  2019-06-01  2020-01-01  waiting
# 2  [5, 30, 20, 20]         108  2020-01-01  2020-06-01  waiting
# 3  [5, 30, 20, 20]         108  2020-06-01  2021-01-01  waiting
# 4  [5, 30, 20, 20]         108  2021-01-01  2021-06-01  waiting

# %%
task = pd.concat([original,task],axis=0)
task.reset_index(drop=True,inplace=True)
task.index.names = ["task_id"]
# if task.duplicated().any() == True:
#     task = original
#     raise ValueError("concains duplicates value")
task
# Out:
#                                Alpha_Name sequence  \
# task_id
# 0        Original_Input_Moving_10_Shift_5        6
# 1        Original_Input_Moving_10_Shift_5        6
# 2        Original_Input_Moving_10_Shift_5        6
# 3        Original_Input_Moving_10_Shift_5        6
# 4        Original_Input_Moving_10_Shift_5        6
# 5         Original_Input_Moving_7_Shift_5        6
# 6         Original_Input_Moving_7_Shift_5        6
# 7         Original_Input_Moving_7_Shift_5        6
# 8         Original_Input_Moving_7_Shift_5        6
# 9         Original_Input_Moving_7_Shift_5        6
#
#                                    LR         epoch_num feature_num  \
# task_id
# 0        [0.01, 0.001, 0.0001, 1e-05]  [10, 30, 30, 30]         108
# 1        [0.01, 0.001, 0.0001, 1e-05]  [10, 30, 30, 30]         108
# 2        [0.01, 0.001, 0.0001, 1e-05]  [10, 30, 30, 30]         108
# 3        [0.01, 0.001, 0.0001, 1e-05]  [10, 30, 30, 30]         108
# 4        [0.01, 0.001, 0.0001, 1e-05]  [10, 30, 30, 30]         108
# 5        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]         108
# 6        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]         108
# 7        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]         108
# 8        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]         108
# 9        [0.01, 0.001, 0.0001, 1e-05]   [5, 30, 20, 20]         108
#
#          start_date    end_date    status
# task_id
# 0        2019-01-01  2019-06-01   waiting
# 1        2019-06-01  2020-01-01   waiting
# 2        2020-01-01  2020-06-01  finished
# 3        2020-06-01  2021-01-01  finished
# 4        2021-01-01  2021-06-01   waiting
# 5        2019-01-01  2019-06-01   waiting
# 6        2019-06-01  2020-01-01   waiting
# 7        2020-01-01  2020-06-01   waiting
# 8        2020-06-01  2021-01-01   waiting
# 9        2021-01-01  2021-06-01   waiting

# %%
task.to_parquet("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.par")
