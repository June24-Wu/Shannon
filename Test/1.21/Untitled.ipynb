# %%
import os
import pandas as pd

# %%
path = "/home/wuwenjun/labeled_data/5d/20210331/"
result = []
for i in os.listdir(path):
    result.append(pd.read_parquet(path + i))
result = pd.concat(result,axis=0)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e8e473af4331> in <module>
#       4     result.append(pd.read_parquet(path + i))
#       5 result = pd.concat(result,axis=0)
# ----> 6 resultu
#
# NameError: name 'resultu' is not defined

# %%
result = result[["timestamp","ticker","target"]]

# %%
result.rename(columns={"ticker":"symbol","target":"5d_ret_standscalar"},inplace=True)
result
# Out:
# /home/wuwenjun/venv-jupyter/lib/python3.7/site-packages/pandas/core/frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                timestamp  symbol  5d_ret_standscalar
# 0    2016-04-01 09:30:00  000534            0.125504
# 1    2016-04-01 09:30:00  300228           -0.342601
# 2    2016-04-01 09:30:00  300211            0.617759
# 3    2016-04-01 09:30:00  002114           -0.609251
# 4    2016-04-01 09:30:00  002225           -1.470060
# ...                  ...     ...                 ...
# 3794 2021-06-30 09:30:00  300763           -0.765400
# 3795 2021-06-30 09:30:00  002371            0.524779
# 3796 2021-06-30 09:30:00  600887           -0.970965
# 3797 2021-06-30 09:30:00  300751           -1.168265
# 3798 2021-06-30 09:30:00  600570           -1.124150
# ...

# %%
import shutil
shutil.rmtree("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Data_lib/Original_Input_Moving_10_Shift_5")

# %%
a = pd.DataFrame(np.random.randn(500,1000))

# %%
sys.getsizeof(a)
# Out:
# 4000160

# %%
sys.getsizeof(a)
# Out:
# 2000160

# %%
sys.path.append("/home/wuwenjun/jupyter_code/Shannon/AlphaNet/packages/")
import AlphaNet
from AlphaNet.Data import DataLoader
from AlphaNet.Models import AlphaNet_LSTM_V1
trainloader = DataLoader()
trainloader.load_data_from_file(alpha_name = "AlphaNet_Moving5_Shift_5_Sequence_6",end_date = "2017-01-01",data_path="/home/ShareFolder/feature_platform/ti0/wuwenjun/#Data_lib/")
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template
# 100%|██████████| 488/488 [00:26<00:00, 18.66it/s]
#                             COV_open_high_5_Shift_25  COV_open_low_5_Shift_25  \
# timestamp           ticker
# 2016-02-22 09:30:00 000001                604.216220               200.440200
#                     000004                240.270705               208.624930
#                     000005                 21.078035                24.917410
#                     000006                495.636480               359.511040
#                     000008                128.417215               193.401615
# ...                                              ...                      ...
# 2016-12-30 09:30:00 603993                 -0.011915                -0.004180
#                     603996                  0.837850                 0.821825
# ...

# %%
grouped.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-2003edc990e3> in <module>
# ----> 1 grouped.key
#
# ~/venv-jupyter/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     751
#     752         raise AttributeError(
# --> 753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#     755
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'key'
