# %%
import time
import datetime
import os
from Research.backtest.bt import BTDaily
import matplotlib.pyplot as plt
from Research.feature.ft import FeatureAnalysis
import Research.utils.namespace as namespace
import Research.utils.normalization as norm
from Platform.database.mysql import MysqlAPI
from Platform.utils.persistence import convert_to_standard_daily_feature_csv, convert_to_standard_daily_feature_par
from Platform.config.mysql_info import FACTOR_LIB_MYSQL_TIO
import DataAPI
from os import walk
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from progressbar import ProgressBar
from tqdm import tqdm
import multiprocessing as mp
import sys
sys.path.append("/home/wuwenjun/jupyter_code/Shannon/AlphaNet/packages/")
import AlphaNet
from AlphaNet.Data import concat_original_data , generate_shift_data
# Out:
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template

# %%
task_info = np.load("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",allow_pickle=True).item()
task_info["Task"]
# Out:
#                                                 Alpha_Name sequence  \
# task_id
# 0                         Original_Input_Moving_10_Shift_5        5
# 1                         Original_Input_Moving_10_Shift_5        5
# 2                         Original_Input_Moving_10_Shift_5        5
# 3                         Original_Input_Moving_10_Shift_5        5
# 4                         Original_Input_Moving_10_Shift_5        5
# ...                                                    ...      ...
# 195      AlphaNet_8Input_corr_filter_Shift_1_Sequence_2...       20
# 196      AlphaNet_8Input_corr_filter_Shift_1_Sequence_2...       20
# 197      AlphaNet_8Input_corr_filter_Shift_1_Sequence_2...       20
# 198      AlphaNet_8Input_corr_filter_Shift_1_Sequence_2...       20
# 199      AlphaNet_8Input_corr_filter_Shift_1_Sequence_2...       20
#
#                       LR epoch_num feature_num  start_date    end_date  \
# task_id
# 0        [0.001, 0.0001]  [30, 20]         108  2019-01-01  2019-06-01
# 1        [0.001, 0.0001]  [30, 20]         108  2019-06-01  2020-01-01
# 2        [0.001, 0.0001]  [30, 20]         108  2020-01-01  2020-06-01
# 3        [0.001, 0.0001]  [30, 20]         108  2020-06-01  2021-01-01
# 4        [0.001, 0.0001]  [30, 20]         108  2021-01-01  2021-06-01
# ...                  ...       ...         ...         ...         ...
# 195       [0.001, 1e-05]  [30, 30]          54  2019-01-01  2019-06-01
# 196       [0.001, 1e-05]  [30, 30]          54  2019-06-01  2020-01-01
# 197       [0.001, 1e-05]  [30, 30]          54  2020-01-01  2020-06-01
# 198       [0.001, 1e-05]  [30, 30]          54  2020-06-01  2021-01-01
# 199       [0.001, 1e-05]  [30, 30]          54  2021-01-01  2021-06-01
#
#                               status  \
# task_id
# 0                           finished
# 1                           finished
# 2                           finished
# 3                           finished
# 4                           finished
# ...                              ...
# 195      Finish: 19:31_01:39 | 01-31
# 196      Finish: 19:32_02:24 | 01-31
# 197      Finish: 19:33_02:57 | 01-31
# 198      Finish: 19:34_02:16 | 01-31
# 199      Finish: 19:35_02:51 | 01-31
#
#                                                description
# task_id
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 195      {'target': '10dRet', 'alpha_name': 'AlphaNet_8...
# 196      {'target': '10dRet', 'alpha_name': 'AlphaNet_8...
# 197      {'target': '10dRet', 'alpha_name': 'AlphaNet_8...
# 198      {'target': '10dRet', 'alpha_name': 'AlphaNet_8...
# 199      {'target': '10dRet', 'alpha_name': 'AlphaNet_8...
#
# [200 rows x 9 columns]

# %%
alpha_list10 = task_info["Task"].loc[199,"description"]["alpha_list"]

# %%
alpha_list = [i.replace("10","20") for i in alpha_list10]
alpha_list
# Out:
# ['COV_div_open_close_div_high_close_20',
#  'COV_div_open_close_div_low_close_20',
#  'COV_div_open_close_close_20',
#  'COV_div_open_close_volume_sqrt_20',
#  'COV_div_open_close_pct_chg_20',
#  'COV_div_high_close_div_low_close_20',
#  'COV_div_high_close_close_20',
#  'COV_div_high_close_volume_sqrt_20',
#  'COV_div_high_close_pct_chg_20',
#  'COV_div_low_close_close_20',
#  'COV_div_low_close_volume_sqrt_20',
#  'COV_close_div_vwap_close_20',
#  'COV_close_volume_sqrt_20',
#  'COV_close_pct_chg_20',
#  'COV_div_vwap_close_volume_sqrt_20',
#  'COV_volume_sqrt_pct_chg_20',
#  'COV_volume_sqrt_turnover_20',
#  'CORR_div_open_close_div_high_close_20',
#  'CORR_div_open_close_div_low_close_20',
#  'CORR_div_open_close_close_20',
#  'CORR_div_open_close_div_vwap_close_20',
#  'CORR_div_open_close_pct_chg_20',
#  'CORR_div_high_close_div_low_close_20',
#  'CORR_div_high_close_close_20',
#  'CORR_div_high_close_div_vwap_close_20',
#  'CORR_div_high_close_pct_chg_20',
#  'CORR_div_low_close_close_20',
#  'CORR_div_low_close_div_vwap_close_20',
#  'CORR_div_low_close_volume_sqrt_20',
#  'CORR_div_low_close_pct_chg_20',
#  'CORR_close_div_vwap_close_20',
#  'CORR_close_volume_sqrt_20',
#  'CORR_close_pct_chg_20',
#  'CORR_div_vwap_close_pct_chg_20',
#  'CORR_volume_sqrt_turnover_20',
#  'STD_close_20',
#  'STD_div_vwap_close_20',
#  'STD_volume_sqrt_20',
#  'ZSCORE_div_open_close_20',
#  'ZSCORE_div_high_close_20',
#  'ZSCORE_div_low_close_20',
#  'ZSCORE_close_20',
#  'ZSCORE_div_vwap_close_20',
#  'ZSCORE_volume_sqrt_20',
#  'ZSCORE_pct_chg_20',
#  'RETURN_div_open_close_20',
#  'RETURN_div_high_close_20',
#  'RETURN_div_low_close_20',
#  'RETURN_div_vwap_close_20',
#  'RETURN_volume_sqrt_20',
#  'RETURN_pct_chg_20',
#  'DECAY_div_high_close_20',
#  'DECAY_div_low_close_20',
#  'DECAY_turnover_20']

# %%
target = None
alpha_name = "AlphaNet_8Input_corr_filter_20dMoving"
shift = 1
sequence = 20
LR = [0.001,0.00001,0.0000001]
epoch_num = [30,30,30]

# %%
# read_task
output_path = "/home/wuwenjun/Data/"

concat_original_data(alpha_name=alpha_name,alpha_list=alpha_list,output_path=output_path,universe = universe)
generate_shift_data(alpha_name=alpha_name,shift=shift,sequence=sequence,target=target,data_path=output_path)
