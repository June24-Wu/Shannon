# 100418  29.053336  18.296711  16.472976 -1.629470
# 100419  27.836593  17.372520  15.686615 -0.879622
#
# [100420 rows x 327 columns]

# %%
import DataAPI
import datetime
def convert_to_standard_daily_data_par(df: pd.DataFrame, output_name: str,  output_path: str):
    grouped = df.groupby('timestamp')
    for date, group in grouped:
        date_format = pd.to_datetime(date).date()
        assert DataAPI.is_trading_day(date), f"{date} is not a trading date!"
        file_name = datetime.date.strftime(date_format, '%Y%m%d') + '.par'
        folder = os.path.join(output_path, output_name, str(date_format.year))
        if not os.path.exists(folder):
            os.makedirs(folder)
        file = os.path.join(folder, file_name)
        group.to_parquet(file)
    return None
def convert_to_standard_daily_data_csv(df: pd.DataFrame, output_name: str,  output_path: str):
    grouped = df.groupby('timestamp')
    for date, group in grouped:
        date_format = pd.to_datetime(date).date()
        assert DataAPI.is_trading_day(date), f"{date} is not a trading date!"
        file_name = datetime.date.strftime(date_format, '%Y%m%d') + '.csv'
        folder = os.path.join(output_path, output_name, str(date_format.year))
        if not os.path.exists(folder):
            os.makedirs(folder)
        file = os.path.join(folder, file_name)
        group.to_csv(file, sep=',', mode='w', header=False, encoding='utf-8')
    return None
class DataLoader(object):
    def __init__(self, model, device=None):
        self.feature_data = None
        self.target = None
        self.length = None
        self.y = None
    def load_data_from_file(data_path,end_date,start_date = "2015-01-01"):
        time_list  = DataAPI.get_trading_days(start_date,end_date)
        final = []
        for date in time_list:
            date = data_path + str(date.year) + '/' + str(date.year) + str(date.month).zfill(2) + str(date.day).zfill(2) + ".par"
            if (os.path.exists(date)):
                final.append(pd.read_parquet(date))
        self.feature_data = pd.concat(final,axis=0)
        self.length = self.feature_data.shape[0]
        return self.feature_data
    
    def to_torch_DataLoader(sequence,shuffle,batch_size = 1024,num_workers = 16):
        self.target = pd.DataFrame(self.feature_data["target"])
        self.feature_data.drop("target",axis=1,inplace=True)
        self.feture_data.set_index(["timestamp","ticker"],inplace=True)
        x = torch.from_numpy(np.array(self.feture_data).reshape(self.length,-1,sequence))
        y = torch.from_numpy(np.array(self.target).reshape(-1,1))
        self.feature_data = torch.utils.data.TensorDataset(x, y)
        self.feature_data = torch.utils.data.DataLoader(
            dataset=self.feature_data,
            batch_size=batch_size,
            shuffle=shuffle,
            num_workers=num_workers,
            pin_memory=True
        )
        return self.feature_data

# %%
config_path = r'/home/ShareFolder/lgc/Modules/Research/config/feature_bt_template'
print('Loading the configuration from ' + config_path)
configs = namespace.load_namespace(config_path)
FT = FeatureAnalysis(configs, feature_path=r"/home/ShareFolder/feature_platform")
alpha_list = list(FT.features_in_path.keys())[:]
alpha_list = ['ewmCorr(high,low,7)','ewmCov(open,high,7)']
print(alpha_list)
start_date = '2015-01-01'
end_date = '2022-01-01'
FT.load_feature_from_file(alpha_list, start_date, end_date, universe='Investable',
                                       timedelta=None, transformer=norm.standard_scale)
# Out:
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template
# Loading Feature...:   4%|███▊                                                                                     | 147/3410 [00:00<00:03, 996.06it/s]
# ['ewmCorr(high,low,7)', 'ewmCov(open,high,7)']
# Loading Feature...: 100%|████████████████████████████████████████████████████████████████████████████████████████| 3410/3410 [00:06<00:00, 527.47it/s]
# (                            ewmCorr(high,low,7)  ewmCov(open,high,7)
#  timestamp           ticker
#  2016-01-05 09:30:00 002269             0.261552            -0.020979
#                      000629             0.261552            -0.020978
#                      603022             0.261552            -0.020970
#                      600617             0.261552            -0.020860
#                      002684             0.261552            -0.020868
#  ...                                         ...                  ...
#  2021-07-01 09:30:00 300230            -4.442220            -0.037525
#                      002319            -4.504204            -0.036942
#                      603286            -4.533666            -0.037445
#                      000796            -4.536809            -0.033297
#                      002707            -4.536859            -0.020746
#
#  [4444115 rows x 2 columns],
#  None)
# Process ForkPoolWorker-142:
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-81:
# Process ForkPoolWorker-133:
# Process ForkPoolWorker-121:
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-73:
# Process ForkPoolWorker-85:
# Process ForkPoolWorker-139:
# Process ForkPoolWorker-143:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-132:
# Process ForkPoolWorker-79:
# Process ForkPoolWorker-136:
# Process ForkPoolWorker-140:
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-135:
# Traceback (most recent call last):
# Process ForkPoolWorker-91:
# Process ForkPoolWorker-104:
# Process ForkPoolWorker-123:
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-118:
# Process ForkPoolWorker-144:
# Process ForkPoolWorker-138:
# Process ForkPoolWorker-131:
# Process ForkPoolWorker-119:
# Process ForkPoolWorker-114:
# Process ForkPoolWorker-127:
# Process ForkPoolWorker-108:
# Process ForkPoolWorker-115:
# Process ForkPoolWorker-87:
# Process ForkPoolWorker-89:
# Process ForkPoolWorker-129:
# Process ForkPoolWorker-94:
# Process ForkPoolWorker-107:
# Process ForkPoolWorker-128:
# Process ForkPoolWorker-77:
# Process ForkPoolWorker-90:
# Process ForkPoolWorker-83:
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-101:
# Process ForkPoolWorker-111:
# Process ForkPoolWorker-103:
# Process ForkPoolWorker-98:
# Process ForkPoolWorker-125:
# Process ForkPoolWorker-112:
# Process ForkPoolWorker-134:
# Process ForkPoolWorker-102:
# Process ForkPoolWorker-105:
# Process ForkPoolWorker-75:
# Process ForkPoolWorker-141:
# Process ForkPoolWorker-96:
# Process ForkPoolWorker-106:
# Process ForkPoolWorker-92:
# Process ForkPoolWorker-88:
# Process ForkPoolWorker-122:
# Process ForkPoolWorker-95:
# Process ForkPoolWorker-80:
# Process ForkPoolWorker-137:
# Process ForkPoolWorker-86:
# Process ForkPoolWorker-84:
# Process ForkPoolWorker-126:
# Process ForkPoolWorker-78:
# Process ForkPoolWorker-124:
# Process ForkPoolWorker-97:
# Process ForkPoolWorker-116:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-82:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process ForkPoolWorker-93:
# Process ForkPoolWorker-113:
# Process ForkPoolWorker-99:
# Process ForkPoolWorker-74:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()

# %%
data = FT.feature_data
data
# Out:
#                             ewmCorr(high,low,7)  ewmCov(open,high,7)
# timestamp           ticker
# 2016-01-05 09:30:00 002269             0.261552            -0.020979
#                     000629             0.261552            -0.020978
#                     603022             0.261552            -0.020970
#                     600617             0.261552            -0.020860
#                     002684             0.261552            -0.020868
# ...                                         ...                  ...
# 2021-07-01 09:30:00 300230            -4.442220            -0.037525
#                     002319            -4.504204            -0.036942
#                     603286            -4.533666            -0.037445
#                     000796            -4.536809            -0.033297
#                     002707            -4.536859            -0.020746
#
# [4444115 rows x 2 columns]

# %%
from AlphaNet import Data
output_path = r'/home/wuwenjun/feature_platform/ti0/wuwenjun'
for i in data.columns:
    one_data = pd.DataFrame(data[i]).unstack()
    display(one_data)
    mean = one_data.rolling(30).mean()
    std = one_data.rolling(30).std()
    one_data = ((one_data- mean) /std ).stack()
    one_data.columns = one_data.columns + "_time_series_norm"
    display(one_data)
    Data.convert_to_standard_daily_data_csv(one_data, one_data.columns.to_list()[0], output_path)
# Out:
#                     ewmCorr(high,low,7)                                \
# ticker                           000001    000002    000004    000005
# timestamp
# 2016-01-05 09:30:00            0.261552       NaN  0.261552  0.261552
# 2016-01-06 09:30:00           -1.179235       NaN  0.316584  0.284800
# 2016-01-07 09:30:00           -2.138963       NaN  0.642144 -1.280154
# 2016-01-08 09:30:00           -0.645846       NaN  0.714015 -1.198864
# 2016-01-11 09:30:00           -0.464023       NaN  0.507512  0.350756
# ...                                 ...       ...       ...       ...
# 2021-06-25 09:30:00           -0.220448  0.753203  0.030204       NaN
# 2021-06-28 09:30:00            0.726565 -1.291454  0.791397       NaN
columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-02-22 09:30:00 000001                             -1.445096
#                     000004                             -1.384286
#                     000005                             -1.366422
#                     000006                             -1.369831
#                     000008                             -1.395631
# ...                                                          ...
# 2021-07-01 09:30:00 688699                              4.678937
#                     688777                             -0.031998
#                     688788                              0.089871
#                     688819                              0.122882
#                     688981                              0.134982
#
# [4276422 rows x 1 columns]

# %%
pd.read_csv("/home/wuwenjun/feature_platform/ti0/wuwenjun/ewmCorr(high,low,7)_time_series_norm/2016/20160222.csv")
# Out:
#       1.0590501503059537
# 0               1.257447
# 1               1.462050
# 2               0.501282
# 3               0.719404
# 4              -3.435658
# ...                  ...
# 2446            1.185510
# 2447            0.863773
# 2448           -1.548593
# 2449            0.043542
# 2450           -1.473352
#
# [2451 rows x 1 columns]

# %%
grouped = one_data.groupby('timestamp')

# %%
for date, group in grouped:
#     date_format = pd.to_datetime(date).date()
    display(group)
#     assert DataAPI.is_trading_day(date), f"{date} is not a trading date!"
#     file_name = datetime.date.strftime(date_format, '%Y%m%d') + '.csv'
#     folder = os.path.join(output_path, output_name, str(date_format.year))
#     if not os.path.exists(folder):
#         os.makedirs(folder)
#     file = os.path.join(folder, file_name)
#     group.to_csv(file, sep=',', mode='w', header=False, encoding='utf-8')
# return None
# Out:
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-02-22 09:30:00 000001                             -1.445096
#                     000004                             -1.384286
#                     000005                             -1.366422
#                     000006                             -1.369831
#                     000008                             -1.395631
# ...                                                          ...
#                     603988                             -1.361174
#                     603989                             -1.362920
#                     603993                             -1.362880
#                     603997                             -1.362943
#                     603998                             -1.364502
#
# [2460 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-02-23 09:30:00 000001                             -0.770037
#                     000004                             -0.751203
#                     000005                             -0.725627
#                     000006                             -0.787299
#                     000008                             -0.751950
# ...                                                          ...
#                     603988                             -0.738824
#                     603989                             -0.733289
#                     603993                             -0.737755
#                     603997                             -0.737883
#                     603998                             -0.738624
#
# [2478 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-02-24 09:30:00 000001                              4.706177
#                     000004                              4.615146
#                     000005                              4.612721
#                     000006                              4.631608
#                     000008                              4.635872
# ...                                                          ...
#                     603988                              4.607335
#                     603989                              4.609587
#                     603993                              4.607631
#                     603997                              4.607791
#                     603998                              4.608889
#
# [2485 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-02-25 09:30:00 000001                              2.921405
#                     000004                              2.887916
#                     000005                              2.886024
#                     000006                              2.882222
#                     000008                              2.891306
# ...                                                          ...
#                     603988                              2.886173
#                     603989                              2.884122
#                     603993                              2.885560
#                     603997                              2.885585
#                     603998                              2.885585
#
# [2490 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-02-26 09:30:00 000001                              3.029739
#                     000004                              3.022325
#                     000005                              3.025234
#                     000006                              3.034197
#                     000008                              3.024210
# ...                                                          ...
#                     603988                              3.019806
#                     603989                              3.018039
#                     603993                              3.019129
#                     603997                              3.019022
#                     603998                              3.019738
#
# [2498 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-02-29 09:30:00 000001                             -0.449245
#                     000004                             -0.454779
#                     000005                             -0.456141
#                     000006                             -0.444850
#                     000008                             -0.454102
# ...                                                          ...
#                     603988                             -0.453810
#                     603989                             -0.453910
#                     603993                             -0.454052
#                     603997                             -0.454220
#                     603998                             -0.453870
#
# [2506 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-03-01 09:30:00 000001                             -0.280753
#                     000004                             -0.258927
#                     000005                             -0.255449
#                     000006                             -0.266105
#                     000008                             -0.261004
# ...                                                          ...
#                     603988                             -0.255098
#                     603989                             -0.255119
#                     603993                             -0.254856
#                     603997                             -0.254852
#                     603998                             -0.255113
#
# [2508 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-03
rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-14 09:30:00 000001                              1.265660
#                     000004                              0.992529
#                     000005                              0.943208
#                     000006                              0.898417
#                     000008                              0.847914
# ...                                                          ...
#                     603988                              0.942589
#                     603989                              0.942731
#                     603993                              0.943481
#                     603997                              0.942199
#                     603998                              0.958003
#
# [2590 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-15 09:30:00 000001                              0.321397
#                     000004                              0.381076
#                     000005                              0.392995
#                     000006                              0.326176
#                     000008                              0.371092
# ...                                                          ...
#                     603988                              0.392405
#                     603989                              0.394704
#                     603993                              0.395035
#                     603997                              0.392989
#                     603998                              0.390306
#
# [2592 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-18 09:30:00 000001                              2.593531
#                     000004                              2.630810
#                     000005                              2.634572
#                     000006                              2.650505
#                     000008                              2.641965
# ...                                                          ...
#                     603988                              2.632737
#                     603989                              2.639577
#                     603993                              2.635059
#                     603997                              2.632750
#                     603998                              2.630222
#
# [2591 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-19 09:30:00 000001                              2.467621
#                     000004                              2.518621
#                     000005                              2.513083
#                     000006                              2.485162
#                     000008                              2.519908
# ...                                                          ...
#                     603988                              2.553297
#                     603989                              2.511281
#                     603993                              2.512223
#                     603997                              2.511466
#                     603998                              2.510788
#
# [2596 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-20 09:30:00 000001                              1.220380
#                     000004                              1.240847
#                     000005                              1.242402
#                     000006                              1.199041
#                     000008                              1.229306
# ...                                                          ...
#                     603989                              1.241872
#                     603993                              1.242883
#                     603997                              1.241937
#                     603998                              1.241093
#                     603999                              1.242392
#
# [2597 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-21 09:30:00 000001                              0.131047
#                     000004                              0.169733
#                     000005                              0.144896
#                     000006                              0.073535
#                     000008                              0.120268
# ...                                                          ...
#                     603989                              0.145539
#                     603993                              0.146062
#                     603997                              0.145000
#                     603998                              0.161560
#                     603999                              0.146426
#
# [2598 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-22 09:30:00 000001                             -0.525391
#                     000004                             -0.508171
#                     000005                             -0.494724
#                     000006                             -0.514066
#                     000008                             -0.522464
# ...                                                          ...
#                     603989                             -0.494552
#                     603993                             -0.494459
#                     603997                             -0.495775
#                     603998                             -0.497094
#                     603999                             -0.494449
#
# [2599 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-25 09:30:00 000001                             -0.614634
#                     000004                             -0.598045
#                     000005                             -0.585682
#                     000006                             -0.596411
#                     000008                             -0.607157
# ...                                                          ...
#                     603989                             -0.585459
#                     603993                             -0.585519
#                     603997                             -0.586901
#                     603998                             -0.588368
#                     603999                             -0.585493
#
# [2602 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-26 09:30:00 000001                             -0.679613
#                     000004                             -0.654605
#                     000005                             -0.645357
#                     000006                             -0.646881
#                     000008                             -0.665488
# ...                                                          ...
#                     603989                             -0.645100
#                     603993                             -0.645100
#                     603997                             -0.646460
#                     603998                             -0.648082
#                     603999                             -0.645105
#
# [2601 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-27 09:30:00 000001                             -0.905827
#                     000004                             -0.877297
#                     000005                             -0.873169
#                     000006                             -0.876499
#                     000008                             -0.895205
# ...                                                          ...
#                     603989                             -0.872724
#                     603993                             -0.872657
#                     603997                             -0.873852
#                     603998                             -0.875956
#                     603999                             -0.872648
#
# [2601 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-28 09:30:00 000001                             -1.100666
#                     000004                             -1.071818
#                     000005                             -1.079769
#                     000006                             -1.084061
#                     000008                             -1.027526
# ...                                                          ...
#                     603989                             -1.078834
#                     603993                             -1.079398
#                     603997                             -1.080512
#                     603998                             -1.082110
#                     603999                             -1.078920
#
# [2602 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-04-29 09:30:00 000001                             -0.691673
#                     000004                             -0.700472
#                     000005                             -0.729931
#                     000006                             -0.731316
#                     000008                             -0.694264
# ...                                                          ...
#                     603989                             -0.727010
#                     603993                             -0.729465
#                     603997                             -0.730493
#                     603998                             -0.732263
#                     603999                             -0.729569
#
# [2602 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-05-03 09:30:00 000001                              0.335963
#                     000004                              0.422466
#                     000005                              0.426325
#                     000006                              0.426619
#                     000008                              0.411239
# ...                                                          ...
#                     603993                              0.426329
#                     603996                              0.427451
#                     603997                              0.424620
#                     603998                              0.418148
#                     603999                              0.425505
#
# [2599 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-05-04 09:30:00 000001                              0.377140
#                     000004                              0.569879
#                     000005                              0.525925
#                     000006                              0.523576
#                     000008                              0.513531
# ...                                                          ...
#                     603993                              0.527343
#                     603996                              0.526857
#                     603997                              0.525683
#                     603998                              0.562364
#                     603999                              0.525849
#
# [2595 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-05-05 09:30:00 000001                             -1.468507
#                     000004                             -1.466746
#                     000005                             -1.517261
#                     000006                             -1.514449
#                     000008                             -1.535348
# ...                                                          ...
#                     603993                             -1.524799
#                     603996                             -1.512234
#                     603997                             -1.524204
#                     603998                             -1.459048
#                     603999                             -1.517338
#
# [2595 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-05-06 09:30:00 000001                             -0.097084
#                     000004                             -0.050712
#                     000005                             -0.062539
#                     000006                             -0.071036
#                     000008                             -0.065585
# ...                                                          ...
#                     603993                             -0.062306
#                     603996                             -0.061308
#                     603997                             -0.063717
#                     603998                             -0.032479
#                     603999                             -0.062587
#
# [2598 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-05-09 09:30:00 000001                             -0.601270
#                     000004                             -0.541955
#                     000005                             -0.578837
#                     000006                             -0.587939
#                     000008                             -0.590814
# ...                                                          ...
#                     603993                             -0.577716
#                     603996                             -0.553749
#                     603997                             -0.579151
#                     603998                             -0.087095
#                     603999                             -0.575667
#
# [2599 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2016-05-10 09:30:00 000001                             -0.618993
#                     000004                             -0.643682
#                     000005                             -0.622484
#                     000006                             -0.623680
#                     000008                             -0.648753
# ...                                                          ...
#                     603993                             -0.621718
#                     603996                             -0.624260
#                     603997                             -0.622544
#                     603998                             -0.636418
#                     603999                             -0.622420
#
# [2600 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# ...
# timestamp           ticker
# 2017-09-25 09:30:00 000001                             -0.303937
#                     000002                             -0.564968
#                     000004                              0.237197
#                     000005                              0.238726
#                     000006                              0.298638
# ...                                                          ...
#                     603993                              0.263511
#                     603996                              0.262686
#                     603997                              0.257672
#                     603998                              0.241055
#                     603999                              0.259237
#
# [3090 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-09-26 09:30:00 000001                             -0.526750
#                     000002                             -0.081651
#                     000004                              0.083388
#                     000005                              0.081774
#                     000006                             -0.259161
# ...                                                          ...
#                     603993                              0.106874
#                     603996                              0.108049
#                     603997                              0.108145
#                     603998                              0.089893
#                     603999                              0.109581
#
# [3092 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-09-27 09:30:00 000001                             -0.548037
#                     000002                             -0.511141
#                     000004                             -0.319395
#                     000005                             -0.333867
#                     000006                             -0.574616
# ...                                                          ...
#                     603993                             -0.288150
#                     603996                             -0.282261
#                     603997                             -0.282722
#                     603998                             -0.296878
#                     603999                             -0.281323
#
# [3095 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-09-28 09:30:00 000001                             -0.073172
#                     000002                             -0.527033
#                     000004                             -0.321209
#                     000005                             -0.336129
#                     000006                             -0.404776
# ...                                                          ...
#                     603993                             -0.290340
#                     603996                             -0.284316
#                     603997                             -0.284914
#                     603998                             -0.299913
#                     603999                             -0.283528
#
# [3093 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-09-29 09:30:00 000001                              0.341245
#                     000002                             -0.545918
#                     000004                             -0.346157
#                     000005                             -0.361481
#                     000006                              0.111941
# ...                                                          ...
#                     603993                             -0.311036
#                     603996                             -0.308504
#                     603997                             -0.308699
#                     603998                             -0.324427
#                     603999                             -0.307861
#
# [3092 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-10-09 09:30:00 000001                             -0.426650
#                     000002                             -0.280421
#                     000004                             -0.642685
#                     000005                             -0.685739
#                     000006                              1.219149
# ...                                                          ...
#                     603993                             -0.622309
#                     603996                             -0.616717
#                     603997                             -0.614572
#                     603998                             -0.626488
#                     603999                             -0.609784
#
# [3092 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-10-10 09:30:00 000001                              1.945956
#                     000002                             -0.444150
#                     000004                             -0.463953
#                     000005                             -0.493533
#                     000006                             -0.419280
# ...                                                          ...
#                     603993                             -0.437968
#                     603996                             -0.432286
#                     603997                             -0.433510
#                     603998                             -0.441101
#                     603999                             -0.431562
#
# [3091 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-10-11 09:30:00 000001                             -0.285265
#                     000002                             -0.518873
#                     000004                             -0.356424
#                     000005                             -0.393061
#                     000006                             -0.608651
# ...                                                          ...
#                     603993                             -0.342399
#                     603996                             -0.336576
#                     603997                             -0.335785
#                     603998                             -0.350041
#                     603999                             -0.336241
#
# [3092 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-10-12 09:30:00 000001                             -0.540042
#                     000002                             -0.629072
#                     000004                             -0.058039
#                     000005                             -0.081989
#                     000006                             -0.654824
# ...                                                          ...
#                     603993                             -0.044684
#                     603996                             -0.041830
#                     603997                             -0.040992
#                     603998                             -0.058128
#                     603999                             -0.040298
#
# [3094 rows x 1 columns]
#                             ewmCov(open,high,7)_time_series_norm
# timestamp           ticker
# 2017-10-13 09:30:00 000001                             -0.491411
#                     000002                             -0.625149
#                     000004                             -0.141864
#                     000005                             -0.168225
#                     000006                             -0.513311
# ...                                                          ...
#                     603993                             -0.123958
#                     603996                             -0.124176
#                     603997                             -0.123617
#                     603998                             -0.138360
#                     603999                             -0.122865
#
# [3088 rows x 1 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-e003b2f37cbf> in <module>
#       1 for date, group in grouped:
#       2 #     date_format = pd.to_datetime(date).date()
# ----> 3     display(group)
#       4 #     assert DataAPI.is_trading_day(date), f"{date} is not a trading date!"
#       5 #     file_name = datetime.date.strftime(date_format, '%Y%m%d') + '.csv'
#
# ~/.local/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/.local/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     853                 decimal=".",
#     854             )
# --> 855             return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#     856         else:
#     857             return None
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1005             render_links=render_links,
#    1006         )
# -> 1007         string = html_formatter.to_string()
#    1008         return save_to_buffer(string, buf=buf, encoding=encoding)
#    1009
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/html.py in to_string(self)
#      58
#      59     def to_string(self) -> str:
# ---> 60         lines = self.render()
#      61         if any(isinstance(x, str) for x in lines):
#      62             lines = [str(x) for x in lines]
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/html.py in render(self)
#     606         self.write("<div>")
#     607         self.write_style()
# --> 608         super().render()
#     609         self.write("</div>")
#     610         return self.elements
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/html.py in render(self)
#      64
#      65     def render(self) -> List[str]:
# ---> 66         self._write_table()
#      67
#      68         if self.should_show_dimensions:
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     234             self._write_header(indent + self.indent_delta)
#     235
# --> 236         self._write_body(indent + self.indent_delta)
#     237
#     238         self.write("</table>", indent)
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     380     def _write_body(self, indent: int) -> None:
#     381         self.write("<tbody>", indent)
# --> 382         fmt_values = self._get_formatted_values()
#     383
#     384         # write values
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/html.py in _get_formatted_values(self)
#     570
#     571     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 572         return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#     573
#     574     def _get_columns_formatted_values(self) -> List[str]:
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/html.py in <dictcomp>(.0)
#     570
#     571     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 572         return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#     573
#     574     def _get_columns_formatted_values(self) -> List[str]:
#
# ~/.local/lib/python3.7/site-packages/pandas/io/formats/format.py in format_col(self, i)
#     798         formatter = self._get_formatter(i)
#     799         return format_array(
# --> 800             frame.iloc[:, i]._values,
#     801             formatter,
#     802             float_format=self.float_format,
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1450         self._has_valid_tuple(tup)
#    1451         with suppress(IndexingError):
# -> 1452             return self._getitem_lowerdim(tup)
#    1453
#    1454         return self._getitem_tuple_same_dim(tup)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     789         # we may have a nested tuples indexer here
#     790         if self._is_nested_tuple_indexer(tup):
# --> 791             return self._getitem_nested_tuple(tup)
#     792
#     793         # we maybe be using a tuple to represent multiple dimensions here
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#     863
#     864             current_ndim = obj.ndim
# --> 865             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     866             axis += 1
#     867
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1484             key = np.asarray(key)
#    1485
# -> 1486         if com.is_bool_indexer(key):
#    1487             self._validate_key(key, axis)
#    1488             return self._getbool_axis(key, axis=axis)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     101         and convert to an ndarray.
#     102     """
# --> 103     if isinstance(key, (ABCSeries, np.ndarray, ABCIndexClass)) or (
#     104         is_array_like(key) and is_extension_array_dtype(key.dtype)
#     105     ):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#      28     # https://github.com/python/mypy/issues/1006
#      29     # error: 'classmethod' used with a non-method
# ---> 30     @classmethod  # type: ignore[misc]
#      31     def _check(cls, inst) -> bool:
#      32         return getattr(inst, attr, "_typ") in comp
#
# KeyboardInterrupt:

# %%
group.to_csv("/home/wuwenjun/feature_platform/ti0/wuwenjun/test.csv", header=False, encoding='utf-8')

# %%
pd.read_csv("/home/wuwenjun/feature_platform/ti0/wuwenjun/test.csv")
# Out:
#       2017-10-16 09:30:00  000001  -0.5820808173712816
# 0     2017-10-16 09:30:00       2            -0.554312
# 1     2017-10-16 09:30:00       4            -0.561384
# 2     2017-10-16 09:30:00       5            -0.597661
# 3     2017-10-16 09:30:00       6            -0.177927
# 4     2017-10-16 09:30:00       7            -0.477869
# ...                   ...     ...                  ...
# 3085  2017-10-16 09:30:00  603993            -0.531642
# 3086  2017-10-16 09:30:00  603996            -0.528607
# 3087  2017-10-16 09:30:00  603997            -0.527753
# 3088  2017-10-16 09:30:00  603998            -0.523065
# 3089  2017-10-16 09:30:00  603999            -0.528668
#
# [3090 rows x 3 columns]
