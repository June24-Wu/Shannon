# %%
import pandas as pd

# %%
data = pd.read_csv("/home/wuwenjun/Data/AlphaNet_Original_Input_12.22_1d_return/data.csv")
data["high"] = (data["high"] - data["close"]) / data["close"]
data["low"] = (data["low"] - data["close"]) / data["close"]
data.drop("open",axis=1,inplace=True)
data.drop("vwap",axis=1,inplace=True)
data.drop("free_turnover",axis=1,inplace=True)
data.drop("turnover",axis=1,inplace=True)
data
# Out:
#                    timestamp  ticker      high       low    close      volume  \
# 0        2015-01-06 09:30:00       1  0.016226 -0.026215  1138.28  2860436.43
# 1        2015-01-06 09:30:00       2  0.025490 -0.046275  1838.34  6560835.70
# 2        2015-01-06 09:30:00       4  0.013488 -0.024780    63.76    28095.12
# 3        2015-01-06 09:30:00       5  0.000000  0.000000    38.00        0.00
# 4        2015-01-06 09:30:00       6  0.043778 -0.008444   225.00  1078647.12
# ...                      ...     ...       ...       ...      ...         ...
# 5357699  2021-07-01 09:30:00  688700  0.020982 -0.118958    53.38    64336.83
# 5357700  2021-07-01 09:30:00  688777  0.006990 -0.054014    94.42    19001.61
# 5357701  2021-07-01 09:30:00  688788  0.021406 -0.062303   146.22    13572.56
# 5357702  2021-07-01 09:30:00  688819  0.010853 -0.026578    45.15    47249.01
# 5357703  2021-07-01 09:30:00  688981  0.011000 -0.039146    61.82   777950.53
#
#          pct_chg    1d_ret
# ...

# %%
data.set_index("timestamp").to_csv("/home/wuwenjun/Data/5_Input_20220110/data.csv")

# %%
data = data[data["ticker"] == 1]
data.set_index(["ticker","timestamp"],inplace=True)
data
# Out:
#                    timestamp  ticker     open     high      low    close  \
# 0        2015-01-06 09:30:00       1  1136.15  1156.75  1108.44  1138.28
# 2588     2015-01-07 09:30:00       1  1126.20  1164.57  1104.89  1121.23
# 5176     2015-01-08 09:30:00       1  1105.60  1124.78  1087.12  1099.91
# 7764     2015-01-09 09:30:00       1  1101.33  1106.31  1058.70  1062.96
# 10352    2015-01-12 09:30:00       1  1058.70  1127.62  1045.20  1071.49
# ...                      ...     ...      ...      ...      ...      ...
# 5335896  2021-06-25 09:30:00       1  2577.56  2587.64  2538.39  2583.16
# 5340252  2021-06-28 09:30:00       1  2583.16  2641.36  2580.92  2614.50
# 5344611  2021-06-29 09:30:00       1  2614.50  2617.85  2516.01  2549.58
# 5348973  2021-06-30 09:30:00       1  2527.20  2550.70  2462.28  2500.34
# 5353336  2021-07-01 09:30:00       1  2502.58  2566.37  2501.46  2531.67
#
#                 vwap      volume  pct_chg  turnover  free_turnover    1d_ret
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
f, ax= plt.subplots(figsize = (14, 10))
corr = data.corr()
# print(corr)
sns.heatmap(corr,cmap='RdBu', linewidths = 0.05, ax = ax,annot=True)

# 设置Axes的标题
ax.set_title('Correlation between features')
plt.show()

# %%
# data["high"] = (data["high"] - data["close"]) / data["close"]
# data["low"] = (data["low"] - data["close"]) / data["close"]
# data.drop("open",axis=1,inplace=True)
# data.drop("vwap",axis=1,inplace=True)
# data.drop("free_turnover",axis=1,inplace=True)
# data.drop("turnover",axis=1,inplace=True)
data
# Out:
# /home/wuwenjun/.local/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                 high       low    close      volume  pct_chg  \
# ticker timestamp
# 1      2015-01-06 09:30:00  0.016226 -0.026215  1138.28  2860436.43   1.1364
#        2015-01-07 09:30:00  0.038654 -0.014573  1121.23  2166421.40  -1.4981
#        2015-01-08 09:30:00  0.022611 -0.011628  1099.91  1700120.67  -1.9011
#        2015-01-09 09:30:00  0.040782 -0.004008  1062.96  1407714.21  -3.3592
#        2015-01-12 09:30:00  0.052385 -0.024536  1071.49  2508500.23   0.8021
# ...                              ...       ...      ...         ...      ...
#        2021-06-25 09:30:00  0.001734 -0.017331  2583.16   390283.49  -0.2593
# ...

# %%
f, ax= plt.subplots(figsize = (14, 10))
corr = data.corr()
sns.heatmap(corr,cmap='RdBu', linewidths = 0.05, ax = ax,annot=True)

ax.set_title('Correlation between features')
plt.show()
