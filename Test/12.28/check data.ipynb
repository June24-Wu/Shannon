# %%
import torch
import pandas as pd 
import numpy as np

# %%
torch.cuda.is_available()
torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'A100-PCIE-40GB'

# %%
corr = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_5d_return/Corr/2017-01-01_2017-03-01.par").iloc[10000,:])
corr = corr.T.set_index(["timestamp","ticker"])
corr.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
data = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_5d_return/Data/2017-01-01_2017-03-01.par").iloc[10000,:])
data = data.T.set_index(["timestamp","ticker"])
data.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
corr
# Out:
#                                    0         1         2         3         4  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.702198  0.992243  0.870583  0.909339  0.461905
#
#                                    5         6         7         8         9  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.943725  0.615144  0.610635  0.906562  0.742313
#
#                             ...   98        99       100       101       102  \
# timestamp           ticker  ...
# 2017-02-17 09:30:00 735     ...  1.0  0.511658 -0.829324  0.720368  0.511663
#
#                                  103       104  105  106  107
# timestamp           ticker
# 2017-02-17 09:30:00 735    -0.829376  0.720374  1.0  1.0  1.0
#
# [1 rows x 108 columns]

# %%
pd.DataFrame(np.array(corr).reshape(-1,3))
# Out:
#           0         1         2
# 0 -0.004042 -0.035911  0.031358
# 1       0.0 -0.034475  0.028564
# 2       0.0 -0.025176  0.043467
# 3   0.00815 -0.019792  0.037249
# 4  0.001481 -0.026358  0.034587
# 5 -0.034511  -0.26792      -1.0
# 6      -1.0  -1.37879      -1.0
# 7 -0.034496  -0.26789      -1.0
# 8 -0.034494 -0.267888      -1.0

# %%
array = np.array(data.drop("target",axis=1))
array = pd.DataFrame(array.reshape(30,-1))
array
# Out:
#         0      1      2      3          4          5       6       7       8
# 0   42.06  42.24  41.66  41.72  41.911799  112174.52 -1.5068  1.2755  1.4843
# 1   41.54  42.12  41.02  41.54  41.555557  155431.21 -0.4172  1.7673  2.0567
# 2    41.6  43.34  41.48  42.93  42.817489  289103.76   3.352  3.2872  3.8254
# 3   42.76  44.04  42.64  43.22  43.325163  310929.82  0.6757  3.5354  4.1142
# 4   42.99   44.5  42.76  43.98    43.6669  387903.43   1.745  4.4106  5.1328
# 5   43.46  43.69  42.93  43.28  43.257279  281633.42 -1.5831  3.2023  3.7266
# 6   43.22  43.51  42.76  43.46  43.125574  171433.19  0.4021  1.9493  2.2684
# 7   43.51  43.51   42.3  42.35   42.87957  201088.26 -2.5367  2.2865  2.6608
# 8   42.18  42.59  41.77  42.06  42.120671   136796.4 -0.6849  1.5554  1.8101
# 9   41.89  42.24  41.66  42.06   41.97388  108303.23     0.0  1.2315  1.4331
# 10  41.77  42.06  41.31  41.43  41.581086  100656.97 -1.5172  1.1445  1.3319
# ...

# %%
a = array.iloc[10:20,[1]]
a = a.astype("float")
a = np.array(a)
a
# Out:
# array([[42.06],
#        [41.6 ],
#        [39.98],
#        [40.27],
#        [40.03],
#        [39.8 ],
#        [40.44],
#        [40.67],
#        [40.44],
#        [40.61]])

# %%
(40.60 - 42.06) / 42.06
# Out:
# -0.034712315739419894

# %% [markdown]
# # Feat Concat

# %%
feat_concat = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_12.22_1d_return_normalized/Feat_Concat/2017-01-01_2017-03-01.par").iloc[10000,:])
feat_concat = feat_concat.T.set_index(["timestamp","ticker"])
feat_concat.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
corr = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_12.22_1d_return_normalized/Decay/2017-01-01_2017-03-01.par").iloc[10000,:])
corr = corr.T.set_index(["timestamp","ticker"])
corr.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
feat_concat.iloc[:,297:]
# Out:
#                                   297        298        299        300  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     42.651455  40.024364  41.172182  43.193818
#
#                                   301        302        303     304  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     40.431455  41.462182  42.187818  39.724
#
#                                   305        306  ...           314       315  \
# timestamp           ticker                        ...
# 2017-02-17 09:30:00 735     40.979091  42.694727  ...  93347.277273 -0.254527
#
#                                  316       317       318       319       320  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.152302  0.376284  2.333287  0.949611  1.061405
#
#                                  321      322       323
# timestamp           ticker
# 2017-02-17 09:30:00 735     2.715298  1.10508  1.235167
#
# [1 rows x 27 columns]

# %%
corr
# Out:
#                                     0          1          2          3  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     42.651455  40.024364  41.172182  43.193818
#
#                                     4          5          6       7  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     40.431455  41.462182  42.187818  39.724
#
#                                     8          9  ...            17        18  \
# timestamp           ticker                        ...
# 2017-02-17 09:30:00 735     40.979091  42.694727  ...  93347.277273 -0.254527
#
#                                   19        20        21        22        23  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.152302  0.376284  2.333287  0.949611  1.061405
#
#                                   24       25        26
# timestamp           ticker
# 2017-02-17 09:30:00 735     2.715298  1.10508  1.235167
#
# [1 rows x 27 columns]

# %%
pd.DataFrame(np.array(corr).reshape(-1,3))
# Out:
#            0         1         2
# 0   0.702198  0.992243  0.870583
# 1   0.909339  0.461905  0.943725
# 2   0.615144  0.610635  0.906562
# 3   0.742313  0.871699  0.945044
# 4   0.388553  0.447561  -0.42601
# 5  -0.381747 -0.656886  0.112736
# 6   0.388568  0.447536 -0.426013
# 7   0.388553  0.447578 -0.426011
# 8   0.830123  0.430471   0.83597
# 9   0.929982  0.593067  0.956562
# 10  0.984733  0.864909  0.964532
# 11  0.897175  0.480181  0.029777
# 12  0.323378 -0.655827  0.455286
# 13  0.897181  0.480158  0.029775
# 14  0.897172  0.480196  0.029778
# 15  0.830254  0.925009  0.913829
# 16   0.88268  0.805766  0.943442
# 17  0.571219 -0.540048 -0.448659
# 18 -0.075943  0.257676  0.078689
# 19  0.571232  -0.54006 -0.448654
# 20  0.571218 -0.540039 -0.448664
# 21  0.956579  0.907878  0.972481
# 22   0.82582 -0.336491  -0.10646
# 23  0.470279  0.185892  0.420514
# 24  0.825827 -0.336495 -0.106462
# 25   0.82582 -0.336485 -0.106465
# 26  0.845545  0.014429 -0.205245
# ...

# %% [markdown]
# # Pooling

# %%
pool = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_12.22_1d_return_normalized/Pooling/2017-01-01_2017-03-01.par").iloc[10000,:])
pool = pool.T.set_index(["timestamp","ticker"])
pool.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
corr = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_12.22_1d_return_normalized/Cov/2017-01-01_2017-03-01.par").iloc[10000,:])
corr = corr.T.set_index(["timestamp","ticker"])
corr.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
corr
# Out:
#                                    0       1         2         3         4  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.442302  0.5496  0.228491  0.455624  0.288791
#
#                                    5         6         7        8        9  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.320633  0.383811  0.286122  0.25701  0.40387
#
#                             ...            98        99      100       101  \
# timestamp           ticker  ...
# 2017-02-17 09:30:00 735     ...  62212.429246  0.961192 -0.60879  0.426747
#
#                                  102       103       104       105       106  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     1.118589 -0.708474  0.496614  1.383158  0.202561
#
#                                  107
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.707382
#
# [1 rows x 108 columns]

# %%
pool
# Out:
#                                  0         1         2         3         4  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.5496  0.406798  0.228491  0.455624  0.355016
#
#                                    5         6         7        8         9  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.288791  0.383811  0.308981  0.25701  0.409516
#
#                             ...           314       315       316       317  \
# timestamp           ticker  ...
# 2017-02-17 09:30:00 735     ...  83514.601091  0.376284  0.091353 -0.254527
#
#                                  318       319       320       321       322  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     2.333287  1.448101  0.949611  2.715298  1.685182
#
#                                 323
# timestamp           ticker
# 2017-02-17 09:30:00 735     1.10508
#
# [1 rows x 324 columns]

# %% [markdown]
# # Final

# %%
final = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_12.22_1d_return_normalized/Final/2017-01-01_2017-03-01.par").iloc[10000,:])
final = final.T.set_index(["timestamp","ticker"])
final.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
feat_concat = pd.DataFrame(pd.read_parquet("/home/wuwenjun/Data/AlphaNet_Original_Input_12.22_1d_return_normalized/Corr/2017-01-01_2017-03-01.par").iloc[10000,:])
feat_concat = feat_concat.T.set_index(["timestamp","ticker"])
feat_concat.index
# Out:
# MultiIndex([('2017-02-17 09:30:00', 735)],
#            names=['timestamp', 'ticker'])

# %%
final.iloc[:,108:216]
# Out:
#                                  108       109       110       111       112  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.702198  0.992243  0.870583  0.909339  0.461905
#
#                                  113       114       115       116       117  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.943725  0.615144  0.610635  0.906562  0.742313
#
#                             ...  206       207       208       209       210  \
# timestamp           ticker  ...
# 2017-02-17 09:30:00 735     ...  1.0  0.511658 -0.829324  0.720368  0.511663
#
#                                  211       212  213  214  215
# timestamp           ticker
# 2017-02-17 09:30:00 735    -0.829376  0.720374  1.0  1.0  1.0
#
# [1 rows x 108 columns]

# %%
feat_concat
# Out:
#                                    0         1         2         3         4  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.702198  0.992243  0.870583  0.909339  0.461905
#
#                                    5         6         7         8         9  \
# timestamp           ticker
# 2017-02-17 09:30:00 735     0.943725  0.615144  0.610635  0.906562  0.742313
#
#                             ...   98        99       100       101       102  \
# timestamp           ticker  ...
# 2017-02-17 09:30:00 735     ...  1.0  0.511658 -0.829324  0.720368  0.511663
#
#                                  103       104  105  106  107
# timestamp           ticker
# 2017-02-17 09:30:00 735    -0.829376  0.720374  1.0  1.0  1.0
#
# [1 rows x 108 columns]
