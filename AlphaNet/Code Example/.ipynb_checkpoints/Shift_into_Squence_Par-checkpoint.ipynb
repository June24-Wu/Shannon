# %%
import time
import os
from Research.backtest.bt import BTDaily
from Research.feature.ft import FeatureAnalysis
import Research.utils.namespace as namespace
import Research.utils.normalization as norm
from Platform.database.mysql import MysqlAPI
from Platform.utils.persistence import convert_to_standard_daily_feature_csv, convert_to_standard_daily_feature_par
from Platform.config.mysql_info import FACTOR_LIB_MYSQL_TIO
import DataAPI
from os import walk
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from progressbar import ProgressBar
from tqdm import tqdm
import multiprocessing as mp
import sys
sys.path.append("/home/wuwenjun/jupyter_code/Shannon/AlphaNet/packages/")

# %%
from AlphaNet.Data import DataLoader
# Out:
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template

# %%
def generate_shift_data(alpha_name,shift,data_path = "/home/wuwenjun/Data_lib/ti0/wuwenjun/"):
    dataloader = DataLoader()
    dataloader.load_data_from_file(alpha_name = alpha_name, data_path=data_path,end_date="2022-01-01")
    
    # generate shift list
    sequence_list = [0]
    for i in range(shift-1,30,shift):
        sequence_list.append(i)
    sequence_list.sort(reverse=True)
    
    # shift
    x = dataloader.feature_data.drop("target",axis=1)
    final_df = []
    for index,group in tqdm(x.groupby("ticker")):
        group_df = []
        for i in sequence_list:
            a = group.shift(i)
            a.columns = [str(j)+"_Shift_%i" % i for j in group.columns]
            group_df.append(a)
        group_df = pd.concat(group_df,axis=1)
        final_df.append(group_df)
    final_df = pd.concat(final_df,axis=0)
    final_df = pd.concat([final_df,dataloader.feature_data["target"]],axis=1)
    convert_to_standard_daily_data_par(df=final_df, output_name=alpha_name +"_Shift_" + shift, 
                                       output_path="/home/wuwenjun/Data_lib/ti0/wuwenjun/")
    return final_df

# %%
generate_shift_data("test",5)
# Out:
# 100%|██████████| 4353/4353 [00:14<00:00, 308.53it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-76c8d1fabcd6> in <module>
# ----> 1 generate_shift_data("test",5)
#
# <ipython-input-3-1c167e2e0538> in generate_shift_data(alpha_name, shift, data_path)
#      23     final_df = pd.concat([final_df,dataloader.feature_data["target"]],axis=1)
#      24
# ---> 25     convert_to_standard_daily_data_par(df=final_df, output_name=alpha_name +"_S", output_path="/home/wuwenjun/Data_lib/ti0/wuwenjun/")
#
# NameError: name 'convert_to_standard_daily_data_par' is not defined

# %%
final_df
# Out:
# 100%|██████████| 4353/4353 [00:10<00:00, 398.29it/s]
#                             test_mcorr_open_low_10_Shift_27  test_1_Shift_27  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                              NaN              NaN
# 2020-01-03 09:30:00 000001                              NaN              NaN
# 2020-01-06 09:30:00 000001                              NaN              NaN
# 2020-01-07 09:30:00 000001                              NaN              NaN
# 2020-01-08 09:30:00 000001                              NaN              NaN
# ...                                                     ...              ...
# 2021-05-26 09:30:00 688981                         0.972941         0.972941
# 2021-05-27 09:30:00 688981                         0.968343         0.968343
# 2021-05-28 09:30:00 688981                         0.958937         0.958937
# 2021-05-31 09:30:00 688981                         0.940781         0.940781
# 2021-06-01 09:30:00 688981                         0.976037         0.976037
#
#                             test_Shift_27  ewmCorr(high,low)_Shift_27  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001            NaN                         NaN
# 2020-01-03 09:30:00 000001            NaN                         NaN
# 2020-01-06 09:30:00 000001            NaN                         NaN
# 2020-01-07 09:30:00 000001            NaN                         NaN
# 2020-01-08 09:30:00 000001            NaN                         NaN
# ...                                   ...                         ...
# 2021-05-26 09:30:00 688981         111.92                    0.870913
# 2021-05-27 09:30:00 688981         112.47                    0.918865
# 2021-05-28 09:30:00 688981         113.17                    0.897014
# 2021-05-31 09:30:00 688981         112.86                    0.194527
# 2021-06-01 09:30:00 688981         113.29                    0.222234
#
#                             ewmCorr(high,low,7)_Shift_27  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                           NaN
# 2020-01-03 09:30:00 000001                           NaN
# 2020-01-06 09:30:00 000001                           NaN
# 2020-01-07 09:30:00 000001                           NaN
# 2020-01-08 09:30:00 000001                           NaN
# ...                                                  ...
# 2021-05-26 09:30:00 688981                      0.870913
# 2021-05-27 09:30:00 688981                      0.918865
# 2021-05-28 09:30:00 688981                      0.897014
# 2021-05-31 09:30:00 688981                      0.194527
# 2021-06-01 09:30:00 688981                      0.222234
#
#                             test_mcorr_open_low_10_Shift_20  test_1_Shift_20  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                              NaN              NaN
# 2020-01-03 09:30:00 000001                              NaN              NaN
# 2020-01-06 09:30:00 000001                              NaN              NaN
# 2020-01-07 09:30:00 000001                              NaN              NaN
# 2020-01-08 09:30:00 000001                              NaN              NaN
# ...                                                     ...              ...
# 2021-05-26 09:30:00 688981                         0.886539         0.886539
# 2021-05-27 09:30:00 688981                         0.883308         0.883308
# 2021-05-28 09:30:00 688981                         0.883115         0.883115
# 2021-05-31 09:30:00 688981                         0.928937         0.928937
# 2021-06-01 09:30:00 688981                         0.925138         0.925138
#
#                             test_Shift_20  ewmCorr(high,low)_Shift_20  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001            NaN                         NaN
# 2020-01-03 09:30:00 000001            NaN                         NaN
# 2020-01-06 09:30:00 000001            NaN                         NaN
# 2020-01-07 09:30:00 000001            NaN                         NaN
# 2020-01-08 09:30:00 000001            NaN                         NaN
# ...                                   ...                         ...
# 2021-05-26 09:30:00 688981         110.29                    0.934368
# 2021-05-27 09:30:00 688981         110.72                    0.736020
# 2021-05-28 09:30:00 688981         109.82                   -0.545963
# 2021-05-31 09:30:00 688981         109.40                    0.717709
# 2021-06-01 09:30:00 688981         110.24                    0.557725
#
#                             ewmCorr(high,low,7)_Shift_20  ...  \
# timestamp           ticker                                ...
# 2020-01-02 09:30:00 000001                           NaN  ...
# 2020-01-03 09:30:00 000001                           NaN  ...
# 2020-01-06 09:30:00 000001                           NaN  ...
# 2020-01-07 09:30:00 000001                           NaN  ...
# 2020-01-08 09:30:00 000001                           NaN  ...
# ...                                                  ...  ...
# 2021-05-26 09:30:00 688981                      0.934368  ...
# 2021-05-27 09:30:00 688981                      0.736020  ...
# 2021-05-28 09:30:00 688981                     -0.545963  ...
# 2021-05-31 09:30:00 688981                      0.717709  ...
# 2021-06-01 09:30:00 688981                      0.557725  ...
#
#                             test_mcorr_open_low_10_Shift_6  test_1_Shift_6  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                             NaN             NaN
# 2020-01-03 09:30:00 000001                             NaN             NaN
# 2020-01-06 09:30:00 000001                             NaN             NaN
# 2020-01-07 09:30:00 000001                             NaN             NaN
# 2020-01-08 09:30:00 000001                             NaN             NaN
# ...                                                    ...             ...
# 2021-05-26 09:30:00 688981                        0.910865        0.910865
# 2021-05-27 09:30:00 688981                        0.910914        0.910914
# 2021-05-28 09:30:00 688981                        0.906171        0.906171
# 2021-05-31 09:30:00 688981                        0.917671        0.917671
# 2021-06-01 09:30:00 688981                        0.938853        0.938853
#
#                             test_Shift_6  ewmCorr(high,low)_Shift_6  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001           NaN                        NaN
# 2020-01-03 09:30:00 000001           NaN                        NaN
# 2020-01-06 09:30:00 000001           NaN                        NaN
# 2020-01-07 09:30:00 000001           NaN                        NaN
# 2020-01-08 09:30:00 000001           NaN                        NaN
# ...                                  ...                        ...
# 2021-05-26 09:30:00 688981        110.70                   0.967554
# 2021-05-27 09:30:00 688981        110.18                   0.933708
# 2021-05-28 09:30:00 688981        109.59                   0.910664
# 2021-05-31 09:30:00 688981        108.97                   0.856728
# 2021-06-01 09:30:00 688981        108.62                   0.925424
#
#                             ewmCorr(high,low,7)_Shift_6  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                          NaN
# 2020-01-03 09:30:00 000001                          NaN
# 2020-01-06 09:30:00 000001                          NaN
# 2020-01-07 09:30:00 000001                          NaN
# 2020-01-08 09:30:00 000001                          NaN
# ...                                                 ...
# 2021-05-26 09:30:00 688981                     0.967554
# 2021-05-27 09:30:00 688981                     0.933708
# 2021-05-28 09:30:00 688981                     0.910664
# 2021-05-31 09:30:00 688981                     0.856728
# 2021-06-01 09:30:00 688981                     0.925424
#
#                             test_mcorr_open_low_10_Shift_0  test_1_Shift_0  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                        0.115025        0.115025
# 2020-01-03 09:30:00 000001                        0.340535        0.340535
# 2020-01-06 09:30:00 000001                        0.717011        0.717011
# 2020-01-07 09:30:00 000001                        0.820196        0.820196
# 2020-01-08 09:30:00 000001                        0.931442        0.931442
# ...                                                    ...             ...
# 2021-05-26 09:30:00 688981                        0.954971        0.954971
# 2021-05-27 09:30:00 688981                        0.941155        0.941155
# 2021-05-28 09:30:00 688981                        0.935656        0.935656
# 2021-05-31 09:30:00 688981                        0.949229        0.949229
# 2021-06-01 09:30:00 688981                             NaN             NaN
#
#                             test_Shift_0  ewmCorr(high,low)_Shift_0  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001       3604.78                   0.414245
# 2020-01-03 09:30:00 000001       3659.36                   0.922935
# 2020-01-06 09:30:00 000001       3724.86                   0.989700
# 2020-01-07 09:30:00 000001       3720.49                   0.987041
# 2020-01-08 09:30:00 000001       3742.33                   0.893703
# ...                                  ...                        ...
# 2021-05-26 09:30:00 688981        110.85                   0.900790
# 2021-05-27 09:30:00 688981        110.71                   0.924924
# 2021-05-28 09:30:00 688981        111.88                   0.083880
# 2021-05-31 09:30:00 688981        112.08                  -0.400864
# 2021-06-01 09:30:00 688981           NaN                        NaN
#
#                             ewmCorr(high,low,7)_Shift_0
# timestamp           ticker
# 2020-01-02 09:30:00 000001                     0.414245
# 2020-01-03 09:30:00 000001                     0.922935
# 2020-01-06 09:30:00 000001                     0.989700
# 2020-01-07 09:30:00 000001                     0.987041
# 2020-01-08 09:30:00 000001                     0.893703
# ...                                                 ...
# 2021-05-26 09:30:00 688981                     0.900790
# 2021-05-27 09:30:00 688981                     0.924924
# 2021-05-28 09:30:00 688981                     0.083880
# 2021-05-31 09:30:00 688981                    -0.400864
# 2021-06-01 09:30:00 688981                          NaN
#
# [1366034 rows x 25 columns]

# %%
# Out:
#                             test_mcorr_open_low_10_Shift_27  test_1_Shift_27  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                              NaN              NaN
#                     000002                              NaN              NaN
#                     000004                              NaN              NaN
#                     000005                              NaN              NaN
#                     000006                              NaN              NaN
# ...                                                     ...              ...
# 2021-06-01 09:30:00 688699                         0.799873         0.799873
#                     688777                         0.072384         0.072384
#                     688788                         0.883944         0.883944
#                     688819                         0.888472         0.888472
#                     688981                         0.976037         0.976037
#
#                             test_Shift_27  ewmCorr(high,low)_Shift_27  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001            NaN                         NaN
#                     000002            NaN                         NaN
#                     000004            NaN                         NaN
#                     000005            NaN                         NaN
#                     000006            NaN                         NaN
# ...                                   ...                         ...
# 2021-06-01 09:30:00 688699         188.71                    0.561402
#                     688777         170.92                    0.858772
#                     688788         215.24                    0.992183
#                     688819          90.65                    0.968043
#                     688981         113.29                    0.222234
#
#                             ewmCorr(high,low,7)_Shift_27  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                           NaN
#                     000002                           NaN
#                     000004                           NaN
#                     000005                           NaN
#                     000006                           NaN
# ...                                                  ...
# 2021-06-01 09:30:00 688699                      0.561402
#                     688777                      0.858772
#                     688788                      0.992183
#                     688819                      0.968043
#                     688981                      0.222234
#
#                             test_mcorr_open_low_10_Shift_20  test_1_Shift_20  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                              NaN              NaN
#                     000002                              NaN              NaN
#                     000004                              NaN              NaN
#                     000005                              NaN              NaN
#                     000006                              NaN              NaN
# ...                                                     ...              ...
# 2021-06-01 09:30:00 688699                         0.942024         0.942024
#                     688777                         0.447107         0.447107
#                     688788                         0.918706         0.918706
#                     688819                         0.833126         0.833126
#                     688981                         0.925138         0.925138
#
#                             test_Shift_20  ewmCorr(high,low)_Shift_20  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001            NaN                         NaN
#                     000002            NaN                         NaN
#                     000004            NaN                         NaN
#                     000005            NaN                         NaN
#                     000006            NaN                         NaN
# ...                                   ...                         ...
# 2021-06-01 09:30:00 688699         257.67                    0.596919
#                     688777         167.68                    0.459227
#                     688788         205.30                    0.873697
#                     688819          89.85                    0.588955
#                     688981         110.24                    0.557725
#
#                             ewmCorr(high,low,7)_Shift_20  ...  test_1_Shift_6  \
# timestamp           ticker                                ...
# 2020-01-02 09:30:00 000001                           NaN  ...             NaN
#                     000002                           NaN  ...             NaN
#                     000004                           NaN  ...             NaN
#                     000005                           NaN  ...             NaN
#                     000006                           NaN  ...             NaN
# ...                                                  ...  ...             ...
# 2021-06-01 09:30:00 688699                      0.596919  ...        0.983295
#                     688777                      0.459227  ...        0.959165
#                     688788                      0.873697  ...        0.996728
#                     688819                      0.588955  ...        0.781295
#                     688981                      0.557725  ...        0.938853
#
#                             test_Shift_6  ewmCorr(high,low)_Shift_6  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001           NaN                        NaN
#                     000002           NaN                        NaN
#                     000004           NaN                        NaN
#                     000005           NaN                        NaN
#                     000006           NaN                        NaN
# ...                                  ...                        ...
# 2021-06-01 09:30:00 688699        319.69                   0.775226
#                     688777        176.45                   0.739302
#                     688788        241.31                   0.811151
#                     688819           NaN                   0.871079
#                     688981        108.62                   0.925424
#
#                             ewmCorr(high,low,7)_Shift_6  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                          NaN
#                     000002                          NaN
#                     000004                          NaN
#                     000005                          NaN
#                     000006                          NaN
# ...                                                 ...
# 2021-06-01 09:30:00 688699                     0.775226
#                     688777                     0.739302
#                     688788                     0.811151
#                     688819                     0.871079
#                     688981                     0.925424
#
#                             test_mcorr_open_low_10_Shift_0  test_1_Shift_0  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001                        0.115025        0.115025
#                     000002                        0.796874        0.796874
#                     000004                        0.815852        0.815852
#                     000005                        0.815519        0.815519
#                     000006                        0.846951        0.846951
# ...                                                    ...             ...
# 2021-06-01 09:30:00 688699                             NaN             NaN
#                     688777                             NaN             NaN
#                     688788                             NaN             NaN
#                     688819                             NaN             NaN
#                     688981                             NaN             NaN
#
#                             test_Shift_0  ewmCorr(high,low)_Shift_0  \
# timestamp           ticker
# 2020-01-02 09:30:00 000001       3604.78                   0.414245
#                     000002       9428.61                   0.968666
#                     000004        184.01                  -0.086929
#                     000005         57.28                   0.656316
#                     000006        379.05                   0.967827
# ...                                  ...                        ...
# 2021-06-01 09:30:00 688699           NaN                        NaN
#                     688777           NaN                        NaN
#                     688788           NaN                        NaN
#                     688819           NaN                        NaN
#                     688981           NaN                        NaN
#
#                             ewmCorr(high,low,7)_Shift_0    target
# timestamp           ticker
# 2020-01-02 09:30:00 000001                     0.414245 -5.551395
#                     000002                     0.968666 -6.203258
#                     000004                    -0.086929 -5.390784
#                     000005                     0.656316 -5.142255
#                     000006                     0.967827 -5.327572
# ...                                                 ...       ...
# 2021-06-01 09:30:00 688699                          NaN -6.236975
#                     688777                          NaN -6.432447
#                     688788                          NaN -6.486812
#                     688819                          NaN -6.124710
#                     688981                          NaN -6.088935
#
# [1366034 rows x 26 columns]
