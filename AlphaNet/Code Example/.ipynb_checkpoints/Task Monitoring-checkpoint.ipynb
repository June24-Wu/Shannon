# %%
import pandas as pd 
import numpy as np

# %%
task_info = np.load("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",allow_pickle=True).item()

# %%
task_info["Cuda"]
# Out:
# ['cuda:0', 'cuda:0', 'cuda:1', 'cuda:1', 'cuda:1']

# %%
task_info["Task"].query("status == ['running','cuda:0','cuda:1']")
# Out:
# Empty DataFrame
# Columns: [Alpha_Name, sequence, LR, epoch_num, feature_num, start_date, end_date, status, description]
# Index: []

# %%
task_info["Task"]
# Out:
#                                         Alpha_Name sequence  \
# task_id
# 0                 Original_Input_Moving_10_Shift_5        5
# 1                 Original_Input_Moving_10_Shift_5        5
# 2                 Original_Input_Moving_10_Shift_5        5
# 3                 Original_Input_Moving_10_Shift_5        5
# 4                 Original_Input_Moving_10_Shift_5        5
# ...                                            ...      ...
# 80       AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 81       AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 82       AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 83       AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 84       AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
#
#                              LR     epoch_num feature_num  start_date  \
# task_id
# 0               [0.001, 0.0001]      [30, 20]         108  2019-01-01
# 1               [0.001, 0.0001]      [30, 20]         108  2019-06-01
# 2               [0.001, 0.0001]      [30, 20]         108  2020-01-01
# 3               [0.001, 0.0001]      [30, 20]         108  2020-06-01
# 4               [0.001, 0.0001]      [30, 20]         108  2021-01-01
# ...                         ...           ...         ...         ...
# 80       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-01-01
# 81       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-06-01
# 82       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-01-01
# 83       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-06-01
# 84       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2021-01-01
#
#            end_date    status  \
# task_id
# 0        2019-06-01  finished
# 1        2020-01-01  finished
# 2        2020-06-01  finished
# 3        2021-01-01  finished
# 4        2021-06-01  finished
# ...             ...       ...
# 80       2019-06-01   waiting
# 81       2020-01-01   waiting
# 82       2020-06-01   waiting
# 83       2021-01-01   waiting
# 84       2021-06-01   waiting
#
#                                                description
# task_id
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 80       {'target': '10d_ret_standscalar', 'alpha_name'...
# 81       {'target': '10d_ret_standscalar', 'alpha_name'...
# 82       {'target': '10d_ret_standscalar', 'alpha_name'...
# 83       {'target': '10d_ret_standscalar', 'alpha_name'...
# 84       {'target': '10d_ret_standscalar', 'alpha_name'...
#
# [85 rows x 9 columns]

# %%
task_info["Task"][-20:]
# Out:
#                                                 Alpha_Name sequence  \
# task_id
# 65             Original_Input_Residual_Shift_1_Sequence_10       10
# 66             Original_Input_Residual_Shift_1_Sequence_10       10
# 67             Original_Input_Residual_Shift_1_Sequence_10       10
# 68             Original_Input_Residual_Shift_1_Sequence_10       10
# 69             Original_Input_Residual_Shift_1_Sequence_10       10
# 70              AlphaNetV1_Ts_Standard_Shift_10_Sequence_3        3
# 71              AlphaNetV1_Ts_Standard_Shift_10_Sequence_3        3
# 72              AlphaNetV1_Ts_Standard_Shift_10_Sequence_3        3
# 73              AlphaNetV1_Ts_Standard_Shift_10_Sequence_3        3
# 74              AlphaNetV1_Ts_Standard_Shift_10_Sequence_3        3
# 75       Original_Input_Ts_Stand_Residual_Concated_Shif...       10
# 76       Original_Input_Ts_Stand_Residual_Concated_Shif...       10
# 77       Original_Input_Ts_Stand_Residual_Concated_Shif...       10
# 78       Original_Input_Ts_Stand_Residual_Concated_Shif...       10
# 79       Original_Input_Ts_Stand_Residual_Concated_Shif...       10
# 80               AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 81               AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 82               AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 83               AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
# 84               AlphaNetV1_Ts_Standard_Shift_5_Sequence_6        6
#
#                              LR     epoch_num feature_num  start_date  \
# task_id
# 65       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2019-01-01
# 66       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2019-06-01
# 67       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2020-01-01
# 68       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2020-06-01
# 69       [0.001, 0.0001, 1e-05]  [30, 30, 30]           9  2021-01-01
# 70       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-01-01
# 71       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-06-01
# 72       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-01-01
# 73       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-06-01
# 74       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2021-01-01
# 75       [0.001, 0.0001, 1e-05]  [30, 30, 30]          18  2019-01-01
# 76       [0.001, 0.0001, 1e-05]  [30, 30, 30]          18  2019-06-01
# 77       [0.001, 0.0001, 1e-05]  [30, 30, 30]          18  2020-01-01
# 78       [0.001, 0.0001, 1e-05]  [30, 30, 30]          18  2020-06-01
# 79       [0.001, 0.0001, 1e-05]  [30, 30, 30]          18  2021-01-01
# 80       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-01-01
# 81       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-06-01
# 82       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-01-01
# 83       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-06-01
# 84       [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2021-01-01
#
#            end_date    status  \
# task_id
# 65       2019-06-01  finished
# 66       2020-01-01  finished
# 67       2020-06-01  finished
# 68       2021-01-01  finished
# 69       2021-06-01  finished
# 70       2019-06-01  finished
# 71       2020-01-01  finished
# 72       2020-06-01  finished
# 73       2021-01-01  finished
# 74       2021-06-01  finished
# 75       2019-06-01  finished
# 76       2020-01-01  finished
# 77       2020-06-01  finished
# 78       2021-01-01  finished
# 79       2021-06-01  finished
# 80       2019-06-01   waiting
# 81       2020-01-01   waiting
# 82       2020-06-01   waiting
# 83       2021-01-01   waiting
# 84       2021-06-01   waiting
#
#                                                description
# task_id
# 65       {'target': '10d_ret_standscalar', 'alpha_name'...
# 66       {'target': '10d_ret_standscalar', 'alpha_name'...
# 67       {'target': '10d_ret_standscalar', 'alpha_name'...
# 68       {'target': '10d_ret_standscalar', 'alpha_name'...
# 69       {'target': '10d_ret_standscalar', 'alpha_name'...
# 70       {'target': '10d_ret_standscalar', 'alpha_name'...
# 71       {'target': '10d_ret_standscalar', 'alpha_name'...
# 72       {'target': '10d_ret_standscalar', 'alpha_name'...
# 73       {'target': '10d_ret_standscalar', 'alpha_name'...
# 74       {'target': '10d_ret_standscalar', 'alpha_name'...
# 75       {'target': '10d_ret_standscalar', 'alpha_name'...
# 76       {'target': '10d_ret_standscalar', 'alpha_name'...
# 77       {'target': '10d_ret_standscalar', 'alpha_name'...
# 78       {'target': '10d_ret_standscalar', 'alpha_name'...
# 79       {'target': '10d_ret_standscalar', 'alpha_name'...
# 80       {'target': '10d_ret_standscalar', 'alpha_name'...
# 81       {'target': '10d_ret_standscalar', 'alpha_name'...
# 82       {'target': '10d_ret_standscalar', 'alpha_name'...
# 83       {'target': '10d_ret_standscalar', 'alpha_name'...
# 84       {'target': '10d_ret_standscalar', 'alpha_name'...

# %%
np.save("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",task_info)
