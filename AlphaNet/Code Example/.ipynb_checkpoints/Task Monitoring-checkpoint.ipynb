# %%
import pandas as pd 
import numpy as np

# %%
task_info = np.load("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",allow_pickle=True).item()

# %%
task_info["Cuda"]
# Out:
# ['cuda:0', 'cuda:1', 'cuda:0', 'cuda:1', 'cuda:1']

# %%
task_info["Task"].query("status != ['waiting','finished']")
# Out:
# Empty DataFrame
# Columns: [Alpha_Name, sequence, LR, epoch_num, feature_num, start_date, end_date, status, description]
# Index: []

# %%
task_info["Task"]
# Out:
#                                                 Alpha_Name sequence  \
# task_id
# 0                         Original_Input_Moving_10_Shift_5        5
# 1                         Original_Input_Moving_10_Shift_5        5
# 2                         Original_Input_Moving_10_Shift_5        5
# 3                         Original_Input_Moving_10_Shift_5        5
# 4                         Original_Input_Moving_10_Shift_5        5
# ...                                                    ...      ...
# 165      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 166      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 167      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 168      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 169      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
#
#                             LR     epoch_num feature_num  start_date  \
# task_id
# 0              [0.001, 0.0001]      [30, 20]         108  2019-01-01
# 1              [0.001, 0.0001]      [30, 20]         108  2019-06-01
# 2              [0.001, 0.0001]      [30, 20]         108  2020-01-01
# 3              [0.001, 0.0001]      [30, 20]         108  2020-06-01
# 4              [0.001, 0.0001]      [30, 20]         108  2021-01-01
# ...                        ...           ...         ...         ...
# 165      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2019-01-01
# 166      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2019-06-01
# 167      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2020-01-01
# 168      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2020-06-01
# 169      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2021-01-01
#
#            end_date    status  \
# task_id
# 0        2019-06-01  finished
# 1        2020-01-01  finished
# 2        2020-06-01  finished
# 3        2021-01-01  finished
# 4        2021-06-01  finished
# ...             ...       ...
# 165      2019-06-01   waiting
# 166      2020-01-01   waiting
# 167      2020-06-01   waiting
# 168      2021-01-01   waiting
# 169      2021-06-01   waiting
#
#                                                description
# task_id
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 165      {'target': '10d_ret_standscalar', 'alpha_name'...
# 166      {'target': '10d_ret_standscalar', 'alpha_name'...
# 167      {'target': '10d_ret_standscalar', 'alpha_name'...
# 168      {'target': '10d_ret_standscalar', 'alpha_name'...
# 169      {'target': '10d_ret_standscalar', 'alpha_name'...
#
# [170 rows x 9 columns]

# %%
task_info["Task"][-20:]
# Out:
#                                                 Alpha_Name sequence  \
# task_id
# 150      AlphaNetV1_Shift_1_Sequence_20_10d_ret_standsc...       20
# 151      AlphaNetV1_Shift_1_Sequence_20_10d_ret_standsc...       20
# 152      AlphaNetV1_Shift_1_Sequence_20_10d_ret_standsc...       20
# 153      AlphaNetV1_Shift_1_Sequence_20_10d_ret_standsc...       20
# 154      AlphaNetV1_Shift_1_Sequence_20_10d_ret_standsc...       20
# 155      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 156      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 157      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 158      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 159      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 160      Original_Input_Ts_Standard_Shift_1_Sequence_30...       30
# 161      Original_Input_Ts_Standard_Shift_1_Sequence_30...       30
# 162      Original_Input_Ts_Standard_Shift_1_Sequence_30...       30
# 163      Original_Input_Ts_Standard_Shift_1_Sequence_30...       30
# 164      Original_Input_Ts_Standard_Shift_1_Sequence_30...       30
# 165      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 166      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 167      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 168      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
# 169      Attention_8Input_Shift_1_Sequence_20_10d_ret_s...       20
#
#                             LR     epoch_num feature_num  start_date  \
# task_id
# 150      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2019-01-01
# 151      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2019-06-01
# 152      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2020-01-01
# 153      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2020-06-01
# 154      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2021-01-01
# 155      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2019-01-01
# 156      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2019-06-01
# 157      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2020-01-01
# 158      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2020-06-01
# 159      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2021-01-01
# 160      [0.001, 1e-05, 1e-07]  [30, 30, 30]           9  2019-01-01
# 161      [0.001, 1e-05, 1e-07]  [30, 30, 30]           9  2019-06-01
# 162      [0.001, 1e-05, 1e-07]  [30, 30, 30]           9  2020-01-01
# 163      [0.001, 1e-05, 1e-07]  [30, 30, 30]           9  2020-06-01
# 164      [0.001, 1e-05, 1e-07]  [30, 30, 30]           9  2021-01-01
# 165      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2019-01-01
# 166      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2019-06-01
# 167      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2020-01-01
# 168      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2020-06-01
# 169      [0.001, 1e-05, 1e-07]  [30, 30, 30]          88  2021-01-01
#
#            end_date    status  \
# task_id
# 150      2019-06-01  finished
# 151      2020-01-01  finished
# 152      2020-06-01  finished
# 153      2021-01-01  finished
# 154      2021-06-01  finished
# 155      2019-06-01   waiting
# 156      2020-01-01   waiting
# 157      2020-06-01   waiting
# 158      2021-01-01   waiting
# 159      2021-06-01   waiting
# 160      2019-06-01  finished
# 161      2020-01-01  finished
# 162      2020-06-01  finished
# 163      2021-01-01  finished
# 164      2021-06-01  finished
# 165      2019-06-01   waiting
# 166      2020-01-01   waiting
# 167      2020-06-01   waiting
# 168      2021-01-01   waiting
# 169      2021-06-01   waiting
#
#                                                description
# task_id
# 150      {'target': '10d_ret_standscalar', 'alpha_name'...
# 151      {'target': '10d_ret_standscalar', 'alpha_name'...
# 152      {'target': '10d_ret_standscalar', 'alpha_name'...
# 153      {'target': '10d_ret_standscalar', 'alpha_name'...
# 154      {'target': '10d_ret_standscalar', 'alpha_name'...
# 155      {'target': '10d_ret_standscalar', 'alpha_name'...
# 156      {'target': '10d_ret_standscalar', 'alpha_name'...
# 157      {'target': '10d_ret_standscalar', 'alpha_name'...
# 158      {'target': '10d_ret_standscalar', 'alpha_name'...
# 159      {'target': '10d_ret_standscalar', 'alpha_name'...
# 160      {'target': '10d_ret_standscalar', 'alpha_name'...
# 161      {'target': '10d_ret_standscalar', 'alpha_name'...
# 162      {'target': '10d_ret_standscalar', 'alpha_name'...
# 163      {'target': '10d_ret_standscalar', 'alpha_name'...
# 164      {'target': '10d_ret_standscalar', 'alpha_name'...
# 165      {'target': '10d_ret_standscalar', 'alpha_name'...
# 166      {'target': '10d_ret_standscalar', 'alpha_name'...
# 167      {'target': '10d_ret_standscalar', 'alpha_name'...
# 168      {'target': '10d_ret_standscalar', 'alpha_name'...
# 169      {'target': '10d_ret_standscalar', 'alpha_name'...

# %%
task_info["Factor"]
# Out:
#                             Alpha_Name shift sequence               target  \
# factor_id
# 0          AlphaNet_ConcatMoving5And10     5        6  10d_ret_standscalar
# 1                    AlphaNet_No_Decay     5        6  10d_ret_standscalar
# 2                   AlphaNet_No_Return     5        6  10d_ret_standscalar
# 3                   AlphaNet_No_ZSCORE     5        6  10d_ret_standscalar
# 4                      AlphaNet_No_STD     5        6  10d_ret_standscalar
# 5                     AlphaNet_No_CORR     5        6  10d_ret_standscalar
# 6                      AlphaNet_No_COV     5        6  10d_ret_standscalar
# 7                           AlphaNetV1     1       20  10d_ret_standscalar
# 8                      AlphaNet_8Input     1       20  10d_ret_standscalar
# 9           Original_Input_Ts_Standard     1       30  10d_ret_standscalar
#
#                               LR     epoch_num  \
# factor_id
# 0          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 1          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 2          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 3          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 4          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 5          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 6          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 7          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 8          [0.001, 1e-05, 1e-07]  [30, 30, 30]
# 9          [0.001, 1e-05, 1e-07]  [30, 30, 30]
#
#                                                   alpha_list    status
# factor_id
# 0          [COV_open_high_5, COV_open_high_10, COV_open_l...  finished
# 1          [COV_open_high_10, COV_open_low_10, COV_open_c...  finished
# 2          [COV_open_high_10, COV_open_low_10, COV_open_c...  finished
# 3          [COV_open_high_10, COV_open_low_10, COV_open_c...  finished
# 4          [COV_open_high_10, COV_open_low_10, COV_open_c...  finished
# 5          [COV_open_high_10, COV_open_low_10, COV_open_c...  finished
# 6          [CORR_open_high_10, CORR_open_low_10, CORR_ope...  finished
# 7          [COV_open_high_10, COV_open_low_10, COV_open_c...  finished
# 8          [COV_div_open_close_div_high_close_10, COV_div...  finished
# 9          [open_ts_norm_30d, high_ts_norm_30d, low_ts_no...  finished

# %%
task_info["CPU"]
# Out:
# True

# %%
np.save("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",task_info)
