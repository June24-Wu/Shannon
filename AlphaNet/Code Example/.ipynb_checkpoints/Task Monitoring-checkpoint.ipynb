# %%
import pandas as pd 
import numpy as np

# %%
task_info = np.load("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",allow_pickle=True).item()

# %%
task_info["Cuda"]
# Out:
# ['cuda:1', 'cuda:1', 'cuda:1', 'cuda:0', 'cuda:0']

# %%
task_info["Task"].query("status == ['running','cuda:0','cuda:1']")
# Out:
# Empty DataFrame
# Columns: [Alpha_Name, sequence, LR, epoch_num, feature_num, start_date, end_date, status, description]
# Index: []

# %%
task_info["Task"]
# Out:
#                                                 Alpha_Name sequence  \
# task_id
# 0                         Original_Input_Moving_10_Shift_5        5
# 1                         Original_Input_Moving_10_Shift_5        5
# 2                         Original_Input_Moving_10_Shift_5        5
# 3                         Original_Input_Moving_10_Shift_5        5
# 4                         Original_Input_Moving_10_Shift_5        5
# ...                                                    ...      ...
# 115      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 116      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 117      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 118      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 119      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
#
#                             LR     epoch_num feature_num  start_date  \
# task_id
# 0              [0.001, 0.0001]      [30, 20]         108  2019-01-01
# 1              [0.001, 0.0001]      [30, 20]         108  2019-06-01
# 2              [0.001, 0.0001]      [30, 20]         108  2020-01-01
# 3              [0.001, 0.0001]      [30, 20]         108  2020-06-01
# 4              [0.001, 0.0001]      [30, 20]         108  2021-01-01
# ...                        ...           ...         ...         ...
# 115      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2019-01-01
# 116      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2019-06-01
# 117      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2020-01-01
# 118      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2020-06-01
# 119      [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2021-01-01
#
#            end_date    status  \
# task_id
# 0        2019-06-01  finished
# 1        2020-01-01  finished
# 2        2020-06-01  finished
# 3        2021-01-01  finished
# 4        2021-06-01  finished
# ...             ...       ...
# 115      2019-06-01  finished
# 116      2020-01-01  finished
# 117      2020-06-01  finished
# 118      2021-01-01  finished
# 119      2021-06-01  finished
#
#                                                description
# task_id
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 115      {'target': '10d_ret_standscalar', 'alpha_name'...
# 116      {'target': '10d_ret_standscalar', 'alpha_name'...
# 117      {'target': '10d_ret_standscalar', 'alpha_name'...
# 118      {'target': '10d_ret_standscalar', 'alpha_name'...
# 119      {'target': '10d_ret_standscalar', 'alpha_name'...
#
# [120 rows x 9 columns]

# %%
task_info["Task"][-20:]
# Out:
#                                                 Alpha_Name sequence  \
# task_id
# 100       AlphaNetV1_Shift_5_Sequence_6_1d_ret_standscalar        6
# 101       AlphaNetV1_Shift_5_Sequence_6_1d_ret_standscalar        6
# 102       AlphaNetV1_Shift_5_Sequence_6_1d_ret_standscalar        6
# 103       AlphaNetV1_Shift_5_Sequence_6_1d_ret_standscalar        6
# 104       AlphaNetV1_Shift_5_Sequence_6_1d_ret_standscalar        6
# 105       AlphaNetV1_Shift_5_Sequence_6_5d_ret_standscalar        6
# 106       AlphaNetV1_Shift_5_Sequence_6_5d_ret_standscalar        6
# 107       AlphaNetV1_Shift_5_Sequence_6_5d_ret_standscalar        6
# 108       AlphaNetV1_Shift_5_Sequence_6_5d_ret_standscalar        6
# 109       AlphaNetV1_Shift_5_Sequence_6_5d_ret_standscalar        6
# 110      AlphaNet_ConcatMoving5And10_Shift_5_Sequence_6...        6
# 111      AlphaNet_ConcatMoving5And10_Shift_5_Sequence_6...        6
# 112      AlphaNet_ConcatMoving5And10_Shift_5_Sequence_6...        6
# 113      AlphaNet_ConcatMoving5And10_Shift_5_Sequence_6...        6
# 114      AlphaNet_ConcatMoving5And10_Shift_5_Sequence_6...        6
# 115      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 116      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 117      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 118      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
# 119      AlphaNetV1_Shift_2_Sequence_15_10d_ret_standsc...       15
#
#                              LR     epoch_num feature_num  start_date  \
# task_id
# 100      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-01-01
# 101      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-06-01
# 102      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-01-01
# 103      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-06-01
# 104      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2021-01-01
# 105      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-01-01
# 106      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2019-06-01
# 107      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-01-01
# 108      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2020-06-01
# 109      [0.001, 0.0001, 1e-05]  [30, 30, 30]         108  2021-01-01
# 110       [0.001, 1e-05, 1e-07]  [30, 30, 30]         216  2019-01-01
# 111       [0.001, 1e-05, 1e-07]  [30, 30, 30]         216  2019-06-01
# 112       [0.001, 1e-05, 1e-07]  [30, 30, 30]         216  2020-01-01
# 113       [0.001, 1e-05, 1e-07]  [30, 30, 30]         216  2020-06-01
# 114       [0.001, 1e-05, 1e-07]  [30, 30, 30]         216  2021-01-01
# 115       [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2019-01-01
# 116       [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2019-06-01
# 117       [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2020-01-01
# 118       [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2020-06-01
# 119       [0.001, 1e-05, 1e-07]  [30, 30, 30]         108  2021-01-01
#
#            end_date    status  \
# task_id
# 100      2019-06-01  finished
# 101      2020-01-01  finished
# 102      2020-06-01  finished
# 103      2021-01-01  finished
# 104      2021-06-01  finished
# 105      2019-06-01  finished
# 106      2020-01-01  finished
# 107      2020-06-01  finished
# 108      2021-01-01  finished
# 109      2021-06-01  finished
# 110      2019-06-01  finished
# 111      2020-01-01  finished
# 112      2020-06-01  finished
# 113      2021-01-01  finished
# 114      2021-06-01  finished
# 115      2019-06-01  finished
# 116      2020-01-01  finished
# 117      2020-06-01  finished
# 118      2021-01-01  finished
# 119      2021-06-01  finished
#
#                                                description
# task_id
# 100      {'target': '1d_ret_standscalar', 'alpha_name':...
# 101      {'target': '1d_ret_standscalar', 'alpha_name':...
# 102      {'target': '1d_ret_standscalar', 'alpha_name':...
# 103      {'target': '1d_ret_standscalar', 'alpha_name':...
# 104      {'target': '1d_ret_standscalar', 'alpha_name':...
# 105      {'target': '5d_ret_standscalar', 'alpha_name':...
# 106      {'target': '5d_ret_standscalar', 'alpha_name':...
# 107      {'target': '5d_ret_standscalar', 'alpha_name':...
# 108      {'target': '5d_ret_standscalar', 'alpha_name':...
# 109      {'target': '5d_ret_standscalar', 'alpha_name':...
# 110      {'target': '10d_ret_standscalar', 'alpha_name'...
# 111      {'target': '10d_ret_standscalar', 'alpha_name'...
# 112      {'target': '10d_ret_standscalar', 'alpha_name'...
# 113      {'target': '10d_ret_standscalar', 'alpha_name'...
# 114      {'target': '10d_ret_standscalar', 'alpha_name'...
# 115      {'target': '10d_ret_standscalar', 'alpha_name'...
# 116      {'target': '10d_ret_standscalar', 'alpha_name'...
# 117      {'target': '10d_ret_standscalar', 'alpha_name'...
# 118      {'target': '10d_ret_standscalar', 'alpha_name'...
# 119      {'target': '10d_ret_standscalar', 'alpha_name'...

# %%
np.save("/home/ShareFolder/feature_platform/ti0/wuwenjun/#Factor_Description/Task.npy",task_info)
