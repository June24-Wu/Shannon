# %%
import pandas as pd 
import numpy as np
import torch
import torch.nn as nn
data = pd.read_csv('alphanet_codetest_daily.csv')
# 定义数据图片开始和结束的时间
time_start = 20190801
time_end = 20211001


stock = pd.DataFrame(data.groupby('ticker')['timestamp'].count() == 487).reset_index()
merge = data.merge(stock, on='ticker', how='left')
merge = merge[merge['timestamp_y'] == True]
merge['timestamp'] = merge['timestamp_x']
merge = merge[['timestamp','ticker','open','high','low','close','vwap','volume','pct_chg','turnover','free_turnover']] # feature
merge = merge[(merge['timestamp'] >= time_start) & (merge['timestamp'] <= time_end)]
merge
# Out:
#          timestamp  ticker    open    high     low   close      vwap  \
# 0         20190923       1   15.34   15.47   15.18   15.38   15.3122
# 1         20190923       2   26.49   26.49   26.00   26.15   26.1471
# 2         20190923       4   20.36   20.65   19.61   20.04   20.0171
# 3         20190923       5    3.37    3.37    3.27    3.30    3.2947
# 4         20190923       6    5.34    5.40    5.21    5.38    5.2993
# ...            ...     ...     ...     ...     ...     ...       ...
# 1958151   20210923  688168   52.80   53.30   52.00   52.45   52.5581
# 1958162   20210923  688188  446.80  449.00  425.20  438.14  438.5992
# 1958216   20210923  688321   39.20   39.30   38.64   38.90   38.8391
# 1958221   20210923  688333  199.87  201.01  192.01  200.34  196.4810
# 1958246   20210923  688388  136.00  136.85  130.45  134.93  134.5550
#
#              volume  pct_chg  turnover  free_turnover
# 0        1403282.00   0.2608    0.7428         1.5038
# 1         603530.46  -2.4254    0.6212         1.0882
# 2          29893.32  -4.7076    3.6188         5.9394
# 3         111437.30  -2.0772    1.0533         1.3495
# 4         136997.47   1.1278    1.0161         1.5887
# ...             ...      ...       ...            ...
# 1958151     5919.73   1.0792    2.0771         2.1589
# 1958162     4444.64  -1.6830    1.6540         1.6540
# 1958216    14252.01   0.0772    0.5631         0.6717
# 1958221     4126.57   0.6177    0.9092         0.9092
# 1958246    61087.12   0.3272    3.6459         3.9295
#
# [1772680 rows x 11 columns]

# %%
day_back = 3 # 回溯几天进行计算
day = 30 # 一次提取几天的数,一般默认为30
stride = 10 # 一次学习多少天


x , y , x_delay = [] , [], [] # 初始数据集

for count , ticker in enumerate(merge['ticker'].drop_duplicates()):
#     print(count)
    one_data = merge[merge['ticker'] == ticker]
    one_data['pct_change_shift'] = (one_data['close'].shift(-day_back) - one_data['close']) / one_data['close'] * 100
    one_data = one_data.set_index(['timestamp','ticker'])
    one_data = one_data.dropna() # 丢弃因为回溯而产生的空值
    array = np.array(one_data)

    for i in range(0,array.shape[0] - day ,3): # 其中3 代表取数的步长，ex.每两天取一次数，步长为3
        x.append(array[i:i+day,:-1].T)
        y.append(array[i+day-1][-1])
x  , y = np.array(x) , np.array(y).reshape(-1,1) # x = (153, 9, 30) , y = (153,1)
x = x.reshape(x.shape[0],1,x.shape[1],x.shape[2]) # x = (153, 1, 9, 30)
print("x.shape: ",x.shape)
print("y.shape: ",y.shape)
# Out:
# C:\Users\Xinfei\AppData\Local\Temp/ipykernel_8160/2247197430.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_data['pct_change_shift'] = (one_data['close'].shift(-day_back) - one_data['close']) / one_data['close'] * 100
# x.shape:  (553277, 1, 9, 30)
# y.shape:  (553277, 1)

# %%
class Convolutional(object):
    def __init__(self,data,stride):
        if len(data.shape)!=4:
            raise Exception('Input data dimensions should be [N,C,H,W]')
        self.data = np.array(data)
        self.stride = stride
        self.data_length = data.shape[3]
        self.feat_num = data.shape[2] # 9
        self.num , self.num_rev = self.generate_Num_and_ReversedNum(self.feat_num)
        self.conv_feat = len(self.num)
        self.step_list = self.generate_Step_List(self.data_length,self.stride)
        self.extracted_data = self.Extraction(self.data,self.feat_num,self.conv_feat,self.stride)
    def Extraction(self,data,feat_num,conv_feat,stride):
        print("------Start Extraction------")
        batch = nn.BatchNorm1d(conv_feat,affine=True)
        batch2 = nn.BatchNorm1d(feat_num,affine=True)
        conv1 = self.ts_cov4d(self.data,self.stride,self.num,self.num_rev,self.step_list)
        conv2 = self.ts_corr4d(self.data,self.stride,self.num,self.num_rev,self.step_list,conv1)
        conv2 = torch.tanh(conv2)
        bc1 = batch(conv1.to(torch.float))
        bc2 = batch(conv2.to(torch.float))
        conv3 = self.ts_stddev4d(self.data,self.stride,self.feat_num,self.step_list).to(torch.float)
        bc3 = batch2(conv3)
        conv4 = self.ts_zscore(self.data,self.stride,self.feat_num,self.step_list).to(torch.float)
        bc4 = batch2(conv4)
        conv5 = self.ts_return(self.data,self.stride,self.feat_num,self.step_list).to(torch.float)
        bc5 = batch2(conv5)
        conv6 = self.ts_decaylinear(self.data,self.stride,self.feat_num,self.step_list).to(torch.float)
        bc6 = batch2(conv6)

        feat_cat = torch.cat([bc1,bc2,bc3,bc4,bc5,bc6],axis = 1) # 特征聚合
        shape = feat_cat.shape
        feat_cat = feat_cat.reshape(shape[0],1,shape[1],shape[2])
        print("Convolutional shape: ", feat_cat.shape)
        return feat_cat
    def generateC(self,l1):
        if len(l1) == 1:
            return []
        v = [[l1[0],i] for i in l1[1:]]
        l1 = l1[1:]
        return v+ self.generateC(l1)
    def generate_Num_and_ReversedNum(self,feat_nums):
        list1 = list(range(feat_nums))
        num = self.generateC(list1)
        num_rev = []
        for l in num:
            l1 = l.copy()
            l1.reverse()
            num_rev.append(l1)
        return num , num_rev
    def generate_Step_List(self,data_length,stride):
        # 构建步长列表，如果数据长度不能整除，则取剩下长度，如果剩下长度小于5，则与上一步结合一起
        if data_length % stride == 0:
            step_list = list(range(0,data_length+stride,stride))
        elif data_length % stride<=5:
            mod = data_length % stride
            step_list = list(range(0,data_length-stride,stride))+[data_length]
        else:
            mod = data_length % stride
            step_list = list(range(0,data_length+stride-mod,stride))+[data_length]
        return step_list
    def ts_cov4d(self,data,stride,num,num_rev,step_list):
        '''计算4维数据的协方差'''
        '''data:[N,C,H,W],,W:price length,N:batch size'''
        l = []
        #计算的过程中务必保持keepdims=True
        for i in range(len(step_list)-1):
            start = step_list[i]
            end = step_list[i+1]
            sub_data1 = data[:,:,num,start:end] # (2000, 1, 36, 2, 10)
            sub_data2 = data[:,:,num_rev,start:end]
            mean1 = sub_data1.mean(axis = 4,keepdims = True) # (2000, 1, 36, 2, 1)
            mean2 = sub_data2.mean(axis = 4,keepdims = True)
            spread1 = sub_data1 - mean1 # (2000, 1, 36, 2, 10)
            spread2 = sub_data2 - mean2
            cov = ((spread1*spread2).sum(axis = 4,keepdims = True)/(sub_data1.shape[4] - 1)).mean(axis = 3,keepdims = True) # (2000, 1, 36, 1, 1)
            l.append(cov)
        corr = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,self.conv_feat,len(step_list)-1) # (2000, 1, 36, 3)
        final = torch.from_numpy(corr)
        print("------Finished ts_cov4d----output shape: ",final.shape)
        return final
    def ts_corr4d(self,data,stride,num,num_rev,step_list,cov):
        '''计算4维数据的相关系数'''
        '''data:[N,C,H,W],,W:price length,N:batch size'''
        l = []
        for i in range(len(step_list)-1):
            start = step_list[i]
            end = step_list[i+1]
            sub_data1 = data[:,:,num,start:end]
            sub_data2 = data[:,:,num_rev,start:end]
            std1 = sub_data1.std(axis = 4,keepdims = True)
            std2 = sub_data2.std(axis = 4,keepdims = True)
            std = (std1*std2).mean(axis = 3,keepdims = True)
            del std1 , std2 # 释放内存
            l.append(std)
        std = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,self.conv_feat,len(step_list)-1)
        std[std == 0] = 1e-9
        fct = (sub_data1.shape[4]-1)/sub_data1.shape[4]
        final = cov / torch.from_numpy(std) * fct
        del fct , std
        print("------Finished ts_corr4d----output shape: ",final.shape)
        return final
    def ts_stddev4d(self,data,stride,feat_num,step_list):
        if len(data.shape)!=4:
            raise Exception('Input data dimensions should be [N,C,H,W]')
        l = []
        for i in range(len(step_list)-1):
            start = step_list[i]
            end = step_list[i+1]
            sub_data1 = data[:,:,:,start:end]
            std1 = sub_data1.std(axis = 3,keepdims = True)
            l.append(std1)
            del std1
        std = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,feat_num,len(step_list)-1)
        print("------Finished ts_stddev4d----output shape: ",torch.from_numpy(std).shape)
        return torch.from_numpy(std)
    def ts_zscore(self,data,stride,feat_num,step_list):
        if len(data.shape)!=4:
            raise Exception('Input data dimensions should be [N,C,H,W]')
        l = []
        for i in range(len(step_list)-1):
            start = step_list[i]
            end = step_list[i+1]
            sub_data1 = data[:,:,:,start:end]
            mean = sub_data1.mean(axis = 3,keepdims = True)
            std = sub_data1.std(axis = 3,keepdims = True)
            std[std == 0] = 1e-9
            z_score = mean/std
            l.append(z_score)
        z_score = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,feat_num,len(step_list)-1)
        z_score[z_score >= 6] = 6
        print("------Finished ts_zscore----output shape: ",torch.from_numpy(z_score).shape)
        return torch.from_numpy(z_score)
    def ts_return(self,data,stride,feat_num,step_list):
        if len(data.shape)!=4:
            raise Exception('Input data dimensions should be [N,C,H,W]')
        data[data == 0] = 1e-9
        l = []
        for i in range(len(step_list)-1):
            start = step_list[i]
            end = step_list[i+1]
            sub_data1 = data[:,:,:,start:end]
            ret = sub_data1[:,:,:,-1]/sub_data1[:,:,:,0] - 1
            l.append(ret)
        z_data = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,feat_num,len(step_list)-1)
        z_data[z_data > 1] = 1
        print("------Finished ts_return----output shape: ",torch.from_numpy(z_data).shape)
        return torch.from_numpy(z_data)
    def ts_decaylinear(self,data,stride,feat_num,step_list):
        if len(data.shape)!=4:
            raise Exception('Input data dimensions should be [N,C,H,W]')
        l = []
        for i in range(len(step_list)-1):
            start = step_list[i]
            end = step_list[i+1]
            time_spread = end - start
            weight = np.arange(1,time_spread+1)
            weight = weight/(weight.sum())
            sub_data1 = (data[:,:,:,start:end]*weight).mean(axis = 3,keepdims = True)
            l.append(sub_data1)
        decay_data = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,feat_num,len(step_list)-1)
        final = torch.from_numpy(decay_data)
        print("------Finished ts_decaylinear----output shape: ",final.shape)
        return final

# %%
class Pooling(object):
    def __init__(self,data,stride):
        if len(data.shape)!=4:
            raise Exception('Input data dimensions should be [N,C,H,W]')
        self.data = data.detach().numpy()
        self.stride = stride
        self.data_length = data.shape[3]
        self.feat_num = data.shape[2] # 9
        self.step_list = self.generate_Step_List(self.data_length,self.stride)
        self.extracted_data = self.Extraction(self.data,self.feat_num,self.stride)
    def Extraction(self,data,feat_num,stride):
        print("------Start Pooling------")
        # Pooling
        ts_max = self.ts_pool(feat_cat,self.stride,self.feat_num,self.step_list,method = 'max')
        ts_max = nn.BatchNorm1d(108,affine = True)(ts_max)
        ts_min = self.ts_pool(feat_cat ,self.stride,self.feat_num,self.step_list,method = 'min')
        ts_min = nn.BatchNorm1d(108,affine = True)(ts_min)
        ts_mean = self.ts_pool(feat_cat ,self.stride,self.feat_num,self.step_list,method = 'mean')
        ts_mean = nn.BatchNorm1d(108,affine = True)(ts_mean)
        data_pool = torch.cat([ts_max,ts_min,ts_mean],axis = 1)
        data_pool = data_pool.flatten(start_dim = 1)
        print("Pooling shape: ",data_pool.shape )
        return data_pool
    def generate_Step_List(self,data_length,stride):
        # 构建步长列表，如果数据长度不能整除，则取剩下长度，如果剩下长度小于5，则与上一步结合一起
        if data_length % stride == 0:
            step_list = list(range(0,data_length+stride,stride))
        elif data_length % stride<=5:
            mod = data_length % stride
            step_list = list(range(0,data_length-stride,stride))+[data_length]
        else:
            mod = data_length % stride
            step_list = list(range(0,data_length+stride-mod,stride))+[data_length]
        return step_list
    def ts_pool(self,data,stride,feat_num,step_list,method):
        if type(data) == torch.Tensor:
            data = data.detach().numpy()
        if data.shape[-1] <= stride:
            step_list = [0,data.shape[-1]]
        if len(data.shape)!=4:
            raise Exception('Input data dimensions should be [N,C,H,W]')
        l = []
        for i in range(len(step_list)-1):
            start = step_list[i]
            end = step_list[i+1]
            if method == 'max':
                sub_data1 = data[:,:,:,start:end].max(axis = 3,keepdims = True)
            if method == 'min':
                sub_data1 = data[:,:,:,start:end].min(axis = 3,keepdims = True)
            if method == 'mean':
                sub_data1 = data[:,:,:,start:end].mean(axis = 3,keepdims = True)
            l.append(sub_data1)
        try:
            pool_data = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,feat_num,len(step_list) - 1)
        except:
            pool_data = np.squeeze(np.array(l)).reshape(-1,feat_num,len(step_list) - 1)
        return torch.from_numpy(pool_data)

# %%
convolutional = Convolutional(x,10)
feat_cat = convolutional.extracted_data
pooling = Pooling(feat_cat,3)
x = pooling.extracted_data.detach().numpy()
print("x.shape : ",x.shape)
print("y.shape : ",y.shape)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8160/4003039903.py in <module>
# ----> 1 convolutional = Convolutional(x,10)
#       2 feat_cat = convolutional.extracted_data
#       3 pooling = Pooling(feat_cat,3)
#       4 x = pooling.extracted_data.detach().numpy()
#       5 print("x.shape : ",x.shape)
#
# ~\AppData\Local\Temp/ipykernel_8160/2375768201.py in __init__(self, data, stride)
#       2     def __init__(self,data,stride):
#       3         if len(data.shape)!=4:
# ----> 4             raise Exception('Input data dimensions should be [N,C,H,W]')
#       5         self.data = np.array(data)
#       6         self.stride = stride
#
# Exception: Input data dimensions should be [N,C,H,W]

# %%
from torch.utils.data import Dataset, DataLoader
# x = np.random.uniform(10,100,(3124,1,9,30))
# y = np.random.randn(3124,1)
class Testdataset(Dataset):
    def __init__(self, data,label):
        self.data = torch.from_numpy(data)
        self.label = torch.from_numpy(label)
    def __getitem__(self, index):
        return self.data[index], self.label[index]
    def __len__(self):
        return len(self.data)
trainset = Testdataset(x,y)
trainloader = DataLoader(trainset,batch_size = 200,shuffle = False)
for i,data in enumerate(trainloader):
    input_data,label = data
    print(i,input_data.size())
# Out:
# 0 torch.Size([200, 324])
# 1 torch.Size([200, 324])
# 2 torch.Size([200, 324])
# 3 torch.Size([200, 324])
# 4 torch.Size([200, 324])
# 5 torch.Size([200, 324])
# 6 torch.Size([200, 324])
# 7 torch.Size([200, 324])
# 8 torch.Size([200, 324])
# 9 torch.Size([200, 324])
# 10 torch.Size([200, 324])
# 11 torch.Size([200, 324])
# 12 torch.Size([200, 324])
# 13 torch.Size([200, 324])
# 14 torch.Size([200, 324])
# 15 torch.Size([200, 324])
# 16 torch.Size([200, 324])
# 17 torch.Size([200, 324])
# 18 torch.Size([200, 324])
# 19 torch.Size([200, 324])
# 20 torch.Size([200, 324])
# 21 torch.Size([200, 324])
# 22 torch.Size([200, 324])
# 23 torch.Size([200, 324])
# 24 torch.Size([200, 324])
# 25 torch.Size([200, 324])
# 26 torch.Size([200, 324])
# 27 torch.Size([200, 324])
# 28 torch.Size([200, 324])
# 29 torch.Size([200, 324])
# 30 torch.Size([200, 324])
# 31 torch.Size([200, 324])
# 32 torch.Size([200, 324])
# 33 torch.Size([200, 324])
# 34 torch.Size([200, 324])
# 35 torch.Size([200, 324])
# 36 torch.Size([200, 324])
# 37 torch.Size([200, 324])
# 38 torch.Size([200, 324])
# 39 torch.Size([200, 324])
# 40 torch.Size([200, 324])
# 41 torch.Size([200, 324])
# 42 torch.Size([200, 324])
# 43 torch.Size([200, 324])
# 44 torch.Size([200, 324])
# 45 torch.Size([200, 324])
# 46 torch.Size([200, 324])
# 47 torch.Size([200, 324])
# 48 torch.Size([200, 324])
# 49 torch.Size([200, 324])
# 50 torch.Size([200, 324])
# 51 torch.Size([200, 324])
# 52 torch.Size([200, 324])
# 53 torch.Size([200, 324])
# 54 torch.Size([200, 324])
# 55 torch.Size([200, 324])
# 56 torch.Size([200, 324])
# 57 torch.Size([200, 324])
# 58 torch.Size([200, 324])
# 59 torch.Size([200, 324])
# 60 torch.Size([200, 324])
# 61 torch.Size([200, 324])
# 62 torch.Size([200, 324])
# 63 torch.Size([200, 324])
# 64 torch.Size([200, 324])
# 65 torch.Size([200, 324])
# 66 torch.Size([200, 324])
# 67 torch.Size([200, 324])
# 68 torch.Size([200, 324])
# 69 torch.Size([200, 324])
# 70 torch.Size([200, 324])
# 71 torch.Size([200, 324])
# 72 torch.Size([200, 324])
# 73 torch.Size([200, 324])
# 74 torch.Size([200, 324])
# 75 torch.Size([200, 324])
# 76 torch.Size([200, 324])
# 77 torch.Size([200, 324])
# 78 torch.Size([200, 324])
# 79 torch.Size([200, 324])
# 80 torch.Size([200, 324])
# 81 torch.Size([200, 324])
# 82 torch.Size([200, 324])
# 83 torch.Size([200, 324])
# 84 torch.Size([200, 324])
# 85 torch.Size([200, 324])
# 86 torch.Size([200, 324])
# 87 torch.Size([200, 324])
# 88 torch.Size([200, 324])
# 89 torch.Size([200, 324])
# 90 torch.Size([200, 324])
# 91 torch.Size([200, 324])
# 92 torch.Size([200, 324])
# 93 torch.Size([200, 324])
# 94 torch.Size([200, 324])
# 95 torch.Size([200, 324])
# 96 torch.Size([200, 324])
# 97 torch.Size([200, 324])
# 98 torch.Size([200, 324])
# 99 torch.Size([200, 324])
# 100 torch.Size([200, 324])
# 101 torch.Size([200, 324])
# 102 torch.Size([200, 324])
# 103 torch.Size([200, 324])
# 104 torch.Size([200, 324])
# 105 torch.Size([200, 324])
# 106 torch.Size([200, 324])
# 107 torch.Size([200, 324])
# 108 torch.Size([200, 324])
# 109 torch.Size([200, 324])
# 110 torch.Size([200, 324])
# 111 torch.Size([200, 324])
# 112 torch.Size([200, 324])
# 113 torch.Size([200, 324])
# 114 torch.Size([200, 324])
# 115 torch.Size([200, 324])
# 116 torch.Size([200, 324])
# 117 torch.Size([200, 324])
# 118 torch.Size([200, 324])
# 119 torch.Size([200, 324])
# 120 torch.Size([200, 324])
# 121 torch.Size([200, 324])
# 122 torch.Size([200, 324])
# 123 torch.Size([200, 324])
# 124 torch.Size([200, 324])
# 125 torch.Size([200, 324])
# 126 torch.Size([200, 324])
# 127 torch.Size([200, 324])
# 128 torch.Size([200, 324])
# 129 torch.Size([200, 324])
# 130 torch.Size([200, 324])
# 131 torch.Size([200, 324])
# 132 torch.Size([200, 324])
# 133 torch.Size([200, 324])
# 134 torch.Size([200, 324])
# 135 torch.Size([200, 324])
# 136 torch.Size([200, 324])
# 137 torch.Size([200, 324])
# 138 torch.Size([200, 324])
# 139 torch.Size([200, 324])
# 140 torch.Size([200, 324])
# 141 torch.Size([200, 324])
# 142 torch.Size([200, 324])
# 143 torch.Size([200, 324])
# 144 torch.Size([200, 324])
# 145 torch.Size([200, 324])
# 146 torch.Size([200, 324])
# 147 torch.Size([200, 324])
# 148 torch.Size([200, 324])
# 149 torch.Size([200, 324])
# 150 torch.Size([200, 324])
# 151 torch.Size([200, 324])
# 152 torch.Size([200, 324])
# 153 torch.Size([200, 324])
# 154 torch.Size([200, 324])
# 155 torch.Size([200, 324])
# 156 torch.Size([200, 324])
# 157 torch.Size([200, 324])
# 158 torch.Size([200, 324])
# 159 torch.Size([200, 324])
# 160 torch.Size([200, 324])
# 161 torch.Size([200, 324])
# 162 torch.Size([200, 324])
# 163 torch.Size([200, 324])
# 164 torch.Size([200, 324])
# 165 torch.Size([200, 324])
# 166 torch.Size([200, 324])
# 167 torch.Size([200, 324])
# 168 torch.Size([200, 324])
# 169 torch.Size([200, 324])
# 170 torch.Size([200, 324])
# 171 torch.Size([200, 324])
# 172 torch.Size([200, 324])
# 173 torch.Size([200, 324])
# 174 torch.Size([200, 324])
# 175 torch.Size([200, 324])
# 176 torch.Size([200, 324])
# 177 torch.Size([200, 324])
# 178 torch.Size([200, 324])
# 179 torch.Size([200, 324])
# 180 torch.Size([200, 324])
# 181 torch.Size([200, 324])
# 182 torch.Size([200, 324])
# 183 torch.Size([200, 324])
# 184 torch.Size([200, 324])
# 185 torch.Size([200, 324])
# 186 torch.Size([200, 324])
# 187 torch.Size([200, 324])
# 188 torch.Size([200, 324])
# 189 torch.Size([200, 324])
# 190 torch.Size([200, 324])
# 191 torch.Size([200, 324])
# 192 torch.Size([200, 324])
# 193 torch.Size([200, 324])
# 194 torch.Size([200, 324])
# 195 torch.Size([200, 324])
# 196 torch.Size([200, 324])
# 197 torch.Size([200, 324])
# 198 torch.Size([200, 324])
# 199 torch.Size([200, 324])
# 200 torch.Size([200, 324])
# 201 torch.Size([200, 324])
# 202 torch.Size([200, 324])
# 203 torch.Size([200, 324])
# 204 torch.Size([200, 324])
# 205 torch.Size([200, 324])
# 206 torch.Size([200, 324])
# 207 torch.Size([200, 324])
# 208 torch.Size([200, 324])
# 209 torch.Size([200, 324])
# 210 torch.Size([200, 324])
# 211 torch.Size([200, 324])
# 212 torch.Size([200, 324])
# 213 torch.Size([200, 324])
# 214 torch.Size([200, 324])
# 215 torch.Size([200, 324])
# 216 torch.Size([200, 324])
# 217 torch.Size([200, 324])
# 218 torch.Size([200, 324])
# 219 torch.Size([200, 324])
# 220 torch.Size([200, 324])
# 221 torch.Size([200, 324])
# 222 torch.Size([200, 324])
# 223 torch.Size([200, 324])
# 224 torch.Size([200, 324])
# 225 torch.Size([200, 324])
# 226 torch.Size([200, 324])
# 227 torch.Size([200, 324])
# 228 torch.Size([200, 324])
# 229 torch.Size([200, 324])
# 230 torch.Size([200, 324])
# 231 torch.Size([200, 324])
# 232 torch.Size([200, 324])
# 233 torch.Size([200, 324])
# 234 torch.Size([200, 324])
# 235 torch.Size([200, 324])
# 236 torch.Size([200, 324])
# 237 torch.Size([200, 324])
# 238 torch.Size([200, 324])
# 239 torch.Size([200, 324])
# 240 torch.Size([200, 324])
# 241 torch.Size([200, 324])
# 242 torch.Size([200, 324])
# 243 torch.Size([200, 324])
# 244 torch.Size([200, 324])
# 245 torch.Size([200, 324])
# 246 torch.Size([200, 324])
# 247 torch.Size([200, 324])
# 248 torch.Size([200, 324])
# 249 torch.Size([200, 324])
# 250 torch.Size([200, 324])
# 251 torch.Size([200, 324])
# 252 torch.Size([200, 324])
# 253 torch.Size([200, 324])
# 254 torch.Size([200, 324])
# 255 torch.Size([200, 324])
# 256 torch.Size([200, 324])
# 257 torch.Size([200, 324])
# 258 torch.Size([200, 324])
# 259 torch.Size([200, 324])
# 260 torch.Size([200, 324])
# 261 torch.Size([200, 324])
# 262 torch.Size([200, 324])
# 263 torch.Size([200, 324])
# 264 torch.Size([200, 324])
# 265 torch.Size([200, 324])
# 266 torch.Size([200, 324])
# 267 torch.Size([200, 324])
# 268 torch.Size([200, 324])
# 269 torch.Size([200, 324])
# 270 torch.Size([200, 324])
# 271 torch.Size([200, 324])
# 272 torch.Size([200, 324])
# 273 torch.Size([200, 324])
# 274 torch.Size([200, 324])
# 275 torch.Size([200, 324])
# 276 torch.Size([200, 324])
# 277 torch.Size([200, 324])
# 278 torch.Size([200, 324])
# 279 torch.Size([200, 324])
# 280 torch.Size([200, 324])
# 281 torch.Size([200, 324])
# 282 torch.Size([200, 324])
# 283 torch.Size([200, 324])
# 284 torch.Size([200, 324])
# 285 torch.Size([200, 324])
# 286 torch.Size([200, 324])
# 287 torch.Size([200, 324])
# 288 torch.Size([200, 324])
# 289 torch.Size([200, 324])
# 290 torch.Size([200, 324])
# 291 torch.Size([200, 324])
# 292 torch.Size([200, 324])
# 293 torch.Size([200, 324])
# 294 torch.Size([200, 324])
# 295 torch.Size([200, 324])
# 296 torch.Size([200, 324])
# 297 torch.Size([200, 324])
# 298 torch.Size([200, 324])
# 299 torch.Size([200, 324])
# 300 torch.Size([200, 324])
# 301 torch.Size([200, 324])
# 302 torch.Size([200, 324])
# 303 torch.Size([200, 324])
# 304 torch.Size([200, 324])
# 305 torch.Size([200, 324])
# 306 torch.Size([200, 324])
# 307 torch.Size([200, 324])
# 308 torch.Size([200, 324])
# 309 torch.Size([200, 324])
# 310 torch.Size([200, 324])
# 311 torch.Size([200, 324])
# 312 torch.Size([200, 324])
# 313 torch.Size([200, 324])
# 314 torch.Size([200, 324])
# 315 torch.Size([200, 324])
# 316 torch.Size([200, 324])
# 317 torch.Size([200, 324])
# 318 torch.Size([200, 324])
# 319 torch.Size([200, 324])
# 320 torch.Size([200, 324])
# 321 torch.Size([200, 324])
# 322 torch.Size([200, 324])
# 323 torch.Size([200, 324])
# 324 torch.Size([200, 324])
# 325 torch.Size([200, 324])
# 326 torch.Size([200, 324])
# 327 torch.Size([200, 324])
# 328 torch.Size([200, 324])
# 329 torch.Size([200, 324])
# 330 torch.Size([200, 324])
# 331 torch.Size([200, 324])
# 332 torch.Size([200, 324])
# 333 torch.Size([200, 324])
# 334 torch.Size([200, 324])
# 335 torch.Size([200, 324])
# 336 torch.Size([200, 324])
# 337 torch.Size([200, 324])
# 338 torch.Size([200, 324])
# 339 torch.Size([200, 324])
# 340 torch.Size([200, 324])
# 341 torch.Size([200, 324])
# 342 torch.Size([200, 324])
# 343 torch.Size([200, 324])
# 344 torch.Size([200, 324])
# 345 torch.Size([200, 324])
# 346 torch.Size([200, 324])
# 347 torch.Size([200, 324])
# 348 torch.Size([200, 324])
# 349 torch.Size([200, 324])
# 350 torch.Size([200, 324])
# 351 torch.Size([200, 324])
# 352 torch.Size([200, 324])
# 353 torch.Size([200, 324])
# 354 torch.Size([200, 324])
# 355 torch.Size([200, 324])
# 356 torch.Size([200, 324])
# 357 torch.Size([200, 324])
# 358 torch.Size([200, 324])
# 359 torch.Size([200, 324])
# 360 torch.Size([200, 324])
# 361 torch.Size([200, 324])
# 362 torch.Size([200, 324])
# 363 torch.Size([200, 324])
# 364 torch.Size([200, 324])
# 365 torch.Size([200, 324])
# 366 torch.Size([200, 324])
# 367 torch.Size([200, 324])
# 368 torch.Size([200, 324])
# 369 torch.Size([200, 324])
# 370 torch.Size([200, 324])
# 371 torch.Size([200, 324])
# 372 torch.Size([200, 324])
# 373 torch.Size([200, 324])
# 374 torch.Size([200, 324])
# 375 torch.Size([200, 324])
# 376 torch.Size([200, 324])
# 377 torch.Size([200, 324])
# 378 torch.Size([200, 324])
# 379 torch.Size([200, 324])
# 380 torch.Size([200, 324])
# 381 torch.Size([200, 324])
# 382 torch.Size([200, 324])
# 383 torch.Size([200, 324])
# 384 torch.Size([200, 324])
# 385 torch.Size([200, 324])
# 386 torch.Size([200, 324])
# 387 torch.Size([200, 324])
# 388 torch.Size([200, 324])
# 389 torch.Size([200, 324])
# 390 torch.Size([200, 324])
# 391 torch.Size([200, 324])
# 392 torch.Size([200, 324])
# 393 torch.Size([200, 324])
# 394 torch.Size([200, 324])
# 395 torch.Size([200, 324])
# 396 torch.Size([200, 324])
# 397 torch.Size([200, 324])
# 398 torch.Size([200, 324])
# 399 torch.Size([200, 324])
# 400 torch.Size([200, 324])
# 401 torch.Size([200, 324])
# 402 torch.Size([200, 324])
# 403 torch.Size([200, 324])
# 404 torch.Size([200, 324])
# 405 torch.Size([200, 324])
# 406 torch.Size([200, 324])
# 407 torch.Size([200, 324])
# 408 torch.Size([200, 324])
# 409 torch.Size([200, 324])
# 410 torch.Size([200, 324])
# 411 torch.Size([200, 324])
# 412 torch.Size([200, 324])
# 413 torch.Size([200, 324])
# 414 torch.Size([200, 324])
# 415 torch.Size([200, 324])
# 416 torch.Size([200, 324])
# 417 torch.Size([200, 324])
# 418 torch.Size([200, 324])
# 419 torch.Size([200, 324])
# 420 torch.Size([200, 324])
# 421 torch.Size([200, 324])
# 422 torch.Size([200, 324])
# 423 torch.Size([200, 324])
# 424 torch.Size([200, 324])
# 425 torch.Size([200, 324])
# 426 torch.Size([200, 324])
# 427 torch.Size([200, 324])
# 428 torch.Size([200, 324])
# 429 torch.Size([200, 324])
# 430 torch.Size([200, 324])
# 431 torch.Size([200, 324])
# 432 torch.Size([200, 324])
# 433 torch.Size([200, 324])
# 434 torch.Size([200, 324])
# 435 torch.Size([200, 324])
# 436 torch.Size([200, 324])
# 437 torch.Size([200, 324])
# 438 torch.Size([200, 324])
# 439 torch.Size([200, 324])
# 440 torch.Size([200, 324])
# 441 torch.Size([200, 324])
# 442 torch.Size([200, 324])
# 443 torch.Size([200, 324])
# 444 torch.Size([200, 324])
# 445 torch.Size([200, 324])
# 446 torch.Size([200, 324])
# 447 torch.Size([200, 324])
# 448 torch.Size([200, 324])
# 449 torch.Size([200, 324])
# 450 torch.Size([200, 324])
# 451 torch.Size([200, 324])
# 452 torch.Size([200, 324])
# 453 torch.Size([200, 324])
# 454 torch.Size([200, 324])
# 455 torch.Size([200, 324])
# 456 torch.Size([200, 324])
# 457 torch.Size([200, 324])
# 458 torch.Size([200, 324])
# 459 torch.Size([200, 324])
# 460 torch.Size([200, 324])
# 461 torch.Size([200, 324])
# 462 torch.Size([200, 324])
# 463 torch.Size([200, 324])
# 464 torch.Size([200, 324])
# 465 torch.Size([200, 324])
# 466 torch.Size([200, 324])
# 467 torch.Size([200, 324])
# 468 torch.Size([200, 324])
# 469 torch.Size([200, 324])
# 470 torch.Size([200, 324])
# 471 torch.Size([200, 324])
# 472 torch.Size([200, 324])
# 473 torch.Size([200, 324])
# 474 torch.Size([200, 324])
# 475 torch.Size([200, 324])
# 476 torch.Size([200, 324])
# 477 torch.Size([200, 324])
# 478 torch.Size([200, 324])
# 479 torch.Size([200, 324])
# 480 torch.Size([200, 324])
# 481 torch.Size([200, 324])
# 482 torch.Size([200, 324])
# 483 torch.Size([200, 324])
# 484 torch.Size([200, 324])
# 485 torch.Size([200, 324])
# 486 torch.Size([200, 324])
# 487 torch.Size([200, 324])
# 488 torch.Size([200, 324])
# 489 torch.Size([200, 324])
# 490 torch.Size([200, 324])
# 491 torch.Size([200, 324])
# 492 torch.Size([200, 324])
# 493 torch.Size([200, 324])
# 494 torch.Size([200, 324])
# 495 torch.Size([200, 324])
# 496 torch.Size([200, 324])
# 497 torch.Size([200, 324])
# 498 torch.Size([200, 324])
# 499 torch.Size([200, 324])
# 500 torch.Size([200, 324])
# 501 torch.Size([200, 324])
# 502 torch.Size([200, 324])
# 503 torch.Size([200, 324])
# 504 torch.Size([200, 324])
# 505 torch.Size([200, 324])
# 506 torch.Size([200, 324])
# 507 torch.Size([200, 324])
# 508 torch.Size([200, 324])
# 509 torch.Size([200, 324])
# 510 torch.Size([200, 324])
# 511 torch.Size([200, 324])
# 512 torch.Size([200, 324])
# 513 torch.Size([200, 324])
# 514 torch.Size([200, 324])
# 515 torch.Size([200, 324])
# 516 torch.Size([200, 324])
# 517 torch.Size([200, 324])
# 518 torch.Size([200, 324])
# 519 torch.Size([200, 324])
# 520 torch.Size([200, 324])
# 521 torch.Size([200, 324])
# 522 torch.Size([200, 324])
# 523 torch.Size([200, 324])
# 524 torch.Size([200, 324])
# 525 torch.Size([200, 324])
# 526 torch.Size([200, 324])
# 527 torch.Size([200, 324])
# 528 torch.Size([200, 324])
# 529 torch.Size([200, 324])
# 530 torch.Size([200, 324])
# 531 torch.Size([200, 324])
# 532 torch.Size([200, 324])
# 533 torch.Size([200, 324])
# 534 torch.Size([200, 324])
# 535 torch.Size([200, 324])
# 536 torch.Size([200, 324])
# 537 torch.Size([200, 324])
# 538 torch.Size([200, 324])
# 539 torch.Size([200, 324])
# 540 torch.Size([200, 324])
# 541 torch.Size([200, 324])
# 542 torch.Size([200, 324])
# 543 torch.Size([200, 324])
# 544 torch.Size([200, 324])
# 545 torch.Size([200, 324])
# 546 torch.Size([200, 324])
# 547 torch.Size([200, 324])
# 548 torch.Size([200, 324])
# 549 torch.Size([200, 324])
# 550 torch.Size([200, 324])
# 551 torch.Size([200, 324])
# 552 torch.Size([200, 324])
# 553 torch.Size([200, 324])
# 554 torch.Size([200, 324])
# 555 torch.Size([200, 324])
# 556 torch.Size([200, 324])
# 557 torch.Size([200, 324])
# 558 torch.Size([200, 324])
# 559 torch.Size([200, 324])
# 560 torch.Size([200, 324])
# 561 torch.Size([200, 324])
# 562 torch.Size([200, 324])
# 563 torch.Size([200, 324])
# 564 torch.Size([200, 324])
# 565 torch.Size([200, 324])
# 566 torch.Size([200, 324])
# 567 torch.Size([200, 324])
# 568 torch.Size([200, 324])
# 569 torch.Size([200, 324])
# 570 torch.Size([200, 324])
# 571 torch.Size([200, 324])
# 572 torch.Size([200, 324])
# 573 torch.Size([200, 324])
# 574 torch.Size([200, 324])
# 575 torch.Size([200, 324])
# 576 torch.Size([200, 324])
# 577 torch.Size([200, 324])
# 578 torch.Size([200, 324])
# 579 torch.Size([200, 324])
# 580 torch.Size([200, 324])
# 581 torch.Size([200, 324])
# 582 torch.Size([200, 324])
# 583 torch.Size([200, 324])
# 584 torch.Size([200, 324])
# 585 torch.Size([200, 324])
# 586 torch.Size([200, 324])
# 587 torch.Size([200, 324])
# 588 torch.Size([200, 324])
# 589 torch.Size([200, 324])
# 590 torch.Size([200, 324])
# 591 torch.Size([200, 324])
# 592 torch.Size([200, 324])
# 593 torch.Size([200, 324])
# 594 torch.Size([200, 324])
# 595 torch.Size([200, 324])
# 596 torch.Size([200, 324])
# 597 torch.Size([200, 324])
# 598 torch.Size([200, 324])
# 599 torch.Size([200, 324])
# 600 torch.Size([200, 324])
# 601 torch.Size([200, 324])
# 602 torch.Size([200, 324])
# 603 torch.Size([200, 324])
# 604 torch.Size([200, 324])
# 605 torch.Size([200, 324])
# 606 torch.Size([200, 324])
# 607 torch.Size([200, 324])
# 608 torch.Size([200, 324])
# 609 torch.Size([200, 324])
# 610 torch.Size([200, 324])
# 611 torch.Size([200, 324])
# 612 torch.Size([200, 324])
# 613 torch.Size([200, 324])
# 614 torch.Size([200, 324])
# 615 torch.Size([200, 324])
# 616 torch.Size([200, 324])
# 617 torch.Size([200, 324])
# 618 torch.Size([200, 324])
# 619 torch.Size([200, 324])
# 620 torch.Size([200, 324])
# 621 torch.Size([200, 324])
# 622 torch.Size([200, 324])
# 623 torch.Size([200, 324])
# 624 torch.Size([200, 324])
# 625 torch.Size([200, 324])
# 626 torch.Size([200, 324])
# 627 torch.Size([200, 324])
# 628 torch.Size([200, 324])
# 629 torch.Size([200, 324])
# 630 torch.Size([200, 324])
# 631 torch.Size([200, 324])
# 632 torch.Size([200, 324])
# 633 torch.Size([200, 324])
# 634 torch.Size([200, 324])
# 635 torch.Size([200, 324])
# 636 torch.Size([200, 324])
# 637 torch.Size([200, 324])
# 638 torch.Size([200, 324])
# 639 torch.Size([200, 324])
# 640 torch.Size([200, 324])
# 641 torch.Size([200, 324])
# 642 torch.Size([200, 324])
# 643 torch.Size([200, 324])
# 644 torch.Size([200, 324])
# 645 torch.Size([200, 324])
# 646 torch.Size([200, 324])
# 647 torch.Size([200, 324])
# 648 torch.Size([200, 324])
# 649 torch.Size([200, 324])
# 650 torch.Size([200, 324])
# 651 torch.Size([200, 324])
# 652 torch.Size([200, 324])
# 653 torch.Size([200, 324])
# 654 torch.Size([200, 324])
# 655 torch.Size([200, 324])
# 656 torch.Size([200, 324])
# 657 torch.Size([200, 324])
# 658 torch.Size([200, 324])
# 659 torch.Size([200, 324])
# 660 torch.Size([200, 324])
# 661 torch.Size([200, 324])
# 662 torch.Size([200, 324])
# 663 torch.Size([200, 324])
# 664 torch.Size([200, 324])
# 665 torch.Size([200, 324])
# 666 torch.Size([200, 324])
# 667 torch.Size([200, 324])
# 668 torch.Size([200, 324])
# 669 torch.Size([200, 324])
# 670 torch.Size([200, 324])
# 671 torch.Size([200, 324])
# 672 torch.Size([200, 324])
# 673 torch.Size([200, 324])
# 674 torch.Size([200, 324])
# 675 torch.Size([200, 324])
# 676 torch.Size([200, 324])
# 677 torch.Size([200, 324])
# 678 torch.Size([200, 324])
# 679 torch.Size([200, 324])
# 680 torch.Size([200, 324])
# 681 torch.Size([200, 324])
# 682 torch.Size([200, 324])
# 683 torch.Size([200, 324])
# 684 torch.Size([200, 324])
# 685 torch.Size([200, 324])
# 686 torch.Size([200, 324])
# 687 torch.Size([200, 324])
# 688 torch.Size([200, 324])
# 689 torch.Size([200, 324])
# 690 torch.Size([200, 324])
# 691 torch.Size([200, 324])
# 692 torch.Size([200, 324])
# 693 torch.Size([200, 324])
# 694 torch.Size([200, 324])
# 695 torch.Size([200, 324])
# 696 torch.Size([200, 324])
# 697 torch.Size([200, 324])
# 698 torch.Size([200, 324])
# 699 torch.Size([200, 324])
# 700 torch.Size([200, 324])
# 701 torch.Size([200, 324])
# 702 torch.Size([200, 324])
# 703 torch.Size([200, 324])
# 704 torch.Size([200, 324])
# 705 torch.Size([200, 324])
# 706 torch.Size([200, 324])
# 707 torch.Size([200, 324])
# 708 torch.Size([200, 324])
# 709 torch.Size([200, 324])
# 710 torch.Size([200, 324])
# 711 torch.Size([200, 324])
# 712 torch.Size([200, 324])
# 713 torch.Size([200, 324])
# 714 torch.Size([200, 324])
# 715 torch.Size([200, 324])
# 716 torch.Size([200, 324])
# 717 torch.Size([200, 324])
# 718 torch.Size([200, 324])
# 719 torch.Size([200, 324])
# 720 torch.Size([200, 324])
# 721 torch.Size([200, 324])
# 722 torch.Size([200, 324])
# 723 torch.Size([200, 324])
# 724 torch.Size([200, 324])
# 725 torch.Size([200, 324])
# 726 torch.Size([200, 324])
# 727 torch.Size([200, 324])
# 728 torch.Size([200, 324])
# 729 torch.Size([200, 324])
# 730 torch.Size([200, 324])
# 731 torch.Size([200, 324])
# 732 torch.Size([200, 324])
# 733 torch.Size([200, 324])
# 734 torch.Size([200, 324])
# 735 torch.Size([200, 324])
# 736 torch.Size([200, 324])
# 737 torch.Size([200, 324])
# 738 torch.Size([200, 324])
# 739 torch.Size([200, 324])
# 740 torch.Size([200, 324])
# 741 torch.Size([200, 324])
# 742 torch.Size([200, 324])
# 743 torch.Size([200, 324])
# 744 torch.Size([200, 324])
# 745 torch.Size([200, 324])
# 746 torch.Size([200, 324])
# 747 torch.Size([200, 324])
# 748 torch.Size([200, 324])
# 749 torch.Size([200, 324])
# 750 torch.Size([200, 324])
# 751 torch.Size([200, 324])
# 752 torch.Size([200, 324])
# 753 torch.Size([200, 324])
# 754 torch.Size([200, 324])
# 755 torch.Size([200, 324])
# 756 torch.Size([200, 324])
# 757 torch.Size([200, 324])
# 758 torch.Size([200, 324])
# 759 torch.Size([200, 324])
# 760 torch.Size([200, 324])
# 761 torch.Size([200, 324])
# 762 torch.Size([200, 324])
# 763 torch.Size([200, 324])
# 764 torch.Size([200, 324])
# 765 torch.Size([200, 324])
# 766 torch.Size([200, 324])
# 767 torch.Size([200, 324])
# 768 torch.Size([200, 324])
# 769 torch.Size([200, 324])
# 770 torch.Size([200, 324])
# 771 torch.Size([200, 324])
# 772 torch.Size([200, 324])
# 773 torch.Size([200, 324])
# 774 torch.Size([200, 324])
# 775 torch.Size([200, 324])
# 776 torch.Size([200, 324])
# 777 torch.Size([200, 324])
# 778 torch.Size([200, 324])
# 779 torch.Size([200, 324])
# 780 torch.Size([200, 324])
# 781 torch.Size([200, 324])
# 782 torch.Size([200, 324])
# 783 torch.Size([200, 324])
# 784 torch.Size([200, 324])
# 785 torch.Size([200, 324])
# 786 torch.Size([200, 324])
# 787 torch.Size([200, 324])
# 788 torch.Size([200, 324])
# 789 torch.Size([200, 324])
# 790 torch.Size([200, 324])
# 791 torch.Size([200, 324])
# 792 torch.Size([200, 324])
# 793 torch.Size([200, 324])
# 794 torch.Size([200, 324])
# 795 torch.Size([200, 324])
# 796 torch.Size([200, 324])
# 797 torch.Size([200, 324])
# 798 torch.Size([200, 324])
# 799 torch.Size([200, 324])
# 800 torch.Size([200, 324])
# 801 torch.Size([200, 324])
# 802 torch.Size([200, 324])
# 803 torch.Size([200, 324])
# 804 torch.Size([200, 324])
# 805 torch.Size([200, 324])
# 806 torch.Size([200, 324])
# 807 torch.Size([200, 324])
# 808 torch.Size([200, 324])
# 809 torch.Size([200, 324])
# 810 torch.Size([200, 324])
# 811 torch.Size([200, 324])
# 812 torch.Size([200, 324])
# 813 torch.Size([200, 324])
# 814 torch.Size([200, 324])
# 815 torch.Size([200, 324])
# 816 torch.Size([200, 324])
# 817 torch.Size([200, 324])
# 818 torch.Size([200, 324])
# 819 torch.Size([200, 324])
# 820 torch.Size([200, 324])
# 821 torch.Size([200, 324])
# 822 torch.Size([200, 324])
# 823 torch.Size([200, 324])
# 824 torch.Size([200, 324])
# 825 torch.Size([200, 324])
# 826 torch.Size([200, 324])
# 827 torch.Size([200, 324])
# 828 torch.Size([200, 324])
# 829 torch.Size([200, 324])
# 830 torch.Size([200, 324])
# 831 torch.Size([200, 324])
# 832 torch.Size([200, 324])
# 833 torch.Size([200, 324])
# 834 torch.Size([200, 324])
# 835 torch.Size([200, 324])
# 836 torch.Size([200, 324])
# 837 torch.Size([200, 324])
# 838 torch.Size([200, 324])
# 839 torch.Size([200, 324])
# 840 torch.Size([200, 324])
# 841 torch.Size([200, 324])
# 842 torch.Size([200, 324])
# 843 torch.Size([200, 324])
# 844 torch.Size([200, 324])
# 845 torch.Size([200, 324])
# 846 torch.Size([200, 324])
# 847 torch.Size([200, 324])
# 848 torch.Size([200, 324])
# 849 torch.Size([200, 324])
# 850 torch.Size([200, 324])
# 851 torch.Size([200, 324])
# 852 torch.Size([200, 324])
# 853 torch.Size([200, 324])
# 854 torch.Size([200, 324])
# 855 torch.Size([200, 324])
# 856 torch.Size([200, 324])
# 857 torch.Size([200, 324])
# 858 torch.Size([200, 324])
# 859 torch.Size([200, 324])
# 860 torch.Size([200, 324])
# 861 torch.Size([200, 324])
# 862 torch.Size([200, 324])
# 863 torch.Size([200, 324])
# 864 torch.Size([200, 324])
# 865 torch.Size([200, 324])
# 866 torch.Size([200, 324])
# 867 torch.Size([200, 324])
# 868 torch.Size([200, 324])
# 869 torch.Size([200, 324])
# 870 torch.Size([200, 324])
# 871 torch.Size([200, 324])
# 872 torch.Size([200, 324])
# 873 torch.Size([200, 324])
# 874 torch.Size([200, 324])
# 875 torch.Size([200, 324])
# 876 torch.Size([200, 324])
# 877 torch.Size([200, 324])
# 878 torch.Size([200, 324])
# 879 torch.Size([200, 324])
# 880 torch.Size([200, 324])
# 881 torch.Size([200, 324])
# 882 torch.Size([200, 324])
# 883 torch.Size([200, 324])
# 884 torch.Size([200, 324])
# 885 torch.Size([200, 324])
# 886 torch.Size([200, 324])
# 887 torch.Size([200, 324])
# 888 torch.Size([200, 324])
# 889 torch.Size([200, 324])
# 890 torch.Size([200, 324])
# 891 torch.Size([200, 324])
# 892 torch.Size([200, 324])
# 893 torch.Size([200, 324])
# 894 torch.Size([200, 324])
# 895 torch.Size([200, 324])
# 896 torch.Size([200, 324])
# 897 torch.Size([200, 324])
# 898 torch.Size([200, 324])
# 899 torch.Size([200, 324])
# 900 torch.Size([200, 324])
# 901 torch.Size([200, 324])
# 902 torch.Size([200, 324])
# 903 torch.Size([200, 324])
# 904 torch.Size([200, 324])
# 905 torch.Size([200, 324])
# 906 torch.Size([200, 324])
# 907 torch.Size([200, 324])
# 908 torch.Size([200, 324])
# 909 torch.Size([200, 324])
# 910 torch.Size([200, 324])
# 911 torch.Size([200, 324])
# 912 torch.Size([200, 324])
# 913 torch.Size([200, 324])
# 914 torch.Size([200, 324])
# 915 torch.Size([200, 324])
# 916 torch.Size([200, 324])
# 917 torch.Size([200, 324])
# 918 torch.Size([200, 324])
# 919 torch.Size([200, 324])
# 920 torch.Size([200, 324])
# 921 torch.Size([200, 324])
# 922 torch.Size([200, 324])
# 923 torch.Size([200, 324])
# 924 torch.Size([200, 324])
# 925 torch.Size([200, 324])
# 926 torch.Size([200, 324])
# 927 torch.Size([200, 324])
# 928 torch.Size([200, 324])
# 929 torch.Size([200, 324])
# 930 torch.Size([200, 324])
# 931 torch.Size([200, 324])
# 932 torch.Size([200, 324])
# 933 torch.Size([200, 324])
# 934 torch.Size([200, 324])
# 935 torch.Size([200, 324])
# 936 torch.Size([200, 324])
# 937 torch.Size([200, 324])
# 938 torch.Size([200, 324])
# 939 torch.Size([200, 324])
# 940 torch.Size([200, 324])
# 941 torch.Size([200, 324])
# 942 torch.Size([200, 324])
# 943 torch.Size([200, 324])
# 944 torch.Size([200, 324])
# 945 torch.Size([200, 324])
# 946 torch.Size([200, 324])
# 947 torch.Size([200, 324])
# 948 torch.Size([200, 324])
# 949 torch.Size([200, 324])
# 950 torch.Size([200, 324])
# 951 torch.Size([200, 324])
# 952 torch.Size([200, 324])
# 953 torch.Size([200, 324])
# 954 torch.Size([200, 324])
# 955 torch.Size([200, 324])
# 956 torch.Size([200, 324])
# 957 torch.Size([200, 324])
# 958 torch.Size([200, 324])
# 959 torch.Size([200, 324])
# 960 torch.Size([200, 324])
# 961 torch.Size([200, 324])
# 962 torch.Size([200, 324])
# 963 torch.Size([200, 324])
# 964 torch.Size([200, 324])
# 965 torch.Size([200, 324])
# 966 torch.Size([200, 324])
# 967 torch.Size([200, 324])
# 968 torch.Size([200, 324])
# 969 torch.Size([200, 324])
# 970 torch.Size([200, 324])
# 971 torch.Size([200, 324])
# 972 torch.Size([200, 324])
# 973 torch.Size([200, 324])
# 974 torch.Size([200, 324])
# 975 torch.Size([200, 324])
# 976 torch.Size([200, 324])
# 977 torch.Size([200, 324])
# 978 torch.Size([200, 324])
# 979 torch.Size([200, 324])
# 980 torch.Size([200, 324])
# 981 torch.Size([200, 324])
# 982 torch.Size([200, 324])
# 983 torch.Size([200, 324])
# 984 torch.Size([200, 324])
# 985 torch.Size([200, 324])
# 986 torch.Size([200, 324])
# 987 torch.Size([200, 324])
# 988 torch.Size([200, 324])
# 989 torch.Size([200, 324])
# 990 torch.Size([200, 324])
# 991 torch.Size([200, 324])
# 992 torch.Size([200, 324])
# 993 torch.Size([200, 324])
# 994 torch.Size([200, 324])
# 995 torch.Size([200, 324])
# 996 torch.Size([200, 324])
# 997 torch.Size([200, 324])
# 998 torch.Size([200, 324])
# 999 torch.Size([200, 324])
# 1000 torch.Size([200, 324])
# 1001 torch.Size([200, 324])
# 1002 torch.Size([200, 324])
# 1003 torch.Size([200, 324])
# 1004 torch.Size([200, 324])
# 1005 torch.Size([200, 324])
# 1006 torch.Size([200, 324])
# 1007 torch.Size([200, 324])
# 1008 torch.Size([200, 324])
# 1009 torch.Size([200, 324])
# 1010 torch.Size([200, 324])
# 1011 torch.Size([200, 324])
# 1012 torch.Size([200, 324])
# 1013 torch.Size([200, 324])
# 1014 torch.Size([200, 324])
# 1015 torch.Size([200, 324])
# 1016 torch.Size([200, 324])
# 1017 torch.Size([200, 324])
# 1018 torch.Size([200, 324])
# 1019 torch.Size([200, 324])
# 1020 torch.Size([200, 324])
# 1021 torch.Size([200, 324])
# 1022 torch.Size([200, 324])
# 1023 torch.Size([200, 324])
# 1024 torch.Size([200, 324])
# 1025 torch.Size([200, 324])
# 1026 torch.Size([200, 324])
# 1027 torch.Size([200, 324])
# 1028 torch.Size([200, 324])
# 1029 torch.Size([200, 324])
# 1030 torch.Size([200, 324])
# 1031 torch.Size([200, 324])
# 1032 torch.Size([200, 324])
# 1033 torch.Size([200, 324])
# 1034 torch.Size([200, 324])
# 1035 torch.Size([200, 324])
# 1036 torch.Size([200, 324])
# 1037 torch.Size([200, 324])
# 1038 torch.Size([200, 324])
# 1039 torch.Size([200, 324])
# 1040 torch.Size([200, 324])
# 1041 torch.Size([200, 324])
# 1042 torch.Size([200, 324])
# 1043 torch.Size([200, 324])
# 1044 torch.Size([200, 324])
# 1045 torch.Size([200, 324])
# 1046 torch.Size([200, 324])
# 1047 torch.Size([200, 324])
# 1048 torch.Size([200, 324])
# 1049 torch.Size([200, 324])
# 1050 torch.Size([200, 324])
# 1051 torch.Size([200, 324])
# 1052 torch.Size([200, 324])
# 1053 torch.Size([200, 324])
# 1054 torch.Size([200, 324])
# 1055 torch.Size([200, 324])
# 1056 torch.Size([200, 324])
# 1057 torch.Size([200, 324])
# 1058 torch.Size([200, 324])
# 1059 torch.Size([200, 324])
# 1060 torch.Size([200, 324])
# 1061 torch.Size([200, 324])
# 1062 torch.Size([200, 324])
# 1063 torch.Size([200, 324])
# 1064 torch.Size([200, 324])
# 1065 torch.Size([200, 324])
# 1066 torch.Size([200, 324])
# 1067 torch.Size([200, 324])
# 1068 torch.Size([200, 324])
# 1069 torch.Size([200, 324])
# 1070 torch.Size([200, 324])
# 1071 torch.Size([200, 324])
# 1072 torch.Size([200, 324])
# 1073 torch.Size([200, 324])
# 1074 torch.Size([200, 324])
# 1075 torch.Size([200, 324])
# 1076 torch.Size([200, 324])
# 1077 torch.Size([200, 324])
# 1078 torch.Size([200, 324])
# 1079 torch.Size([200, 324])
# 1080 torch.Size([200, 324])
# 1081 torch.Size([200, 324])
# 1082 torch.Size([200, 324])
# 1083 torch.Size([200, 324])
# 1084 torch.Size([200, 324])
# 1085 torch.Size([200, 324])
# 1086 torch.Size([200, 324])
# 1087 torch.Size([200, 324])
# 1088 torch.Size([200, 324])
# 1089 torch.Size([200, 324])
# 1090 torch.Size([200, 324])
# 1091 torch.Size([200, 324])
# 1092 torch.Size([200, 324])
# 1093 torch.Size([200, 324])
# 1094 torch.Size([200, 324])
# 1095 torch.Size([200, 324])
# 1096 torch.Size([200, 324])
# 1097 torch.Size([200, 324])
# 1098 torch.Size([200, 324])
# 1099 torch.Size([200, 324])
# 1100 torch.Size([200, 324])
# 1101 torch.Size([200, 324])
# 1102 torch.Size([200, 324])
# 1103 torch.Size([200, 324])
# 1104 torch.Size([200, 324])
# 1105 torch.Size([200, 324])
# 1106 torch.Size([200, 324])
# 1107 torch.Size([200, 324])
# 1108 torch.Size([200, 324])
# 1109 torch.Size([200, 324])
# 1110 torch.Size([200, 324])
# 1111 torch.Size([200, 324])
# 1112 torch.Size([200, 324])
# 1113 torch.Size([200, 324])
# 1114 torch.Size([200, 324])
# 1115 torch.Size([200, 324])
# 1116 torch.Size([200, 324])
# 1117 torch.Size([200, 324])
# 1118 torch.Size([200, 324])
# 1119 torch.Size([200, 324])
# 1120 torch.Size([200, 324])
# 1121 torch.Size([200, 324])
# 1122 torch.Size([200, 324])
# 1123 torch.Size([200, 324])
# 1124 torch.Size([200, 324])
# 1125 torch.Size([200, 324])
# 1126 torch.Size([200, 324])
# 1127 torch.Size([200, 324])
# 1128 torch.Size([200, 324])
# 1129 torch.Size([200, 324])
# 1130 torch.Size([200, 324])
# 1131 torch.Size([200, 324])
# 1132 torch.Size([200, 324])
# 1133 torch.Size([200, 324])
# 1134 torch.Size([200, 324])
# 1135 torch.Size([200, 324])
# 1136 torch.Size([200, 324])
# 1137 torch.Size([200, 324])
# 1138 torch.Size([200, 324])
# 1139 torch.Size([200, 324])
# 1140 torch.Size([200, 324])
# 1141 torch.Size([200, 324])
# 1142 torch.Size([200, 324])
# 1143 torch.Size([200, 324])
# 1144 torch.Size([200, 324])
# 1145 torch.Size([200, 324])
# 1146 torch.Size([200, 324])
# 1147 torch.Size([200, 324])
# 1148 torch.Size([200, 324])
# 1149 torch.Size([200, 324])
# 1150 torch.Size([200, 324])
# 1151 torch.Size([200, 324])
# 1152 torch.Size([200, 324])
# 1153 torch.Size([200, 324])
# 1154 torch.Size([200, 324])
# 1155 torch.Size([200, 324])
# 1156 torch.Size([200, 324])
# 1157 torch.Size([200, 324])
# 1158 torch.Size([200, 324])
# 1159 torch.Size([200, 324])
# 1160 torch.Size([200, 324])
# 1161 torch.Size([200, 324])
# 1162 torch.Size([200, 324])
# 1163 torch.Size([200, 324])
# 1164 torch.Size([200, 324])
# 1165 torch.Size([200, 324])
# 1166 torch.Size([200, 324])
# 1167 torch.Size([200, 324])
# 1168 torch.Size([200, 324])
# 1169 torch.Size([200, 324])
# 1170 torch.Size([200, 324])
# 1171 torch.Size([200, 324])
# 1172 torch.Size([200, 324])
# 1173 torch.Size([200, 324])
# 1174 torch.Size([200, 324])
# 1175 torch.Size([200, 324])
# 1176 torch.Size([200, 324])
# 1177 torch.Size([200, 324])
# 1178 torch.Size([200, 324])
# 1179 torch.Size([200, 324])
# 1180 torch.Size([200, 324])
# 1181 torch.Size([200, 324])
# 1182 torch.Size([200, 324])
# 1183 torch.Size([200, 324])
# 1184 torch.Size([200, 324])
# 1185 torch.Size([200, 324])
# 1186 torch.Size([200, 324])
# 1187 torch.Size([200, 324])
# 1188 torch.Size([200, 324])
# 1189 torch.Size([200, 324])
# 1190 torch.Size([200, 324])
# 1191 torch.Size([200, 324])
# 1192 torch.Size([200, 324])
# 1193 torch.Size([200, 324])
# 1194 torch.Size([200, 324])
# 1195 torch.Size([200, 324])
# 1196 torch.Size([200, 324])
# 1197 torch.Size([200, 324])
# 1198 torch.Size([200, 324])
# 1199 torch.Size([200, 324])
# 1200 torch.Size([200, 324])
# 1201 torch.Size([200, 324])
# 1202 torch.Size([200, 324])
# 1203 torch.Size([200, 324])
# 1204 torch.Size([200, 324])
# 1205 torch.Size([200, 324])
# 1206 torch.Size([200, 324])
# 1207 torch.Size([200, 324])
# 1208 torch.Size([200, 324])
# 1209 torch.Size([200, 324])
# 1210 torch.Size([200, 324])
# 1211 torch.Size([200, 324])
# 1212 torch.Size([200, 324])
# 1213 torch.Size([200, 324])
# 1214 torch.Size([200, 324])
# 1215 torch.Size([200, 324])
# 1216 torch.Size([200, 324])
# 1217 torch.Size([200, 324])
# 1218 torch.Size([200, 324])
# 1219 torch.Size([200, 324])
# 1220 torch.Size([200, 324])
# 1221 torch.Size([200, 324])
# 1222 torch.Size([200, 324])
# 1223 torch.Size([200, 324])
# 1224 torch.Size([200, 324])
# 1225 torch.Size([200, 324])
# 1226 torch.Size([200, 324])
# 1227 torch.Size([200, 324])
# 1228 torch.Size([200, 324])
# 1229 torch.Size([200, 324])
# 1230 torch.Size([200, 324])
# 1231 torch.Size([200, 324])
# 1232 torch.Size([200, 324])
# 1233 torch.Size([200, 324])
# 1234 torch.Size([200, 324])
# 1235 torch.Size([200, 324])
# 1236 torch.Size([200, 324])
# 1237 torch.Size([200, 324])
# 1238 torch.Size([200, 324])
# 1239 torch.Size([200, 324])
# 1240 torch.Size([200, 324])
# 1241 torch.Size([200, 324])
# 1242 torch.Size([200, 324])
# 1243 torch.Size([200, 324])
# 1244 torch.Size([200, 324])
# 1245 torch.Size([200, 324])
# 1246 torch.Size([200, 324])
# 1247 torch.Size([200, 324])
# 1248 torch.Size([200, 324])
# 1249 torch.Size([200, 324])
# 1250 torch.Size([200, 324])
# 1251 torch.Size([200, 324])
# 1252 torch.Size([200, 324])
# 1253 torch.Size([200, 324])
# 1254 torch.Size([200, 324])
# 1255 torch.Size([200, 324])
# 1256 torch.Size([200, 324])
# 1257 torch.Size([200, 324])
# 1258 torch.Size([200, 324])
# 1259 torch.Size([200, 324])
# 1260 torch.Size([200, 324])
# 1261 torch.Size([200, 324])
# 1262 torch.Size([200, 324])
# 1263 torch.Size([200, 324])
# 1264 torch.Size([200, 324])
# 1265 torch.Size([200, 324])
# 1266 torch.Size([200, 324])
# 1267 torch.Size([200, 324])
# 1268 torch.Size([200, 324])
# 1269 torch.Size([200, 324])
# 1270 torch.Size([200, 324])
# 1271 torch.Size([200, 324])
# 1272 torch.Size([200, 324])
# 1273 torch.Size([200, 324])
# 1274 torch.Size([200, 324])
# 1275 torch.Size([200, 324])
# 1276 torch.Size([200, 324])
# 1277 torch.Size([200, 324])
# 1278 torch.Size([200, 324])
# 1279 torch.Size([200, 324])
# 1280 torch.Size([200, 324])
# 1281 torch.Size([200, 324])
# 1282 torch.Size([200, 324])
# 1283 torch.Size([200, 324])
# 1284 torch.Size([200, 324])
# 1285 torch.Size([200, 324])
# 1286 torch.Size([200, 324])
# 1287 torch.Size([200, 324])
# 1288 torch.Size([200, 324])
# 1289 torch.Size([200, 324])
# 1290 torch.Size([200, 324])
# 1291 torch.Size([200, 324])
# 1292 torch.Size([200, 324])
# 1293 torch.Size([200, 324])
# 1294 torch.Size([200, 324])
# 1295 torch.Size([200, 324])
# 1296 torch.Size([200, 324])
# 1297 torch.Size([200, 324])
# 1298 torch.Size([200, 324])
# 1299 torch.Size([200, 324])
# 1300 torch.Size([200, 324])
# 1301 torch.Size([200, 324])
# 1302 torch.Size([200, 324])
# 1303 torch.Size([200, 324])
# 1304 torch.Size([200, 324])
# 1305 torch.Size([200, 324])
# 1306 torch.Size([200, 324])
# 1307 torch.Size([200, 324])
# 1308 torch.Size([200, 324])
# 1309 torch.Size([200, 324])
# 1310 torch.Size([200, 324])
# 1311 torch.Size([200, 324])
# 1312 torch.Size([200, 324])
# 1313 torch.Size([200, 324])
# 1314 torch.Size([200, 324])
# 1315 torch.Size([200, 324])
# 1316 torch.Size([200, 324])
# 1317 torch.Size([200, 324])
# 1318 torch.Size([200, 324])
# 1319 torch.Size([200, 324])
# 1320 torch.Size([200, 324])
# 1321 torch.Size([200, 324])
# 1322 torch.Size([200, 324])
# 1323 torch.Size([200, 324])
# 1324 torch.Size([200, 324])
# 1325 torch.Size([200, 324])
# 1326 torch.Size([200, 324])
# 1327 torch.Size([200, 324])
# 1328 torch.Size([200, 324])
# 1329 torch.Size([200, 324])
# 1330 torch.Size([200, 324])
# 1331 torch.Size([200, 324])
# 1332 torch.Size([200, 324])
# 1333 torch.Size([200, 324])
# 1334 torch.Size([200, 324])
# 1335 torch.Size([200, 324])
# 1336 torch.Size([200, 324])
# 1337 torch.Size([200, 324])
# 1338 torch.Size([200, 324])
# 1339 torch.Size([200, 324])
# 1340 torch.Size([200, 324])
# 1341 torch.Size([200, 324])
# 1342 torch.Size([200, 324])
# 1343 torch.Size([200, 324])
# 1344 torch.Size([200, 324])
# 1345 torch.Size([200, 324])
# 1346 torch.Size([200, 324])
# 1347 torch.Size([200, 324])
# 1348 torch.Size([200, 324])
# 1349 torch.Size([200, 324])
# 1350 torch.Size([200, 324])
# 1351 torch.Size([200, 324])
# 1352 torch.Size([200, 324])
# 1353 torch.Size([200, 324])
# 1354 torch.Size([200, 324])
# 1355 torch.Size([200, 324])
# 1356 torch.Size([200, 324])
# 1357 torch.Size([200, 324])
# 1358 torch.Size([200, 324])
# 1359 torch.Size([200, 324])
# 1360 torch.Size([200, 324])
# 1361 torch.Size([200, 324])
# 1362 torch.Size([200, 324])
# 1363 torch.Size([200, 324])
# 1364 torch.Size([200, 324])
# 1365 torch.Size([200, 324])
# 1366 torch.Size([200, 324])
# 1367 torch.Size([200, 324])
# 1368 torch.Size([200, 324])
# 1369 torch.Size([200, 324])
# 1370 torch.Size([200, 324])
# 1371 torch.Size([200, 324])
# 1372 torch.Size([200, 324])
# 1373 torch.Size([200, 324])
# 1374 torch.Size([200, 324])
# 1375 torch.Size([200, 324])
# 1376 torch.Size([200, 324])
# 1377 torch.Size([200, 324])
# 1378 torch.Size([200, 324])
# 1379 torch.Size([200, 324])
# 1380 torch.Size([200, 324])
# 1381 torch.Size([200, 324])
# 1382 torch.Size([200, 324])
# 1383 torch.Size([200, 324])
# 1384 torch.Size([200, 324])
# 1385 torch.Size([200, 324])
# 1386 torch.Size([200, 324])
# 1387 torch.Size([200, 324])
# 1388 torch.Size([200, 324])
# 1389 torch.Size([200, 324])
# 1390 torch.Size([200, 324])
# 1391 torch.Size([200, 324])
# 1392 torch.Size([200, 324])
# 1393 torch.Size([200, 324])
# 1394 torch.Size([200, 324])
# 1395 torch.Size([200, 324])
# 1396 torch.Size([200, 324])
# 1397 torch.Size([200, 324])
# 1398 torch.Size([200, 324])
# 1399 torch.Size([200, 324])
# 1400 torch.Size([200, 324])
# 1401 torch.Size([200, 324])
# 1402 torch.Size([200, 324])
# 1403 torch.Size([200, 324])
# 1404 torch.Size([200, 324])
# 1405 torch.Size([200, 324])
# 1406 torch.Size([200, 324])
# 1407 torch.Size([200, 324])
# 1408 torch.Size([200, 324])
# 1409 torch.Size([200, 324])
# 1410 torch.Size([200, 324])
# 1411 torch.Size([200, 324])
# 1412 torch.Size([200, 324])
# 1413 torch.Size([200, 324])
# 1414 torch.Size([200, 324])
# 1415 torch.Size([200, 324])
# 1416 torch.Size([200, 324])
# 1417 torch.Size([200, 324])
# 1418 torch.Size([200, 324])
# 1419 torch.Size([200, 324])
# 1420 torch.Size([200, 324])
# 1421 torch.Size([200, 324])
# 1422 torch.Size([200, 324])
# 1423 torch.Size([200, 324])
# 1424 torch.Size([200, 324])
# 1425 torch.Size([200, 324])
# 1426 torch.Size([200, 324])
# 1427 torch.Size([200, 324])
# 1428 torch.Size([200, 324])
# 1429 torch.Size([200, 324])
# 1430 torch.Size([200, 324])
# 1431 torch.Size([200, 324])
# 1432 torch.Size([200, 324])
# 1433 torch.Size([200, 324])
# 1434 torch.Size([200, 324])
# 1435 torch.Size([200, 324])
# 1436 torch.Size([200, 324])
# 1437 torch.Size([200, 324])
# 1438 torch.Size([200, 324])
# 1439 torch.Size([200, 324])
# 1440 torch.Size([200, 324])
# 1441 torch.Size([200, 324])
# 1442 torch.Size([200, 324])
# 1443 torch.Size([200, 324])
# 1444 torch.Size([200, 324])
# 1445 torch.Size([200, 324])
# 1446 torch.Size([200, 324])
# 1447 torch.Size([200, 324])
# 1448 torch.Size([200, 324])
# 1449 torch.Size([200, 324])
# 1450 torch.Size([200, 324])
# 1451 torch.Size([200, 324])
# 1452 torch.Size([200, 324])
# 1453 torch.Size([200, 324])
# 1454 torch.Size([200, 324])
# 1455 torch.Size([200, 324])
# 1456 torch.Size([200, 324])
# 1457 torch.Size([200, 324])
# 1458 torch.Size([200, 324])
# 1459 torch.Size([200, 324])
# 1460 torch.Size([200, 324])
# 1461 torch.Size([200, 324])
# 1462 torch.Size([200, 324])
# 1463 torch.Size([200, 324])
# 1464 torch.Size([200, 324])
# 1465 torch.Size([200, 324])
# 1466 torch.Size([200, 324])
# 1467 torch.Size([200, 324])
# 1468 torch.Size([200, 324])
# 1469 torch.Size([200, 324])
# 1470 torch.Size([200, 324])
# 1471 torch.Size([200, 324])
# 1472 torch.Size([200, 324])
# 1473 torch.Size([200, 324])
# 1474 torch.Size([200, 324])
# 1475 torch.Size([200, 324])
# 1476 torch.Size([200, 324])
# 1477 torch.Size([200, 324])
# 1478 torch.Size([200, 324])
# 1479 torch.Size([200, 324])
# 1480 torch.Size([200, 324])
# 1481 torch.Size([200, 324])
# 1482 torch.Size([200, 324])
# 1483 torch.Size([200, 324])
# 1484 torch.Size([200, 324])
# 1485 torch.Size([200, 324])
# 1486 torch.Size([200, 324])
# 1487 torch.Size([200, 324])
# 1488 torch.Size([200, 324])
# 1489 torch.Size([200, 324])
# 1490 torch.Size([200, 324])
# 1491 torch.Size([200, 324])
# 1492 torch.Size([200, 324])
# 1493 torch.Size([200, 324])
# 1494 torch.Size([200, 324])
# 1495 torch.Size([200, 324])
# 1496 torch.Size([200, 324])
# 1497 torch.Size([200, 324])
# 1498 torch.Size([200, 324])
# 1499 torch.Size([200, 324])
# 1500 torch.Size([200, 324])
# 1501 torch.Size([200, 324])
# 1502 torch.Size([200, 324])
# 1503 torch.Size([200, 324])
# 1504 torch.Size([200, 324])
# 1505 torch.Size([200, 324])
# 1506 torch.Size([200, 324])
# 1507 torch.Size([200, 324])
# 1508 torch.Size([200, 324])
# 1509 torch.Size([200, 324])
# 1510 torch.Size([200, 324])
# 1511 torch.Size([200, 324])
# 1512 torch.Size([200, 324])
# 1513 torch.Size([200, 324])
# 1514 torch.Size([200, 324])
# 1515 torch.Size([200, 324])
# 1516 torch.Size([200, 324])
# 1517 torch.Size([200, 324])
# 1518 torch.Size([200, 324])
# 1519 torch.Size([200, 324])
# 1520 torch.Size([200, 324])
# 1521 torch.Size([200, 324])
# 1522 torch.Size([200, 324])
# 1523 torch.Size([200, 324])
# 1524 torch.Size([200, 324])
# 1525 torch.Size([200, 324])
# 1526 torch.Size([200, 324])
# 1527 torch.Size([200, 324])
# 1528 torch.Size([200, 324])
# 1529 torch.Size([200, 324])
# 1530 torch.Size([200, 324])
# 1531 torch.Size([200, 324])
# 1532 torch.Size([200, 324])
# 1533 torch.Size([200, 324])
# 1534 torch.Size([200, 324])
# 1535 torch.Size([200, 324])
# 1536 torch.Size([200, 324])
# 1537 torch.Size([200, 324])
# 1538 torch.Size([200, 324])
# 1539 torch.Size([200, 324])
# 1540 torch.Size([200, 324])
# 1541 torch.Size([200, 324])
# 1542 torch.Size([200, 324])
# 1543 torch.Size([200, 324])
# 1544 torch.Size([200, 324])
# 1545 torch.Size([200, 324])
# 1546 torch.Size([200, 324])
# 1547 torch.Size([200, 324])
# 1548 torch.Size([200, 324])
# 1549 torch.Size([200, 324])
# 1550 torch.Size([200, 324])
# 1551 torch.Size([200, 324])
# 1552 torch.Size([200, 324])
# 1553 torch.Size([200, 324])
# 1554 torch.Size([200, 324])
# 1555 torch.Size([200, 324])
# 1556 torch.Size([200, 324])
# 1557 torch.Size([200, 324])
# 1558 torch.Size([200, 324])
# 1559 torch.Size([200, 324])
# 1560 torch.Size([200, 324])
# 1561 torch.Size([200, 324])
# 1562 torch.Size([200, 324])
# 1563 torch.Size([200, 324])
# 1564 torch.Size([200, 324])
# 1565 torch.Size([200, 324])
# 1566 torch.Size([200, 324])
# 1567 torch.Size([200, 324])
# 1568 torch.Size([200, 324])
# 1569 torch.Size([200, 324])
# 1570 torch.Size([200, 324])
# 1571 torch.Size([200, 324])
# 1572 torch.Size([200, 324])
# 1573 torch.Size([200, 324])
# 1574 torch.Size([200, 324])
# 1575 torch.Size([200, 324])
# 1576 torch.Size([200, 324])
# 1577 torch.Size([200, 324])
# 1578 torch.Size([200, 324])
# 1579 torch.Size([200, 324])
# 1580 torch.Size([200, 324])
# 1581 torch.Size([200, 324])
# 1582 torch.Size([200, 324])
# 1583 torch.Size([200, 324])
# 1584 torch.Size([200, 324])
# 1585 torch.Size([200, 324])
# 1586 torch.Size([200, 324])
# 1587 torch.Size([200, 324])
# 1588 torch.Size([200, 324])
# 1589 torch.Size([200, 324])
# 1590 torch.Size([200, 324])
# 1591 torch.Size([200, 324])
# 1592 torch.Size([200, 324])
# 1593 torch.Size([200, 324])
# 1594 torch.Size([200, 324])
# 1595 torch.Size([200, 324])
# 1596 torch.Size([200, 324])
# 1597 torch.Size([200, 324])
# 1598 torch.Size([200, 324])
# 1599 torch.Size([200, 324])
# 1600 torch.Size([200, 324])
# 1601 torch.Size([200, 324])
# 1602 torch.Size([200, 324])
# 1603 torch.Size([200, 324])
# 1604 torch.Size([200, 324])
# 1605 torch.Size([200, 324])
# 1606 torch.Size([200, 324])
# 1607 torch.Size([200, 324])
# 1608 torch.Size([200, 324])
# 1609 torch.Size([200, 324])
# 1610 torch.Size([200, 324])
# 1611 torch.Size([200, 324])
# 1612 torch.Size([200, 324])
# 1613 torch.Size([200, 324])
# 1614 torch.Size([200, 324])
# 1615 torch.Size([200, 324])
# 1616 torch.Size([200, 324])
# 1617 torch.Size([200, 324])
# 1618 torch.Size([200, 324])
# 1619 torch.Size([200, 324])
# 1620 torch.Size([200, 324])
# 1621 torch.Size([200, 324])
# 1622 torch.Size([200, 324])
# 1623 torch.Size([200, 324])
# 1624 torch.Size([200, 324])
# 1625 torch.Size([200, 324])
# 1626 torch.Size([200, 324])
# 1627 torch.Size([200, 324])
# 1628 torch.Size([200, 324])
# 1629 torch.Size([200, 324])
# 1630 torch.Size([200, 324])
# 1631 torch.Size([200, 324])
# 1632 torch.Size([200, 324])
# 1633 torch.Size([200, 324])
# 1634 torch.Size([200, 324])
# 1635 torch.Size([200, 324])
# 1636 torch.Size([200, 324])
# 1637 torch.Size([200, 324])
# 1638 torch.Size([200, 324])
# 1639 torch.Size([200, 324])
# 1640 torch.Size([200, 324])
# 1641 torch.Size([200, 324])
# 1642 torch.Size([200, 324])
# 1643 torch.Size([200, 324])
# 1644 torch.Size([200, 324])
# 1645 torch.Size([200, 324])
# 1646 torch.Size([200, 324])
# 1647 torch.Size([200, 324])
# 1648 torch.Size([200, 324])
# 1649 torch.Size([200, 324])
# 1650 torch.Size([200, 324])
# 1651 torch.Size([200, 324])
# 1652 torch.Size([200, 324])
# 1653 torch.Size([200, 324])
# 1654 torch.Size([200, 324])
# 1655 torch.Size([200, 324])
# 1656 torch.Size([200, 324])
# 1657 torch.Size([200, 324])
# 1658 torch.Size([200, 324])
# 1659 torch.Size([200, 324])
# 1660 torch.Size([200, 324])
# 1661 torch.Size([200, 324])
# 1662 torch.Size([200, 324])
# 1663 torch.Size([200, 324])
# 1664 torch.Size([200, 324])
# 1665 torch.Size([200, 324])
# 1666 torch.Size([200, 324])
# 1667 torch.Size([200, 324])
# 1668 torch.Size([200, 324])
# 1669 torch.Size([200, 324])
# 1670 torch.Size([200, 324])
# 1671 torch.Size([200, 324])
# 1672 torch.Size([200, 324])
# 1673 torch.Size([200, 324])
# 1674 torch.Size([200, 324])
# 1675 torch.Size([200, 324])
# 1676 torch.Size([200, 324])
# 1677 torch.Size([200, 324])
# 1678 torch.Size([200, 324])
# 1679 torch.Size([200, 324])
# 1680 torch.Size([200, 324])
# 1681 torch.Size([200, 324])
# 1682 torch.Size([200, 324])
# 1683 torch.Size([200, 324])
# 1684 torch.Size([200, 324])
# 1685 torch.Size([200, 324])
# 1686 torch.Size([200, 324])
# 1687 torch.Size([200, 324])
# 1688 torch.Size([200, 324])
# 1689 torch.Size([200, 324])
# 1690 torch.Size([200, 324])
# 1691 torch.Size([200, 324])
# 1692 torch.Size([200, 324])
# 1693 torch.Size([200, 324])
# 1694 torch.Size([200, 324])
# 1695 torch.Size([200, 324])
# 1696 torch.Size([200, 324])
# 1697 torch.Size([200, 324])
# 1698 torch.Size([200, 324])
# 1699 torch.Size([200, 324])
# 1700 torch.Size([200, 324])
# 1701 torch.Size([200, 324])
# 1702 torch.Size([200, 324])
# 1703 torch.Size([200, 324])
# 1704 torch.Size([200, 324])
# 1705 torch.Size([200, 324])
# 1706 torch.Size([200, 324])
# 1707 torch.Size([200, 324])
# 1708 torch.Size([200, 324])
# 1709 torch.Size([200, 324])
# 1710 torch.Size([200, 324])
# 1711 torch.Size([200, 324])
# 1712 torch.Size([200, 324])
# 1713 torch.Size([200, 324])
# 1714 torch.Size([200, 324])
# 1715 torch.Size([200, 324])
# 1716 torch.Size([200, 324])
# 1717 torch.Size([200, 324])
# 1718 torch.Size([200, 324])
# 1719 torch.Size([200, 324])
# 1720 torch.Size([200, 324])
# 1721 torch.Size([200, 324])
# 1722 torch.Size([200, 324])
# 1723 torch.Size([200, 324])
# 1724 torch.Size([200, 324])
# 1725 torch.Size([200, 324])
# 1726 torch.Size([200, 324])
# 1727 torch.Size([200, 324])
# 1728 torch.Size([200, 324])
# 1729 torch.Size([200, 324])
# 1730 torch.Size([200, 324])
# 1731 torch.Size([200, 324])
# 1732 torch.Size([200, 324])
# 1733 torch.Size([200, 324])
# 1734 torch.Size([200, 324])
# 1735 torch.Size([200, 324])
# 1736 torch.Size([200, 324])
# 1737 torch.Size([200, 324])
# 1738 torch.Size([200, 324])
# 1739 torch.Size([200, 324])
# 1740 torch.Size([200, 324])
# 1741 torch.Size([200, 324])
# 1742 torch.Size([200, 324])
# 1743 torch.Size([200, 324])
# 1744 torch.Size([200, 324])
# 1745 torch.Size([200, 324])
# 1746 torch.Size([200, 324])
# 1747 torch.Size([200, 324])
# 1748 torch.Size([200, 324])
# 1749 torch.Size([200, 324])
# 1750 torch.Size([200, 324])
# 1751 torch.Size([200, 324])
# 1752 torch.Size([200, 324])
# ...
# 2196 torch.Size([200, 324])
# 2197 torch.Size([200, 324])
# 2198 torch.Size([200, 324])
# 2199 torch.Size([200, 324])
# 2200 torch.Size([200, 324])
# 2201 torch.Size([200, 324])
# 2202 torch.Size([200, 324])
# 2203 torch.Size([200, 324])
# 2204 torch.Size([200, 324])
# 2205 torch.Size([200, 324])
# 2206 torch.Size([200, 324])
# 2207 torch.Size([200, 324])
# 2208 torch.Size([200, 324])
# 2209 torch.Size([200, 324])
# 2210 torch.Size([200, 324])
# 2211 torch.Size([200, 324])
# 2212 torch.Size([200, 324])
# 2213 torch.Size([200, 324])
# 2214 torch.Size([200, 324])
# 2215 torch.Size([200, 324])
# 2216 torch.Size([200, 324])
# 2217 torch.Size([200, 324])
# 2218 torch.Size([200, 324])
# 2219 torch.Size([200, 324])
# 2220 torch.Size([200, 324])
# 2221 torch.Size([200, 324])
# 2222 torch.Size([200, 324])
# 2223 torch.Size([200, 324])
# 2224 torch.Size([200, 324])
# 2225 torch.Size([200, 324])
# 2226 torch.Size([200, 324])
# 2227 torch.Size([200, 324])
# 2228 torch.Size([200, 324])
# 2229 torch.Size([200, 324])
# 2230 torch.Size([200, 324])
# 2231 torch.Size([200, 324])
# 2232 torch.Size([200, 324])
# 2233 torch.Size([200, 324])
# 2234 torch.Size([200, 324])
# 2235 torch.Size([200, 324])
# 2236 torch.Size([200, 324])
# 2237 torch.Size([200, 324])
# 2238 torch.Size([200, 324])
# 2239 torch.Size([200, 324])
# 2240 torch.Size([200, 324])
# 2241 torch.Size([200, 324])
# 2242 torch.Size([200, 324])
# 2243 torch.Size([200, 324])
# 2244 torch.Size([200, 324])
# 2245 torch.Size([200, 324])
# 2246 torch.Size([200, 324])
# 2247 torch.Size([200, 324])
# 2248 torch.Size([200, 324])
# 2249 torch.Size([200, 324])
# 2250 torch.Size([200, 324])
# 2251 torch.Size([200, 324])
# 2252 torch.Size([200, 324])
# 2253 torch.Size([200, 324])
# 2254 torch.Size([200, 324])
# 2255 torch.Size([200, 324])
# 2256 torch.Size([200, 324])
# 2257 torch.Size([200, 324])
# 2258 torch.Size([200, 324])
# 2259 torch.Size([200, 324])
# 2260 torch.Size([200, 324])
# 2261 torch.Size([200, 324])
# 2262 torch.Size([200, 324])
# 2263 torch.Size([200, 324])
# 2264 torch.Size([200, 324])
# 2265 torch.Size([200, 324])
# 2266 torch.Size([200, 324])
# 2267 torch.Size([200, 324])
# 2268 torch.Size([200, 324])
# 2269 torch.Size([200, 324])
# 2270 torch.Size([200, 324])
# 2271 torch.Size([200, 324])
# 2272 torch.Size([200, 324])
# 2273 torch.Size([200, 324])
# 2274 torch.Size([200, 324])
# 2275 torch.Size([200, 324])
# 2276 torch.Size([200, 324])
# 2277 torch.Size([200, 324])
# 2278 torch.Size([200, 324])
# 2279 torch.Size([200, 324])
# 2280 torch.Size([200, 324])
# 2281 torch.Size([200, 324])
# 2282 torch.Size([200, 324])
# 2283 torch.Size([200, 324])
# 2284 torch.Size([200, 324])
# 2285 torch.Size([200, 324])
# 2286 torch.Size([200, 324])
# 2287 torch.Size([200, 324])
# 2288 torch.Size([200, 324])
# 2289 torch.Size([200, 324])
# 2290 torch.Size([200, 324])
# 2291 torch.Size([200, 324])
# 2292 torch.Size([200, 324])
# 2293 torch.Size([200, 324])
# 2294 torch.Size([200, 324])
# 2295 torch.Size([200, 324])
# 2296 torch.Size([200, 324])
# 2297 torch.Size([200, 324])
# 2298 torch.Size([200, 324])
# 2299 torch.Size([200, 324])
# 2300 torch.Size([200, 324])
# 2301 torch.Size([200, 324])
# 2302 torch.Size([200, 324])
# 2303 torch.Size([200, 324])
# 2304 torch.Size([200, 324])
# 2305 torch.Size([200, 324])
# 2306 torch.Size([200, 324])
# 2307 torch.Size([200, 324])
# 2308 torch.Size([200, 324])
# 2309 torch.Size([200, 324])
# 2310 torch.Size([200, 324])
# 2311 torch.Size([200, 324])
# 2312 torch.Size([200, 324])
# 2313 torch.Size([200, 324])
# 2314 torch.Size([200, 324])
# 2315 torch.Size([200, 324])
# 2316 torch.Size([200, 324])
# 2317 torch.Size([200, 324])
# 2318 torch.Size([200, 324])
# 2319 torch.Size([200, 324])
# 2320 torch.Size([200, 324])
# 2321 torch.Size([200, 324])
# 2322 torch.Size([200, 324])
# 2323 torch.Size([200, 324])
# 2324 torch.Size([200, 324])
# 2325 torch.Size([200, 324])
# 2326 torch.Size([200, 324])
# 2327 torch.Size([200, 324])
# 2328 torch.Size([200, 324])
# 2329 torch.Size([200, 324])
# 2330 torch.Size([200, 324])
# 2331 torch.Size([200, 324])
# 2332 torch.Size([200, 324])
# 2333 torch.Size([200, 324])
# 2334 torch.Size([200, 324])
# 2335 torch.Size([200, 324])
# 2336 torch.Size([200, 324])
# 2337 torch.Size([200, 324])
# 2338 torch.Size([200, 324])
# 2339 torch.Size([200, 324])
# 2340 torch.Size([200, 324])
# 2341 torch.Size([200, 324])
# 2342 torch.Size([200, 324])
# 2343 torch.Size([200, 324])
# 2344 torch.Size([200, 324])
# 2345 torch.Size([200, 324])
# 2346 torch.Size([200, 324])
# 2347 torch.Size([200, 324])
# 2348 torch.Size([200, 324])
# 2349 torch.Size([200, 324])
# 2350 torch.Size([200, 324])
# 2351 torch.Size([200, 324])
# 2352 torch.Size([200, 324])
# 2353 torch.Size([200, 324])
# 2354 torch.Size([200, 324])
# 2355 torch.Size([200, 324])
# 2356 torch.Size([200, 324])
# 2357 torch.Size([200, 324])
# 2358 torch.Size([200, 324])
# 2359 torch.Size([200, 324])
# 2360 torch.Size([200, 324])
# 2361 torch.Size([200, 324])
# 2362 torch.Size([200, 324])
# 2363 torch.Size([200, 324])
# 2364 torch.Size([200, 324])
# 2365 torch.Size([200, 324])
# 2366 torch.Size([200, 324])
# 2367 torch.Size([200, 324])
# 2368 torch.Size([200, 324])
# 2369 torch.Size([200, 324])
# 2370 torch.Size([200, 324])
# 2371 torch.Size([200, 324])
# 2372 torch.Size([200, 324])
# 2373 torch.Size([200, 324])
# 2374 torch.Size([200, 324])
# 2375 torch.Size([200, 324])
# 2376 torch.Size([200, 324])
# 2377 torch.Size([200, 324])
# 2378 torch.Size([200, 324])
# 2379 torch.Size([200, 324])
# 2380 torch.Size([200, 324])
# 2381 torch.Size([200, 324])
# 2382 torch.Size([200, 324])
# 2383 torch.Size([200, 324])
# 2384 torch.Size([200, 324])
# 2385 torch.Size([200, 324])
# 2386 torch.Size([200, 324])
# 2387 torch.Size([200, 324])
# 2388 torch.Size([200, 324])
# 2389 torch.Size([200, 324])
# 2390 torch.Size([200, 324])
# 2391 torch.Size([200, 324])
# 2392 torch.Size([200, 324])
# 2393 torch.Size([200, 324])
# 2394 torch.Size([200, 324])
# 2395 torch.Size([200, 324])
# 2396 torch.Size([200, 324])
# 2397 torch.Size([200, 324])
# 2398 torch.Size([200, 324])
# 2399 torch.Size([200, 324])
# 2400 torch.Size([200, 324])
# 2401 torch.Size([200, 324])
# 2402 torch.Size([200, 324])
# 2403 torch.Size([200, 324])
# 2404 torch.Size([200, 324])
# 2405 torch.Size([200, 324])
# 2406 torch.Size([200, 324])
# 2407 torch.Size([200, 324])
# 2408 torch.Size([200, 324])
# 2409 torch.Size([200, 324])
# 2410 torch.Size([200, 324])
# 2411 torch.Size([200, 324])
# 2412 torch.Size([200, 324])
# 2413 torch.Size([200, 324])
# 2414 torch.Size([200, 324])
# 2415 torch.Size([200, 324])
# 2416 torch.Size([200, 324])
# 2417 torch.Size([200, 324])
# 2418 torch.Size([200, 324])
# 2419 torch.Size([200, 324])
# 2420 torch.Size([200, 324])
# 2421 torch.Size([200, 324])
# 2422 torch.Size([200, 324])
# 2423 torch.Size([200, 324])
# 2424 torch.Size([200, 324])
# 2425 torch.Size([200, 324])
# 2426 torch.Size([200, 324])
# 2427 torch.Size([200, 324])
# 2428 torch.Size([200, 324])
# 2429 torch.Size([200, 324])
# 2430 torch.Size([200, 324])
# 2431 torch.Size([200, 324])
# 2432 torch.Size([200, 324])
# 2433 torch.Size([200, 324])
# 2434 torch.Size([200, 324])
# 2435 torch.Size([200, 324])
# 2436 torch.Size([200, 324])
# 2437 torch.Size([200, 324])
# 2438 torch.Size([200, 324])
# 2439 torch.Size([200, 324])
# 2440 torch.Size([200, 324])
# 2441 torch.Size([200, 324])
# 2442 torch.Size([200, 324])
# 2443 torch.Size([200, 324])
# 2444 torch.Size([200, 324])
# 2445 torch.Size([200, 324])
# 2446 torch.Size([200, 324])
# 2447 torch.Size([200, 324])
# 2448 torch.Size([200, 324])
# 2449 torch.Size([200, 324])
# 2450 torch.Size([200, 324])
# 2451 torch.Size([200, 324])
# 2452 torch.Size([200, 324])
# 2453 torch.Size([200, 324])
# 2454 torch.Size([200, 324])
# 2455 torch.Size([200, 324])
# 2456 torch.Size([200, 324])
# 2457 torch.Size([200, 324])
# 2458 torch.Size([200, 324])
# 2459 torch.Size([200, 324])
# 2460 torch.Size([200, 324])
# 2461 torch.Size([200, 324])
# 2462 torch.Size([200, 324])
# 2463 torch.Size([200, 324])
# 2464 torch.Size([200, 324])
# 2465 torch.Size([200, 324])
# 2466 torch.Size([200, 324])
# 2467 torch.Size([200, 324])
# 2468 torch.Size([200, 324])
# 2469 torch.Size([200, 324])
# 2470 torch.Size([200, 324])
# 2471 torch.Size([200, 324])
# 2472 torch.Size([200, 324])
# 2473 torch.Size([200, 324])
# 2474 torch.Size([200, 324])
# 2475 torch.Size([200, 324])
# 2476 torch.Size([200, 324])
# 2477 torch.Size([200, 324])
# 2478 torch.Size([200, 324])
# 2479 torch.Size([200, 324])
# 2480 torch.Size([200, 324])
# 2481 torch.Size([200, 324])
# 2482 torch.Size([200, 324])
# 2483 torch.Size([200, 324])
# 2484 torch.Size([200, 324])
# 2485 torch.Size([200, 324])
# 2486 torch.Size([200, 324])
# 2487 torch.Size([200, 324])
# 2488 torch.Size([200, 324])
# 2489 torch.Size([200, 324])
# 2490 torch.Size([200, 324])
# 2491 torch.Size([200, 324])
# 2492 torch.Size([200, 324])
# 2493 torch.Size([200, 324])
# 2494 torch.Size([200, 324])
# 2495 torch.Size([200, 324])
# 2496 torch.Size([200, 324])
# 2497 torch.Size([200, 324])
# 2498 torch.Size([200, 324])
# 2499 torch.Size([200, 324])
# 2500 torch.Size([200, 324])
# 2501 torch.Size([200, 324])
# 2502 torch.Size([200, 324])
# 2503 torch.Size([200, 324])
# 2504 torch.Size([200, 324])
# 2505 torch.Size([200, 324])
# 2506 torch.Size([200, 324])
# 2507 torch.Size([200, 324])
# 2508 torch.Size([200, 324])
# 2509 torch.Size([200, 324])
# 2510 torch.Size([200, 324])
# 2511 torch.Size([200, 324])
# 2512 torch.Size([200, 324])
# 2513 torch.Size([200, 324])
# 2514 torch.Size([200, 324])
# 2515 torch.Size([200, 324])
# 2516 torch.Size([200, 324])
# 2517 torch.Size([200, 324])
# 2518 torch.Size([200, 324])
# 2519 torch.Size([200, 324])
# 2520 torch.Size([200, 324])
# 2521 torch.Size([200, 324])
# 2522 torch.Size([200, 324])
# 2523 torch.Size([200, 324])
# 2524 torch.Size([200, 324])
# 2525 torch.Size([200, 324])
# 2526 torch.Size([200, 324])
# 2527 torch.Size([200, 324])
# 2528 torch.Size([200, 324])
# 2529 torch.Size([200, 324])
# 2530 torch.Size([200, 324])
# 2531 torch.Size([200, 324])
# 2532 torch.Size([200, 324])
# 2533 torch.Size([200, 324])
# 2534 torch.Size([200, 324])
# 2535 torch.Size([200, 324])
# 2536 torch.Size([200, 324])
# 2537 torch.Size([200, 324])
# 2538 torch.Size([200, 324])
# 2539 torch.Size([200, 324])
# 2540 torch.Size([200, 324])
# 2541 torch.Size([200, 324])
# 2542 torch.Size([200, 324])
# 2543 torch.Size([200, 324])
# 2544 torch.Size([200, 324])
# 2545 torch.Size([200, 324])
# 2546 torch.Size([200, 324])
# 2547 torch.Size([200, 324])
# 2548 torch.Size([200, 324])
# 2549 torch.Size([200, 324])
# 2550 torch.Size([200, 324])
# 2551 torch.Size([200, 324])
# 2552 torch.Size([200, 324])
# 2553 torch.Size([200, 324])
# 2554 torch.Size([200, 324])
# 2555 torch.Size([200, 324])
# 2556 torch.Size([200, 324])
# 2557 torch.Size([200, 324])
# 2558 torch.Size([200, 324])
# 2559 torch.Size([200, 324])
# 2560 torch.Size([200, 324])
# 2561 torch.Size([200, 324])
# 2562 torch.Size([200, 324])
# 2563 torch.Size([200, 324])
# 2564 torch.Size([200, 324])
# 2565 torch.Size([200, 324])
# 2566 torch.Size([200, 324])
# 2567 torch.Size([200, 324])
# 2568 torch.Size([200, 324])
# 2569 torch.Size([200, 324])
# 2570 torch.Size([200, 324])
# 2571 torch.Size([200, 324])
# 2572 torch.Size([200, 324])
# 2573 torch.Size([200, 324])
# 2574 torch.Size([200, 324])
# 2575 torch.Size([200, 324])
# 2576 torch.Size([200, 324])
# 2577 torch.Size([200, 324])
# 2578 torch.Size([200, 324])
# 2579 torch.Size([200, 324])
# 2580 torch.Size([200, 324])
# 2581 torch.Size([200, 324])
# 2582 torch.Size([200, 324])
# 2583 torch.Size([200, 324])
# 2584 torch.Size([200, 324])
# 2585 torch.Size([200, 324])
# 2586 torch.Size([200, 324])
# 2587 torch.Size([200, 324])
# 2588 torch.Size([200, 324])
# 2589 torch.Size([200, 324])
# 2590 torch.Size([200, 324])
# 2591 torch.Size([200, 324])
# 2592 torch.Size([200, 324])
# 2593 torch.Size([200, 324])
# 2594 torch.Size([200, 324])
# 2595 torch.Size([200, 324])
# 2596 torch.Size([200, 324])
# 2597 torch.Size([200, 324])
# 2598 torch.Size([200, 324])
# 2599 torch.Size([200, 324])
# 2600 torch.Size([200, 324])
# 2601 torch.Size([200, 324])
# 2602 torch.Size([200, 324])
# 2603 torch.Size([200, 324])
# 2604 torch.Size([200, 324])
# 2605 torch.Size([200, 324])
# 2606 torch.Size([200, 324])
# 2607 torch.Size([200, 324])
# 2608 torch.Size([200, 324])
# 2609 torch.Size([200, 324])
# 2610 torch.Size([200, 324])
# 2611 torch.Size([200, 324])
# 2612 torch.Size([200, 324])
# 2613 torch.Size([200, 324])
# 2614 torch.Size([200, 324])
# 2615 torch.Size([200, 324])
# 2616 torch.Size([200, 324])
# 2617 torch.Size([200, 324])
# 2618 torch.Size([200, 324])
# 2619 torch.Size([200, 324])
# 2620 torch.Size([200, 324])
# 2621 torch.Size([200, 324])
# 2622 torch.Size([200, 324])
# 2623 torch.Size([200, 324])
# 2624 torch.Size([200, 324])
# 2625 torch.Size([200, 324])
# 2626 torch.Size([200, 324])
# 2627 torch.Size([200, 324])
# 2628 torch.Size([200, 324])
# 2629 torch.Size([200, 324])
# 2630 torch.Size([200, 324])
# 2631 torch.Size([200, 324])
# 2632 torch.Size([200, 324])
# 2633 torch.Size([200, 324])
# 2634 torch.Size([200, 324])
# 2635 torch.Size([200, 324])
# 2636 torch.Size([200, 324])
# 2637 torch.Size([200, 324])
# 2638 torch.Size([200, 324])
# 2639 torch.Size([200, 324])
# 2640 torch.Size([200, 324])
# 2641 torch.Size([200, 324])
# 2642 torch.Size([200, 324])
# 2643 torch.Size([200, 324])
# 2644 torch.Size([200, 324])
# 2645 torch.Size([200, 324])
# 2646 torch.Size([200, 324])
# 2647 torch.Size([200, 324])
# 2648 torch.Size([200, 324])
# 2649 torch.Size([200, 324])
# 2650 torch.Size([200, 324])
# 2651 torch.Size([200, 324])
# 2652 torch.Size([200, 324])
# 2653 torch.Size([200, 324])
# 2654 torch.Size([200, 324])
# 2655 torch.Size([200, 324])
# 2656 torch.Size([200, 324])
# 2657 torch.Size([200, 324])
# 2658 torch.Size([200, 324])
# 2659 torch.Size([200, 324])
# 2660 torch.Size([200, 324])
# 2661 torch.Size([200, 324])
# 2662 torch.Size([200, 324])
# 2663 torch.Size([200, 324])
# 2664 torch.Size([200, 324])
# 2665 torch.Size([200, 324])
# 2666 torch.Size([200, 324])
# 2667 torch.Size([200, 324])
# 2668 torch.Size([200, 324])
# 2669 torch.Size([200, 324])
# 2670 torch.Size([200, 324])
# 2671 torch.Size([200, 324])
# 2672 torch.Size([200, 324])
# 2673 torch.Size([200, 324])
# 2674 torch.Size([200, 324])
# 2675 torch.Size([200, 324])
# 2676 torch.Size([200, 324])
# 2677 torch.Size([200, 324])
# 2678 torch.Size([200, 324])
# 2679 torch.Size([200, 324])
# 2680 torch.Size([200, 324])
# 2681 torch.Size([200, 324])
# 2682 torch.Size([200, 324])
# 2683 torch.Size([200, 324])
# 2684 torch.Size([200, 324])
# 2685 torch.Size([200, 324])
# 2686 torch.Size([200, 324])
# 2687 torch.Size([200, 324])
# 2688 torch.Size([200, 324])
# 2689 torch.Size([200, 324])
# 2690 torch.Size([200, 324])
# 2691 torch.Size([200, 324])
# 2692 torch.Size([200, 324])
# 2693 torch.Size([200, 324])
# 2694 torch.Size([200, 324])
# 2695 torch.Size([200, 324])
# 2696 torch.Size([200, 324])
# 2697 torch.Size([200, 324])
# 2698 torch.Size([200, 324])
# 2699 torch.Size([200, 324])
# 2700 torch.Size([200, 324])
# 2701 torch.Size([200, 324])
# 2702 torch.Size([200, 324])
# 2703 torch.Size([200, 324])
# 2704 torch.Size([200, 324])
# 2705 torch.Size([200, 324])
# 2706 torch.Size([200, 324])
# 2707 torch.Size([200, 324])
# 2708 torch.Size([200, 324])
# 2709 torch.Size([200, 324])
# 2710 torch.Size([200, 324])
# 2711 torch.Size([200, 324])
# 2712 torch.Size([200, 324])
# 2713 torch.Size([200, 324])
# 2714 torch.Size([200, 324])
# 2715 torch.Size([200, 324])
# 2716 torch.Size([200, 324])
# 2717 torch.Size([200, 324])
# 2718 torch.Size([200, 324])
# 2719 torch.Size([200, 324])
# 2720 torch.Size([200, 324])
# 2721 torch.Size([200, 324])
# 2722 torch.Size([200, 324])
# 2723 torch.Size([200, 324])
# 2724 torch.Size([200, 324])
# 2725 torch.Size([200, 324])
# 2726 torch.Size([200, 324])
# 2727 torch.Size([200, 324])
# 2728 torch.Size([200, 324])
# 2729 torch.Size([200, 324])
# 2730 torch.Size([200, 324])
# 2731 torch.Size([200, 324])
# 2732 torch.Size([200, 324])
# 2733 torch.Size([200, 324])
# 2734 torch.Size([200, 324])
# 2735 torch.Size([200, 324])
# 2736 torch.Size([200, 324])
# 2737 torch.Size([200, 324])
# 2738 torch.Size([200, 324])
# 2739 torch.Size([200, 324])
# 2740 torch.Size([200, 324])
# 2741 torch.Size([200, 324])
# 2742 torch.Size([200, 324])
# 2743 torch.Size([200, 324])
# 2744 torch.Size([200, 324])
# 2745 torch.Size([200, 324])
# 2746 torch.Size([200, 324])
# 2747 torch.Size([200, 324])
# 2748 torch.Size([200, 324])
# 2749 torch.Size([200, 324])
# 2750 torch.Size([200, 324])
# 2751 torch.Size([200, 324])
# 2752 torch.Size([200, 324])
# 2753 torch.Size([200, 324])
# 2754 torch.Size([200, 324])
# 2755 torch.Size([200, 324])
# 2756 torch.Size([200, 324])
# 2757 torch.Size([200, 324])
# 2758 torch.Size([200, 324])
# 2759 torch.Size([200, 324])
# 2760 torch.Size([200, 324])
# 2761 torch.Size([200, 324])
# 2762 torch.Size([200, 324])
# 2763 torch.Size([200, 324])
# 2764 torch.Size([200, 324])
# 2765 torch.Size([200, 324])
# 2766 torch.Size([77, 324])

# %%
import torch
from torch import nn
class AlphaNet(nn.Module):
    def __init__(self,factor_num,fully_connect_layer_neural):
        # super 父类，调用父类的构造，这一步必须有
        # 第一个参数为定义类的名称，第二个为self
        super(AlphaNet,self).__init__()
        self.fc1_neuron = (factor_num * (factor_num -1) + 4 * factor_num)* 3
        self.fc2_neuron = fully_connect_layer_neural
        self.dropout = nn.Dropout(0.3)
        self.fc1 = torch.nn.Linear(self.fc1_neuron,self.fc2_neuron)
        self.out = nn.Linear(self.fc2_neuron,1)
        self.relu = nn.ReLU()
    def forward(self,x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        y_pred = self.out(x)
        return y_pred

# %%
x.shape
# Out:
# torch.Size([12, 324])

# %%
label.shape
# Out:
# torch.Size([77, 1])

# %%
import torch.optim as optim
alphanet = AlphaNet(9,30)
print(alphanet)
LR = 0.01
optimizer = optim.RMSprop(alphanet.parameters(), lr=LR, alpha=0.9)
criterion=nn.MSELoss()
epoch_num = 5
preds=[]
labels=[]
for epoch in range(epoch_num):
    total_loss=0
    for idx,(x,y) in enumerate(train_loader):
        pred = alphanet(x)
        loss=criterion(pred,y.to(torch.float))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss+=loss.item()
    print("current epoch time:",epoch+1,"  Loss: ",total_loss)
# Out:
# AlphaNet(
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc1): Linear(in_features=324, out_features=30, bias=True)
#   (out): Linear(in_features=30, out_features=1, bias=True)
#   (relu): ReLU()
# )
# current epoch time: 1   Loss:  67189578.53705335
# current epoch time: 2   Loss:  378193556.619213
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8160/1539326734.py in <module>
#      12     for idx,(x,y) in enumerate(train_loader):
#      13         pred = alphanet(x)
# ---> 14         loss=criterion(pred,y.to(torch.float))
#      15         optimizer.zero_grad()
#      16         loss.backward()
#
# C:\ProgramData\Anaconda3\envs\python383\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# C:\ProgramData\Anaconda3\envs\python383\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     444
#     445     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 446         return F.mse_loss(input, target, reduction=self.reduction)
#     447
#     448
#
# C:\ProgramData\Anaconda3\envs\python383\lib\site-packages\torch\nn\functional.py in mse_loss(input, target, size_average, reduce, reduction)
#    2658
#    2659     expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 2660     return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#    2661
#    2662
#
# KeyboardInterrupt:

# %%
import torch.optim as optim
alphanet = AlphaNet(9,30)
print(alphanet)
loss_func = nn.MSELoss()
LR = 0.01
optimizer = optim.RMSprop(alphanet.parameters(), lr=LR, alpha=0.9)
epoch_num = 20
loss_list = []
for epoch in range(epoch_num):
    train_loss = 0.0
    for data,label in trainloader:
        out_put = alphanet(data)
        loss = loss_func(out_put,label.to(torch.float))
        optimizer.zero_grad()
        train_loss += loss.data
        loss.backward()
        optimizer.step()
    loss_list.append(train_loss.item())
    print("current epoch time:",epoch+1,"  Loss: ",train_loss.item())
# Out:
# AlphaNet(
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc1): Linear(in_features=324, out_features=30, bias=True)
#   (out): Linear(in_features=30, out_features=1, bias=True)
#   (relu): ReLU()
# )
# current epoch time: 1   Loss:  tensor(52.6974)
# current epoch time: 2   Loss:  tensor(52.9543)
# current epoch time: 3   Loss:  tensor(52.3064)
# current epoch time: 4   Loss:  tensor(52.7984)
# current epoch time: 5   Loss:  tensor(52.9351)
# current epoch time: 6   Loss:  tensor(52.7547)
# current epoch time: 7   Loss:  tensor(52.7151)
# current epoch time: 8   Loss:  tensor(52.9234)
# current epoch time: 9   Loss:  tensor(52.6263)
# current epoch time: 10   Loss:  tensor(52.8461)
# current epoch time: 11   Loss:  tensor(52.9109)
# current epoch time: 12   Loss:  tensor(52.6958)
# current epoch time: 13   Loss:  tensor(52.8688)
# current epoch time: 14   Loss:  tensor(52.3655)
# current epoch time: 15   Loss:  tensor(52.7638)
# current epoch time: 16   Loss:  tensor(52.9132)
# current epoch time: 17   Loss:  tensor(52.6934)
# current epoch time: 18   Loss:  tensor(52.9639)
# current epoch time: 19   Loss:  tensor(52.5933)
# current epoch time: 20   Loss:  tensor(52.7973)

# %%
model = alphanet.forward(x)
model
# Out:
# tensor([[39.7400],
#         [ 0.1375],
#         [ 0.4649],
#         [ 1.2760],
#         [ 0.1375],
#         [ 0.1375],
#         [ 0.1375],
#         [ 0.1375],
#         [ 0.9441],
#         [ 0.1375],
#         [ 0.6293],
#         [ 0.1375]], grad_fn=<AddmmBackward>)

# %%
y
# Out:
# tensor([[-0.7519],
#         [ 2.6144],
#         [ 6.0952],
#         [ 4.6031],
#         [ 0.7463],
#         [-1.3714],
#         [ 4.1742],
#         [-1.0811],
#         [-9.7602],
#         [ 2.7586],
#         [ 0.7792],
#         [-2.0045]], dtype=torch.float64)

# %%
feat_cat[0][0]
# Out:
# tensor([[-0.0293, -0.0297, -0.0300],
#         [-0.0289, -0.0295, -0.0296],
#         [-0.0267, -0.0275, -0.0276],
#         [-0.0283, -0.0290, -0.0290],
#         [-0.9412,  0.2199, -0.3941],
#         [ 0.1667,  0.0964,  0.1174],
#         [-0.1594, -0.1389, -0.1490],
#         [-0.1582, -0.1341, -0.1445],
#         [-0.0286, -0.0293, -0.0294],
#         [-0.0290, -0.0301, -0.0301],
#         [-0.0296, -0.0305, -0.0306],
#         [-0.2876,  0.0312, -0.1063],
#         [ 0.0631, -0.0813, -0.0579],
#         [-0.2064, -0.2001, -0.2024],
#         [-0.2010, -0.1952, -0.1941],
#         [-0.0281, -0.0288, -0.0290],
#         [-0.0289, -0.0295, -0.0297],
#         [-0.6820, -0.4986, -0.2886],
#         [ 0.0165,  0.0476, -0.0471],
#         [-0.1274, -0.1228, -0.1192],
#         [-0.1268, -0.1252, -0.1153],
#         [-0.0290, -0.0300, -0.0301],
#         [-0.2610, -0.5075, -0.0564],
#         [-0.0936, -0.1729, -0.1752],
#         [-0.1782, -0.1809, -0.1733],
#         [-0.1725, -0.1779, -0.1643],
#         [-0.3640, -0.4248, -0.1332],
#         [-0.0183, -0.0662, -0.1118],
#         [-0.1782, -0.1779, -0.1730],
#         [-0.1736, -0.1768, -0.1652],
#         [ 0.9703, -0.8368,  0.4262],
#         [-0.1319, -0.1227, -0.2027],
#         [-0.1029, -0.0819, -0.1990],
#         [-0.1487, -0.2305, -0.1733],
#         [-0.1200, -0.2192, -0.1435],
#         [-0.2359, -0.2355, -0.2386],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [    nan,     nan,     nan],
#         [-0.1659, -0.1883, -0.2272],
#         [-0.1296, -0.2140, -0.2250],
#         [-0.1442, -0.2031, -0.2243],
#         [-0.1015, -0.2072, -0.2128],
#         [-0.1255, -0.2038, -0.2231],
#         [ 1.6719,  1.8246,  0.6909],
#         [-0.3366, -0.4896, -0.4972],
#         [-0.6046, -0.6021, -0.6677],
#         [-0.3969, -0.3849, -0.4496],
#         [ 0.0472,  0.0472,  0.0472],
#         [ 0.0477,  0.0477,  0.0477],
#         [ 0.0435,  0.0435,  0.0435],
#         [ 0.0453,  0.0453,  0.0453],
#         [ 0.0447,  0.0447,  0.0447],
#         [ 0.9649,  0.3233,  2.0686],
#         [ 0.1582,  0.0120, -0.0214],
#         [ 0.8354,  0.3252,  2.0695],
#         [ 0.7090,  0.1248,  2.0723],
#         [ 0.5210, -0.1865, -0.0688],
#         [ 0.9018, -0.4404, -0.0826],
#         [ 0.6724, -0.2895,  0.0389],
#         [ 0.9108, -0.2783, -0.0763],
#         [ 0.8369, -0.3597, -0.0092],
#         [-0.1596, -1.1646, -0.5345],
#         [ 0.0906,  0.0906,  0.0906],
#         [-0.2000, -1.1569, -0.5270],
#         [-0.2479, -1.0423, -0.5285],
#         [-0.0416, -0.0223, -0.0189],
#         [-0.0419, -0.0249, -0.0223],
#         [-0.0363, -0.0206, -0.0150],
#         [-0.0373, -0.0224, -0.0201],
#         [-0.0384, -0.0230, -0.0195],
#         [ 2.8606,  2.4485,  1.9322],
#         [ 1.0405,  0.0309, -0.2105],
#         [-0.6095, -0.6385, -0.6729],
#         [-0.4510, -0.4643, -0.4939]], grad_fn=<SelectBackward>)

# %%
# import torch
# from torch import nn


# class AlphaNet(nn.Module):
#     def __init__(self,factor_num,fully_connect_layer_neural):
#         """ factor_num : 因子个数
#             fully_connect_layer_neural: 全连接层神经元的数量
#         """
#         super(AlphaNet,self).__init__()
#         self.fc1_neuron = (factor_num * (factor_num -1) + 4 * factor_num)* 3
#         self.fc2_neuron = fully_connect_layer_neural
#         self.batchnorm = nn.BatchNorm2d(1,affine=True)
#         self.dropout = nn.Dropout(0.5)
#         self.fc1 = nn.Linear(self.fc1_neuron,self.fc2_neuron)
#         self.out = nn.Linear(self.fc2_neuron,1)
#         self.relu = nn.ReLU()
#     def forward(self,data,num,num_rev):
#         # Conv
#         conv1 = self.ts_cov4d(data,10).to(torch.float)
#         sigmoid1 = torch.sigmoid(conv1)
#         bc1 = self.batchnorm(sigmoid1)
#         conv2 = self.ts_corr4d(data,10).to(torch.float)
#         bc2 = self.batchnorm(conv2)
#         conv3 = self.ts_stddev4d(data,10).to(torch.float)
#         sigmoid3 = torch.sigmoid(conv3)
#         bc3 = self.batchnorm(sigmoid3)
#         conv4 = self.ts_decaylinear(data,10).to(torch.float)
#         sigmoid4 = torch.sigmoid(conv4)
#         bc4 = self.batchnorm(sigmoid4)
#         conv5 = self.ts_zscore(data,10).to(torch.float)
#         bc5 = self.batchnorm(conv5)
#         data_conv = torch.cat([bc1,bc2,bc3,bc4,bc5],axis = 2)
#         # Pooling
#         ts_max = self.ts_pool(data_conv,3,method = 'max')
#         ts_max = self.batchnorm(ts_max)
#         ts_min = self.ts_pool(data_conv,3,method = 'min')
#         ts_min = self.batchnorm(ts_min)
#         ts_mean = self.ts_pool(data_conv,3,method = 'mean')
#         ts_mean = self.batchnorm(ts_mean)
#         data_fin = torch.cat([ts_max,ts_min,ts_mean],axis = 2)
#         data_fin = data_fin.flatten(start_dim = 1)
#         input_size = data_fin.size(1)
#         ful_connect = self.dropout(self.relu(self.fc1(data_fin)))
#         output = self.out(ful_connect)
#         return output.to(torch.float)
#     # 为了cov 和 corr提取并行计算产生计算列表
#     def generateC(l1):
#         if len(l1) == 1:
#             return []
#         v = [[l1[0],i] for i in l1[1:]]
#         l1 = l1[1:]
#         return v+generateC(l1)
#     def generate_Num_and_ReversedNum(feat_nums):
#         list1 = list(range(feat_nums))
#         num = generateC(list1)
#         num_rev = []
#         for l in num:
#             l1 = l.copy()
#             l1.reverse()
#             num_rev.append(l1)
#         return num , num_rev
#     def data_info(data,stride):
#         if len(data.shape)!=4:
#             raise Exception('Input data dimensions should be [N,C,H,W]')
#         data_length = data.shape[3] # 30
#         feat_num = data.shape[2] # 9
#         """num:组合数对列表,num_rev:num的翻转列表"""
#         num , num_rev = generate_Num_and_ReversedNum(feat_num)
#         conv_feat = len(num)
#         # 构建步长列表，如果数据长度不能整除，则取剩下长度，如果剩下长度小于5，则与上一步结合一起
#         if data_length % stride == 0:
#             step_list = list(range(0,data_length+stride,stride))
#         elif data_length % stride<=5:
#             mod = data_length % stride
#             step_list = list(range(0,data_length-stride,stride))+[data_length]
#         else:
#             mod = data_length % stride
#             step_list = list(range(0,data_length+stride-mod,stride))+[data_length]
#         return data_length,feat_num,conv_feat,num,num_rev,step_list
#     def ts_cov4d(self,data,stride):
#         '''计算4维数据的协方差'''
#         '''data:[N,C,H,W],,W:price length,N:batch size'''
#         if len(data.shape)!=4:
#             raise Exception('Input data dimensions should be [N,C,H,W]')
#         data_length , feat_num , conv_feat, num , num_rev,step_list= data_info(data,stride)
#         l = []
#         #计算的过程中务必保持keepdims=True
#         for i in range(len(step_list)-1):
#             start = step_list[i]
#             end = step_list[i+1]
#             sub_data1 = data[:,:,num,start:end] # (2000, 1, 36, 2, 10)
#             sub_data2 = data[:,:,num_rev,start:end]
#             mean1 = sub_data1.mean(axis = 4,keepdims = True) # (2000, 1, 36, 2, 1)
#             mean2 = sub_data2.mean(axis = 4,keepdims = True)
#             spread1 = sub_data1 - mean1 # (2000, 1, 36, 2, 10)
#             spread2 = sub_data2 - mean2
#             cov = ((spread1*spread2).sum(axis = 4,keepdims = True)/(sub_data1.shape[4] - 1)).mean(axis = 3,keepdims = True) # (2000, 1, 36, 1, 1)
#             l.append(cov)
#         corr = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,1,conv_feat,len(step_list)-1) # (2000, 1, 36, 3)
#         return torch.from_numpy(corr)
#     def ts_corr4d(self,data,stride):
#         '''计算4维数据的相关系数'''
#         '''data:[N,C,H,W],,W:price length,N:batch size'''
#         if len(data.shape)!=4:
#             raise Exception('Input data dimensions should be [N,C,H,W]')
#         data_length , feat_num , conv_feat, num , num_rev,step_list= data_info(data,stride)
#         l = []
#         for i in range(len(step_list)-1):
#             start = step_list[i]
#             end = step_list[i+1]
#             sub_data1 = data[:,:,num,start:end]
#             sub_data2 = data[:,:,num_rev,start:end]
#             std1 = sub_data1.std(axis = 4,keepdims = True)
#             std2 = sub_data2.std(axis = 4,keepdims = True)
#             std = (std1*std2).mean(axis = 3,keepdims = True)
#             l.append(std)
#         std = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,1,conv_feat,len(step_list)-1)
#         cov = self.ts_cov4d(data,stride)
#         fct = (sub_data1.shape[4]-1)/sub_data1.shape[4]
#         return (cov/torch.from_numpy(std))*fct
#     def ts_stddev4d(self,data,stride):
#         if len(data.shape)!=4:
#             raise Exception('Input data dimensions should be [N,C,H,W]')
#         data_length , feat_num , conv_feat, num , num_rev,step_list= data_info(data,stride)
#         l = []
#         for i in range(len(step_list)-1):
#             start = step_list[i]
#             end = step_list[i+1]
#             sub_data1 = data[:,:,:,start:end]
#             std1 = sub_data1.std(axis = 3,keepdims = True)
#             l.append(std1)
#         std = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,1,feat_num,len(step_list)-1)
#         return torch.from_numpy(std)
#     def ts_zscore(self,data,stride):
#         if len(data.shape)!=4:
#             raise Exception('Input data dimensions should be [N,C,H,W]')
#         data_length , feat_num , conv_feat, num , num_rev,step_list= data_info(data,stride)
#         l = []
#         for i in range(len(step_list)-1):
#             start = step_list[i]
#             end = step_list[i+1]
#             sub_data1 = data[:,:,:,start:end]
#             mean = sub_data1.mean(axis = 3,keepdims = True)
#             std = sub_data1.std(axis = 3,keepdims = True)
#             z_score = mean/std
#             l.append(z_score)
#         z_score = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,1,feat_num,len(step_list)-1)
#         return torch.from_numpy(z_score)
#     def ts_decaylinear(self,data,stride):
#         if len(data.shape)!=4:
#             raise Exception('Input data dimensions should be [N,C,H,W]')
#         data_length , feat_num , conv_feat, num , num_rev,step_list= data_info(data,stride)
#         l = []
#         for i in range(len(step_list)-1):
#             start = step_list[i]
#             end = step_list[i+1]
#             time_spread = end - start
#             weight = np.arange(1,time_spread+1)
#             weight = weight/(weight.sum())
#             sub_data1 = (data[:,:,:,start:end]*weight).mean(axis = 3,keepdims = True)
#             l.append(sub_data1)
#         decay_data = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,1,feat_num,len(step_list)-1)
#         return torch.from_numpy(decay_data)
#     def ts_pool(self,data,stride,method):
#         if type(data) == torch.Tensor:
#             data = data.detach().numpy()
#         if data.shape[-1] <= stride:
#             step_list = [0,data.shape[-1]]
#         if len(data.shape)!=4:
#             raise Exception('Input data dimensions should be [N,C,H,W]')
#         data_length , feat_num , conv_feat, num , num_rev,step_list= data_info(data,stride)
#         l = []
#         for i in range(len(step_list)-1):
#             start = step_list[i]
#             end = step_list[i+1]
#             if method == 'max':
#                 sub_data1 = data[:,:,:,start:end].max(axis = 3,keepdims = True)
#             if method == 'min':
#                 sub_data1 = data[:,:,:,start:end].min(axis = 3,keepdims = True)
#             if method == 'mean':
#                 sub_data1 = data[:,:,:,start:end].mean(axis = 3,keepdims = True)
#             l.append(sub_data1)
#         try:
#             pool_data = np.squeeze(np.array(l)).transpose(1,2,0).reshape(-1,1,feat_num,len(step_list) - 1)
#         except:
#             pool_data = np.squeeze(np.array(l)).reshape(-1,1,feat_num,len(step_list) - 1)
#         return torch.from_numpy(pool_data)
