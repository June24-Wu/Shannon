# %%
alpha_name = "AlphaNet_Original_Input"
path = "/home/wuwenjun/Alpha_Factor/AlphaNetV1_Original_Input"
output_path = r'/home/wuwenjun/factor_lib/ti0/wuwenjun'

# %%
import time
from Research.backtest.bt import BTDaily
from Research.feature.ft import FeatureAnalysis
import Research.utils.namespace as namespace
import Research.utils.normalization as norm
from Platform.database.mysql import MysqlAPI
from Platform.utils.persistence import convert_to_standard_daily_feature_csv, convert_to_standard_daily_feature_par
from Platform.config.mysql_info import FACTOR_LIB_MYSQL_TIO
import numpy as np

# %%
# 生成标准数据


from os import walk
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from progressbar import ProgressBar
from tqdm import tqdm
df = pd.DataFrame()


for f, _, i in walk(path):
    for j in tqdm(i):
        df = pd.concat([df,pd.read_csv(f + "/" + j)],axis=0)
df.rename(columns={'AlphaNet': alpha_name}, inplace=True)
df['timestamp'] = df['timestamp'].astype(str)
# df['timestamp'] = df['timestamp'].astype(int).astype(str)
df['symbol'] = df['symbol'].astype(int)
df['symbol'] =  df['symbol'].apply(lambda x : '{:0>6d}'.format(x))
df['symbol'] = df['symbol'].astype('string')
df['timestamp'] = pd.to_datetime(df['timestamp'])
display(df)
# output

convert_to_standard_daily_feature_csv(alpha_name, df, output_path)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 12.75it/s]
#         symbol           timestamp  AlphaNet_Original_Input
# 0       000001 2019-05-16 09:30:00                -0.012189
# 1       000001 2019-05-21 09:30:00                -0.012623
# 2       000001 2019-05-24 09:30:00                 0.017195
# 3       000001 2019-05-29 09:30:00                -0.033453
# 4       000001 2019-06-03 09:30:00                -0.001300
# ...        ...                 ...                      ...
# 115640  601399 2021-06-28 09:30:00                 0.043495
# 115641  000408 2021-06-24 09:30:00                -0.003002
# 115642  600080 2021-06-24 09:30:00                -0.002599
# 115643  600877 2021-06-25 09:30:00                -0.002531
# 115644  603389 2021-06-25 09:30:00                -0.009664
#
# [483461 rows x 3 columns]

# %%
df[df['timestamp'] == '2019-05-20 09:30:00']
# Out:
#        symbol           timestamp  AlphaNet_Original_Input
# 8895   002514 2019-05-20 09:30:00                -0.011016
# 33809  600202 2019-05-20 09:30:00                 0.038287
# 33819  600871 2019-05-20 09:30:00                 0.015074
# 33829  601860 2019-05-20 09:30:00                -0.058718

# %%
import time
from Research.backtest.bt import BTDaily
from Research.feature.ft import FeatureAnalysis
import Research.utils.namespace as namespace
import Research.utils.normalization as norm
import numpy as np
 
config_path = r'/home/ShareFolder/lgc/Modules/Research/config/feature_bt_template'
print('Loading the configuration from ' + config_path)
configs = namespace.load_namespace(config_path)
FT = FeatureAnalysis(configs, feature_path=r"/home/wuwenjun/factor_lib")

alpha_list = list(FT.features_in_path.keys())
start_date = '2018-01-01'
end_date = '2021-03-02'
FT.load_feature_from_file(alpha_list, start_date, end_date, universe='Investable',
                                       timedelta=None, transformer=norm.standard_scale)
FT.load_return_data()

for alpha_name in alpha_list:
    FT.get_intersection_ic(feature_name=alpha_name, truncate_fold=None, method='spearman',
                                     period=('1d', '3d', '5d'))
#     ic_flag, trading_direction = FT.test_ic(alpha_name, verbose=False)
    df, df_all = FT.get_ic_summary_by_month(num=6)
#     if trading_direction == -1:
#         negative = True
#     else:
#         negative = False
#     FT.get_top_return(alpha_name, negative=True, trade_type='long-short', transmission_rate=0.0,
#                             tax_rate=0.0, verbose=True)
# Out:
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template
# Loading Feature...: 100%|████████████████████████████████████████████████████████████████████████████████████████| 1532/1532 [00:02<00:00, 634.54it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ShareFolder/lgc/Modules/Research/feature/ft.py", line 1325, in _merge
#     df = pd.concat(df_list, copy=False, axis=1, sort=False)
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 298, in concat
#     return op.get_result()
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 516, in get_result
#     indexers[ax] = obj_labels.get_indexer(new_labels)
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 3173, in get_indexer
#     "Reindexing only valid with uniquely valued Index objects"
# pandas.errors.InvalidIndexError: Reindexing only valid with uniquely valued Index objects
# """
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-12-028cde148921> in <module>
#      15 end_date = '2021-03-02'
#      16 FT.load_feature_from_file(alpha_list, start_date, end_date, universe='Investable',
# ---> 17                                        timedelta=None, transformer=norm.standard_scale)
#      18 FT.load_return_data()
#      19
#
# /home/ShareFolder/lgc/Modules/Research/feature/ft.py in load_feature_from_file(self, feature_names, start_time, end_time, universe, timedelta, transformer, cover_rate, check_timestamp)
#     269                                                          handler=handler, time_delta=timedelta, transformer=transformer,
#     270                                                          cover_rate=cover_rate,
# --> 271                                                          missing_file_allowed=missing_file_allowed)
#     272         self.feature_data = \
#     273             self.feature_data.loc[(self.feature_data.index.get_level_values(0) >= pd.Timestamp(start_time)) &
#
# /home/ShareFolder/lgc/Modules/Research/feature/ft.py in read_files_filter(path_list, universe, pool, scope, handler, time_delta, transformer, cover_rate, missing_file_allowed)
#    1397                 while index:
#    1398                     out_index = index.pop(0) - count
# -> 1399                     df = result_list[out_index].get()
#    1400                     df_list.append(df)
#    1401                     result_list.pop(out_index)
#
# /usr/local/miniconda/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects
# Process ForkPoolWorker-893:
# Process ForkPoolWorker-936:
# Process ForkPoolWorker-871:
# Process ForkPoolWorker-910:
# Process ForkPoolWorker-907:
# Process ForkPoolWorker-930:
# Process ForkPoolWorker-901:
# Process ForkPoolWorker-876:
# Process ForkPoolWorker-873:
# Process ForkPoolWorker-891:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):

# %%
alpha_list

# %%
alpha_list
# Out:
# ['AlphaNet_1130', 'AlphaNet_Original_Input']

# %%
import time
from Research.backtest.bt import BTDaily
from Research.feature.ft import FeatureAnalysis
import Research.utils.namespace as namespace
import Research.utils.normalization as norm
import numpy as np
 
config_path = r'/home/ShareFolder/lgc/Modules/Research/config/feature_bt_template'
print('Loading the configuration from ' + config_path)
configs = namespace.load_namespace(config_path)
FT = FeatureAnalysis(configs, feature_path=r"/home/wuwenjun/factor_lib")

# alpha_list = list(FT.features_in_path.keys())[0]
# print(alpha_list)
start_date = '2019-01-01'
end_date = '2021-06-30'
FT.load_feature_from_file('AlphaNet_Original_Input', start_date, end_date, universe='Investable',
                                       timedelta=None, transformer=norm.standard_scale)
FT.load_return_data()

FT.get_intersection_ic(feature_name='AlphaNet_Original_Input', truncate_fold=None, method='spearman',
                                     period=('1d', '3d', '5d'))

# ic_flag, trading_direction = FT.test_ic(alpha_name, verbose=False)
df, df_all = FT.get_ic_summary_by_month(num=6)
#     if trading_direction == -1:
#         negative = True
#     else:
#         negative = False
# Out:
# Loading the configuration from /home/ShareFolder/lgc/Modules/Research/config/feature_bt_template
# Loading Feature...:  17%|███████████████                                                                           | 101/604 [00:00<00:01, 377.05it/s]terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Loading Feature...:  17%|███████████████▎                                                                          | 103/604 [00:00<00:01, 377.05it/s]terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Loading Feature...:  24%|█████████████████████▍                                                                    | 144/604 [00:00<00:01, 318.87it/s]terminate called after throwing an instance of 'terminate called after throwing an instance of 'std::system_errorterminate called after throwing an instance of 'terminate called after throwing an instance of 'terminate called after throwing an instance of 'std::system_error'
# std::system_errorstd::system_error'
# std::system_error'
# '
# '
#   what():    what():    what():  Resource temporarily unavailable  what():  Resource temporarily unavailableResource temporarily unavailableResource temporarily unavailable
#
#   what():
#
# Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Loading Feature...:  24%|█████████████████████▌                                                                    | 145/604 [00:00<00:01, 318.87it/s]terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Loading Feature...:  26%|███████████████████████                                                                   | 155/604 [00:00<00:01, 318.87it/s]terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable  what():
# Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# terminate called after throwing an instance of 'terminate called after throwing an instance of 'std::system_errorstd::system_error'
# '
#   what():    what():  Resource temporarily unavailableResource temporarily unavailable
#
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Loading Feature...:  26%|███████████████████████▋                                                                  | 159/604 [00:00<00:01, 318.87it/s]terminate called after throwing an instance of 'std::system_error'
# Loading Feature...:  26%|███████████████████████▊                                                                  | 160/604 [00:00<00:01, 318.87it/s]  what():  Resource temporarily unavailable
# Loading Feature...:  29%|█████████████████████████▉                                                                | 174/604 [00:00<00:01, 318.87it/s]std::system_error'fter throwing an instance of '
#   what():  Resource temporarily unavailable
# Loading Feature...:  56%|██████████████████████████████████████████████████                                        | 336/604 [00:00<00:00, 423.57it/s]terminate called after throwing an instance of 'std::system_error'
# Loading Feature...:  56%|██████████████████████████████████████████████████▏                                       | 337/604 [00:00<00:00, 423.57it/s]  what():  Resource temporarily unavailable
# Loading Feature...:  57%|██████████████████████████████████████████████████▉                                       | 342/604 [00:00<00:00, 423.57it/s]terminate called after throwing an instance of 'terminate called after throwing an instance of 'std::system_errorstd::system_error'
# '
#   what():    what():  Resource temporarily unavailableResource temporarily unavailable
#
# terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Loading Feature...:  58%|████████████████████████████████████████████████████▎                                     | 351/604 [00:00<00:00, 459.47it/s]terminate called after throwing an instance of 'std::system_error'
#   what():  Resource temporarily unavailable
# Loading Feature...:  86%|█████████████████████████████████████████████████████████████████████████████▏            | 518/604 [00:01<00:00, 385.44it/s]terminate called after throwing an instance of 'std::system_error'
# Loading Feature...:  86%|█████████████████████████████████████████████████████████████████████████████▎            | 519/604 [00:01<00:00, 385.44it/s]  what():  Resource temporarily unavailable
# Loading Feature...:  95%|█████████████████████████████████████████████████████████████████████████████████████▍    | 573/604 [00:18<00:00, 385.44it/s]Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Loading Feature...:  95%|██████████████████████████████████████████████████████████████████████████████████████▎    | 573/604 [00:37<00:02, 15.35it/s]Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
# Resource temporarily unavailable (src/thread.cpp:269)
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Process ForkPoolWorker-950:
# Process ForkPoolWorker-1028:
# Process ForkPoolWorker-983:
# Process ForkPoolWorker-939:
# Process ForkPoolWorker-1022:
# Process ForkPoolWorker-1015:
# Process ForkPoolWorker-977:
# Traceback (most recent call last):
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3427, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-942a3a9d96d0>", line 18, in <module>
#     timedelta=None, transformer=norm.standard_scale)
#   File "/home/ShareFolder/lgc/Modules/Research/feature/ft.py", line 271, in load_feature_from_file
#     missing_file_allowed=missing_file_allowed)
#   File "/home/ShareFolder/lgc/Modules/Research/feature/ft.py", line 1352, in read_files_filter
#     time.sleep(0.00001)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/wuwenjun/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/local/miniconda/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/local/miniconda/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/local/miniconda/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/local/miniconda/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/local/miniconda/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/local/miniconda/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# KeyboardInterrupt
# Process ForkPoolWorker-969:
# Process ForkPoolWorker-980:
# Process ForkPoolWorker-973:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-13-942a3a9d96d0> in <module>
#      17 FT.load_feature_from_file('AlphaNet_Original_Input', start_date, end_date, universe='Investable',
# ---> 18                                        timedelta=None, transformer=norm.standard_scale)
#      19 FT.load_return_data()
#
# /home/ShareFolder/lgc/Modules/Research/feature/ft.py in load_feature_from_file(self, feature_names, start_time, end_time, universe, timedelta, transformer, cover_rate, check_timestamp)
#     270                                                          cover_rate=cover_rate,
# --> 271                                                          missing_file_allowed=missing_file_allowed)
#     272         self.feature_data = \
#
# /home/ShareFolder/lgc/Modules/Research/feature/ft.py in read_files_filter(path_list, universe, pool, scope, handler, time_delta, transformer, cover_rate, missing_file_allowed)
#    1351             while len(result_list) > 0:
# -> 1352                 time.sleep(0.00001)
#    1353                 status = np.array(list(map(lambda x: x.ready(), result_list)))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2053                         # in the engines. This should return a list of strings.
# -> 2054                         stb = value._render_traceback_()
#    2055                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2055                     except Exception:
#    2056                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2057                                             value, tb, tb_offset=tb_offset)
#    2058
#    2059                     self._showtraceback(etype, value, stb)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
# Process ForkPoolWorker-1030:
# Process ForkPoolWorker-1012:
# Process ForkPoolWorker-999:
# Process ForkPoolWorker-991:
# Process ForkPoolWorker-1019:
# Process ForkPoolWorker-948:
# Process ForkPoolWorker-971:
# Process ForkPoolWorker-994:
# Process ForkPoolWorker-947:
# Process ForkPoolWorker-1018:
# Process ForkPoolWorker-1021:
# Process ForkPoolWorker-1035:
# Process ForkPoolWorker-1024:
# Process ForkPoolWorker-1014:
# Process ForkPoolWorker-1039:
# Process ForkPoolWorker-1037:
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-1033:
# Process ForkPoolWorker-1029:
# Process ForkPoolWorker-965:
# KeyboardInterrupt
# Process ForkPoolWorker-987:
# Traceback (most recent call last):
# Process ForkPoolWorker-1025:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process ForkPoolWorker-1032:
# Process ForkPoolWorker-937:
# Process ForkPoolWorker-975:
# Process ForkPoolWorker-1008:
# Process ForkPoolWorker-940:
# Process ForkPoolWorker-960:
# Process ForkPoolWorker-976:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-974:
# Process ForkPoolWorker-938:
# Process ForkPoolWorker-989:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/miniconda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)

# %%
FT.get_top_return('AlphaNet_1130', negative=True, trade_type='long-short', transmission_rate=0.0,
                            tax_rate=0.0, verbose=True)
# Out:
# Getting BT result for date: 20190515...:  14%|██████████                                                            | 87/604 [00:00<00:04, 128.99it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ac1c09600ff9> in <module>
#       1 FT.get_top_return('AlphaNet_1130', negative=True, trade_type='long-short', transmission_rate=0.0,
# ----> 2                             tax_rate=0.0, verbose=True)
#
# /home/ShareFolder/lgc/Modules/Research/feature/ft.py in get_top_return(self, feature_name, negative, trade_type, stock_pct, transmission_rate, tax_rate, period, weight, verbose, **kwargs)
#     652         bt.feed_data(df)
#     653         # bt.run_feature(start_num=start_num, end_num=end_num, mode=mode)
# --> 654         bt.run()
#     655
#     656         if verbose:
#
# /home/ShareFolder/lgc/Modules/Research/backtest/bt.pyc in run(self)
#
# /home/ShareFolder/lgc/Modules/Research/backtest/bt.pyc in run_intersect_long_short(self)
#
# ValueError: operands could not be broadcast together with shapes (1122,) (1677,)

# %%
FT.data_info
